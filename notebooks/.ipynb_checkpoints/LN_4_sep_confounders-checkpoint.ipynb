# %%
import sys

# %%
sys.path.insert(1,'../src')
sys.path.insert(1,'../src/ITE-1.1_code')

# %%
from latentNoise_funcs_gen   import *
# Out:
# [1] "in func_entropy_v1.R"
# $platform
# [1] "x86_64-conda-linux-gnu"
#
# $arch
# [1] "x86_64"
#
# $os
# [1] "linux-gnu"
#
# $system
# [1] "x86_64, linux-gnu"
#
# $status
# [1] ""
#
# $major
# [1] "4"
#
# $minor
# [1] "0.5"
#
# $year
# [1] "2021"
#
# $month
# [1] "03"
#
# $day
# [1] "31"
#
# $`svn rev`
# [1] "80133"
#
# $language
# [1] "R"
#
# $version.string
# [1] "R version 4.0.5 (2021-03-31)"
#
# $nickname
# [1] "Shake and Throw"
#
# enters latentNoise_funcs_gen.py

# %% [markdown]
# # Generate Data

# %% [markdown]
# ## generate $z_x,z_y,z_c$

# %% [markdown]
# ## generate $x$

# %% [markdown]
# ## generate $y$

# %% [markdown]
# ## generate $u$

# %% [markdown]
# # Adapt ln-krr

# %% [markdown]
# ## Adapt model function

# %% [markdown]
# ## Adapt loss function

# %%
@jax.jit
def getDataLoss_LNC(smpl, loss_data):
    
    x, y, Z, K_u, D_x, K_y, D_y, K_x = loss_data 
    

    D_x_aux = D_x[smpl, :]
    D_x_aux = D_x_aux[:, smpl]
    #K_zmani_aux = K_zmani[smpl,:]
    #K_zmani_aux = K_zmani_aux[:,smpl]
    K_y_aux = K_y[smpl,:]
    K_y_aux = K_y_aux[:,smpl]
    K_u_aux = K_u[smpl,:]
    #K_u_aux = K_u_aux[:,smpl]
                
    x_aux = x[smpl,]
    y_aux = y[smpl,]
    

    if Z is not None:
        Z_aux = Z[smpl,]
    else:
        Z_aux = None
        
            
    return x_aux, y_aux, Z_aux, K_u_aux, D_x_aux, K_y_aux, None, None

# %%
onp.random.normal(size=100)[:,None].shape
# Out:
# (100, 1)

# %%
from sklearn.manifold import Isomap


def getIniPar_LNC(reps, loss_data, pars, smplsParts): #N, m, reps, y, M
    
    
    _, _, lam, _ , _ = pars 
    x, y, Z, K_u, D_x, K_y, D_y, K_x = loss_data
    
    n = x.shape[0]
    

    # initialize z_x to x, z_y to y and z_c manifold of z_c
    # we actually have to initialize alpha_x, alpha_y and alpha_c so in each case
    # we have to work out what z = U*alpha -> cholesky decomposition of U
    
    zx_ini = x
    zy_ini = y 
    
    embedding = Isomap(n_components=10)
    xy = onp.hstack([x, y])
    xy_transformed = embedding.fit_transform(xy)
    zc_ini = np.array(xy_transformed[:,3])[:,None]
    
    
    #L = linalg.cho_factor(np.dot(U.T, U) + 0.0001 * np.eye(m))
    #alpha_x = linalg.cho_solve(L, np.dot(U.T, zx_ini))
    #alpha_y = linalg.cho_solve(L, np.dot(U.T, zy_ini))
    #alpha_c = linalg.cho_solve(L, np.dot(U.T, zc_ini))
    
    
    ws = np.ones(n)
    alpha_x, _, _ = krrModel(lam, K_u, zx_ini, ws)
    alpha_x = alpha_x * np.ones(reps)
    alpha_y, _, _ = krrModel(lam, K_u, zy_ini, ws)
    alpha_y = alpha_y * np.ones(reps)
    alpha_c, _, _ = krrModel(lam, K_u, zc_ini, ws)
    alpha_c = alpha_c * np.ones(reps)
    
    #alpha_x = onp.random.normal(size=(n,reps))#[:,None]
    #alpha_y = onp.random.normal(size=(n,reps))#[:,None]
    #alpha_c = onp.random.normal(size=(n,reps))#[:,None]
    
    
    params = {
            'alpha_x': alpha_x,
            'alpha_y': alpha_y,
            'alpha_c': alpha_c,
    }
    
    #onp.random.seed(seed=4)
    
    zx_ini = np.array(onp.apply_along_axis(normalize, 0, zx_ini))
    zy_ini = np.array(onp.apply_along_axis(normalize, 0, zy_ini))
    zc_ini = np.array(onp.apply_along_axis(normalize, 0, zc_ini))
    

    
    sigma_x_med = 1 / np.median(D_x)
    sigma_y = 1 / np.median(D_y)
    

    
    D_zx = covariance_matrix(sqeuclidean_distance, zx_ini, zx_ini)
    sigma_zx_med = 1 / np.median(D_zx)
    
    D_zy= covariance_matrix(sqeuclidean_distance, zy_ini, zy_ini)
    sigma_zy_med = 1 / np.median(D_zy)
    
    D_zc = covariance_matrix(sqeuclidean_distance, zc_ini, zc_ini)
    sigma_zc_med = 1 / np.median(D_zc)
    
    
    
    K_zx = rbf_kernel_matrix({'gamma': sigma_zx_med}, zx_ini, zx_ini)
    K_zy = rbf_kernel_matrix({'gamma': sigma_zy_med}, zy_ini, zy_ini)
    K_zc = rbf_kernel_matrix({'gamma': sigma_zc_med}, zc_ini, zc_ini)
    K_yhat = K_x*K_zc*K_zy
    K_xhat = K_zc*K_zx

    
    smplPart1 = smplsParts[0]
    N_part1 = smplPart1.shape[0]
    y_part1 = y[smplPart1,]
    x_part1 = x[smplPart1,]
    K_yhat_part1 = K_yhat[smplPart1, :]
    K_yhat_part1 = K_yhat_part1[:, smplPart1]
    K_xhat_part1 = K_xhat[smplPart1, :]
    K_xhat_part1 = K_xhat_part1[:, smplPart1]
    ws = np.ones(N_part1)
    
    
    weights_y, resids_y, y_hat = krrModel(lam, K_yhat_part1, y_part1, ws)
    weights_x, resids_x, x_hat = krrModel(lam, K_xhat_part1, x_part1, ws)
    
    # right now we simply overwrite residual lengthscale sig_r_h to be median heuristic
    distsRx = covariance_matrix(sqeuclidean_distance, resids_x, resids_x)
    sigma_rx_med = 1 / np.quantile(distsRx, 0.5)
    distsRy = covariance_matrix(sqeuclidean_distance, resids_y, resids_y)
    sigma_ry_med = 1 / np.quantile(distsRy, 0.5)
    
    

    qs = [0.1, 0.3, 0.5, 0.7,0.9,0.99, 1]
    qs_smpl_zx_f = np.array(qs)
    sigs_zx_f= 1/np.quantile(D_zx, qs_smpl_zx_f)
    
    qs_smpl_zy_f = np.array(qs)
    sigs_zy_f= 1/np.quantile(D_zy, qs_smpl_zy_f)
    
    qs_smpl_zc_f = np.array(qs)
    sigs_zc_f= 1/np.quantile(D_zc, qs_smpl_zc_f)
    
    
    sigs_x_f= sigma_x_med * np.ones(reps)
    
    sigs_zx_h= sigma_zx_med * np.ones(reps)
    sigs_zy_h= sigma_zy_med * np.ones(reps)
    sigs_zc_h= sigma_zc_med * np.ones(reps)
    sigs_x_h= sigma_x_med * np.ones(reps)
    sigs_rx_h= sigma_rx_med * np.ones(reps)
    sigs_ry_h= sigma_rx_med * np.ones(reps)
    
    params['ln_sig_zx_f']= np.log(sigs_zx_f)
    params['ln_sig_zy_f']= np.log(sigs_zy_f)
    params['ln_sig_zc_f']= np.log(sigs_zc_f)
    params['ln_sig_x_f']= np.log(sigs_x_f)
    
    params['ln_sig_zx_h']= np.log(sigs_zx_h)
    params['ln_sig_zy_h']= np.log(sigs_zy_h)
    params['ln_sig_zc_h']= np.log(sigs_zc_h)
    params['ln_sig_x_h']= np.log(sigs_x_h)
    params['ln_sig_rx_h']= np.log(sigs_rx_h)
    params['ln_sig_ry_h']= np.log(sigs_ry_h)
    
    
    return params

# %%
@jax.jit
def kernel_mat_LNC(D_x, x, zx, zy, zc, sig_x_h, sig_zx_h, sig_zy_h, sig_zc_h, sigs_f):
    # sigs_f = np.hstack([sig_x_f, sig_zx_f, sig_zy_f, sig_zc_f])
    sig_x_f = sigs_f[0]
    sig_zx_f = sigs_f[1]
    sig_zy_f = sigs_f[2]
    sig_zc_f = sigs_f[3]
    
    K_x_f = np.exp(-sig_x_f * D_x)
    K_zx_f = rbf_kernel_matrix({'gamma': sig_zx_f}, zx, zx)
    K_zy_f = rbf_kernel_matrix({'gamma': sig_zy_f}, zy, zy)
    K_zc_f = rbf_kernel_matrix({'gamma': sig_zc_f}, zc, zc)
    

    K_x_h = K_x_f #np.exp(-sig_x_h * D_x)
    K_zx_h = K_zx_f #rbf_kernel_matrix({'gamma': sig_z_h}, z, z)
    K_zy_h = K_zy_f #rbf_kernel_matrix({'gamma': sig_z_h}, z, z)
    K_zc_h = K_zc_f #rbf_kernel_matrix({'gamma': sig_z_h}, z, z)
    # x causes - to compare to rx
    K_ax_h = K_zx_h * K_zc_h
    # y causes - to compare to ry
    K_ay_h = K_x_h*K_zy_h * K_zc_h
    #K_a_f = 2 * K_x_f + 2 * K_z_f + K_xz_f + K_zx_f
    K_ax_f = K_ax_h
    K_ay_f = K_ay_h

    return K_ax_f, K_ay_f, K_ax_h, K_ay_h, K_x_h, K_zx_h, K_zy_h, K_zc_h

# %%
# loss 
@jax.jit
def loss_LNC(params, pars, loss_data, ws):
    
    beta, neta, lam, nu, lu = pars 
    
    
    x, y, Z, K_u, D_x, K_y, D_y, K_x = loss_data
    
    alpha_x = params["alpha_x"]
    alpha_y = params["alpha_y"]
    alpha_c = params["alpha_c"]
    
    zx = K_u@alpha_x
    zy = K_u@alpha_y
    zc = K_u@alpha_c
    
    zx = (zx - np.mean(zx)) / (np.std(zx))
    zy = (zy - np.mean(zy)) / (np.std(zy))
    zc = (zc - np.mean(zc)) / (np.std(zc))

    
    sig_x_h = np.exp(params["ln_sig_x_h"])
    sig_zx_h = np.exp(params["ln_sig_zx_h"])
    sig_zy_h = np.exp(params["ln_sig_zy_h"])
    sig_zc_h = np.exp(params["ln_sig_zc_h"])
    sig_rx_h = np.exp(params["ln_sig_rx_h"])
    sig_ry_h = np.exp(params["ln_sig_ry_h"])
    


    sig_x_f = np.exp(params["ln_sig_x_f"])
    sig_zx_f = np.exp(params["ln_sig_zx_f"])
    sig_zy_f = np.exp(params["ln_sig_zy_f"])
    sig_zc_f = np.exp(params["ln_sig_zc_f"])
    
    
    sigs_f = np.hstack([sig_x_f, sig_zx_f, sig_zy_f, sig_zc_f])
    K_ax_f, K_ay_f, K_ax_h, K_ay_h, K_x_h, K_zx_h, K_zy_h, K_zc_h = kernel_mat_LNC(D_x, x, zx, zy, zc, sig_x_h, sig_zx_h, sig_zy_h, sig_zc_h, sigs_f) 
    n = K_ax_f.shape[0]
 
    weights_y, resids_y, y_hat = krrModel(lam, K_ay_f, y, ws)
    weights_x, resids_x, x_hat = krrModel(lam, K_ax_f, x, ws)
    
    # right now we simply overwrite residual lengthscale sig_r_h to be median heuristic
    distsRx = covariance_matrix(sqeuclidean_distance, resids_x, resids_x)
    sig_rx_h = 1 / np.quantile(distsRx, 0.5)
    distsRy = covariance_matrix(sqeuclidean_distance, resids_y, resids_y)
    sig_ry_h = 1 / np.quantile(distsRx, 0.5)
    


    K_rx_h = rbf_kernel_matrix({'gamma': sig_rx_h}, resids_x, resids_x)
    K_ry_h = rbf_kernel_matrix({'gamma': sig_ry_h}, resids_y, resids_y)

    
    # additivity
    # hsic resids_x, (zx, zc)
    hsic_rx_ax = hsic(K_rx_h, K_ax_h)
    # hsic resids_y, (x, zx, zc)
    hsic_ry_ay = hsic(K_ry_h, K_ay_h)
    hsic_resids = np.log(hsic_rx_ax) +  np.log(hsic_ry_ay)

    # indep causes: between (zx, zy, zc) and between zy and x
    hsic_zx_zy = hsic(K_zx_h, K_zy_h)
    #hsic_zx_zy = np.max(np.array([hsic_zx_zy, 0.01]))
    hsic_zx_zc = hsic(K_zx_h, K_zc_h)
    #hsic_zx_zc = np.max(np.array([hsic_zx_zc, 0.01]))
    hsic_zy_zc = hsic(K_zy_h, K_zc_h)
    #hsic_zy_zc = np.max(np.array([hsic_zy_zc, 0.01]))
    hsic_zy_x  = hsic(K_zy_h, K_x_h)
    #hsic_zy_x = np.max(np.array([hsic_zy_x, 0.01]))
    hsic_indep = np.log(hsic_zx_zy) + np.log(hsic_zx_zc) + np.log(hsic_zy_zc) + np.log(hsic_zy_x)
     
    # mse residual
    mse_rx = mse(x, x_hat)
    mse_ry = mse(y, y_hat)
    mses = np.log(mse_rx) +  np.log(mse_ry)
    
    # CI condition
    
    # Zs size
    zx_norm = np.dot(zx.T, zx)[1,1]
    zy_norm = np.dot(zy.T, zy)[1,1]
    zc_norm = np.dot(zc.T, zc)[1,1]
    z_norm = np.log(zx_norm) + np.log(zy_norm) + np.log(zc_norm)
    
    # calcualte compute los
    loss_value = 0*hsic_resids + beta * mses  + neta*hsic_indep   + nu*z_norm 
    
    return loss_value

# %%
dloss_LNC = jax.grad(loss_LNC, )
dloss_LNC_jitted = jax.jit(dloss_LNC)

# %%
# for reporting purposes give back 3 terms separatley
@jax.jit
def model_LNC(params, lam, loss_data, K_t):

    x, y, Z, K_u, D_x, K_y, D_y, K_x = loss_data

    alpha_x = params["alpha_x"]
    alpha_y = params["alpha_y"]
    alpha_c = params["alpha_c"]
    
    zx = K_u@alpha_x
    zy = K_u@alpha_y
    zc = K_u@alpha_c
    
    zx = (zx - np.mean(zx)) / (np.std(zx))
    zy = (zy - np.mean(zy)) / (np.std(zy))
    zc = (zc - np.mean(zc)) / (np.std(zc))

    
    sig_x_h = np.exp(params["ln_sig_x_h"])
    sig_zx_h = np.exp(params["ln_sig_zx_h"])
    sig_zy_h = np.exp(params["ln_sig_zy_h"])
    sig_zc_h = np.exp(params["ln_sig_zc_h"])
    sig_rx_h = np.exp(params["ln_sig_rx_h"])
    sig_ry_h = np.exp(params["ln_sig_ry_h"])
    


    sig_x_f = np.exp(params["ln_sig_x_f"])
    sig_zx_f = np.exp(params["ln_sig_zx_f"])
    sig_zy_f = np.exp(params["ln_sig_zy_f"])
    sig_zc_f = np.exp(params["ln_sig_zc_f"])
    
    
    sigs_f = np.hstack([sig_x_f, sig_zx_f, sig_zy_f, sig_zc_f])
    K_ax_f, K_ay_f, K_ax_h, K_ay_h, K_x_h, K_zx_h, K_zy_h, K_zc_h = kernel_mat_LNC(D_x, x, zx, zy, zc, sig_x_h, sig_zx_h, sig_zy_h, sig_zc_h, sigs_f) 
    n = K_ax_f.shape[0]

    ws = np.ones(n)
    weights_y, resids_y, y_hat = krrModel(lam, K_ay_f, y, ws)
    weights_x, resids_x, x_hat = krrModel(lam, K_ax_f, x, ws)
    
    # right now we simply overwrite residual lengthscale sig_r_h to be median heuristic
    distsRx = covariance_matrix(sqeuclidean_distance, resids_x, resids_x)
    sig_rx_h = 1 / np.quantile(distsRx, 0.5)
    distsRy = covariance_matrix(sqeuclidean_distance, resids_y, resids_y)
    sig_ry_h = 1 / np.quantile(distsRx, 0.5)
    K_rx_h = rbf_kernel_matrix({'gamma': sig_rx_h}, resids_x, resids_x)
    K_ry_h = rbf_kernel_matrix({'gamma': sig_ry_h}, resids_y, resids_y)

    
    # additivity
    # hsic resids_x, (zx, zc)
    hsic_rx_ax = hsic(K_rx_h, K_ax_h)
    # hsic resids_y, (x, zx, zc)
    hsic_ry_ay = hsic(K_ry_h, K_ay_h)
    hsic_resids = np.log(hsic_rx_ax) +  np.log(hsic_ry_ay)

    
    # indep causes: between (zx, zy, zc) and between zy and x
    hsic_zx_zy = hsic(K_zx_h, K_zy_h)
    hsic_zx_zc = hsic(K_zx_h, K_zc_h)
    hsic_zy_zc = hsic(K_zy_h, K_zc_h)
    hsic_zy_x  = hsic(K_zy_h, K_x_h)
    hsic_indep = np.log(hsic_zx_zy) + np.log(hsic_zx_zc) + np.log(hsic_zy_zc) + np.log(hsic_zy_x)
     
    
        
        
    # mse residual
    mse_rx = mse(x, x_hat)
    mse_ry = mse(y, y_hat)
    mses = np.log(mse_rx) +  np.log(mse_ry)

    
    

    # hsic (zs, zs_reals)
    
    # only valid for "5_exponential1gaussian1_dependent_10_1_100.csv"
    # ix c(8, 2, 3)
    # iy c(1, 7, 6)
    # ic 10    
    zx_real = Z[:,[7,1,2]]
    zy_real = Z[:,[0,6,5]]
    zc_real = Z[:,9]
    
    distsZx_real = covariance_matrix(sqeuclidean_distance, zx_real, zx_real)
    sig_zx_real = 1 / np.quantile(distsZx_real, 0.5)
    K_zx_real = rbf_kernel_matrix({'gamma': sig_zx_real}, zx_real, zx_real)
    
    distsZy_real = covariance_matrix(sqeuclidean_distance, zy_real, zy_real)
    sig_zy_real = 1 / np.quantile(distsZy_real, 0.5)
    K_zy_real = rbf_kernel_matrix({'gamma': sig_zy_real}, zy_real, zy_real)
    
    distsZc_real = covariance_matrix(sqeuclidean_distance, zc_real, zc_real)
    sig_zc_real = 1 / np.quantile(distsZc_real, 0.5)
    K_zc_real = rbf_kernel_matrix({'gamma': sig_zc_real}, zc_real, zc_real)
    
    
    hsic_zx = hsic(K_zx_h, K_zx_real)
    hsic_zy = hsic(K_zy_h, K_zy_real)
    hsic_zc = hsic(K_zc_h, K_zc_real)
    
    imp_zx = hsic(K_zx_h, K_zc_real)
    imp_zy = hsic(K_zy_h, K_zc_real)
    
    
    
    monitor = {}
    monitor = {    
        'hsic_rx_ax': hsic_rx_ax,
        'hsic_ry_ay': hsic_ry_ay,
        'hsic_resids': hsic_resids,
        'hsic_zx_zy': hsic_zx_zy,
        'hsic_zx_zc': hsic_zx_zc,
        'hsic_zy_zc': hsic_zy_zc,
        'hsic_zy_x': hsic_zy_x,
        'hsic_indep': hsic_indep,
        'mse_rx': mse_rx,
        'mse_ry': mse_ry,
        'mses': mses,
        'hsic_zx': hsic_zx,
        'hsic_zy': hsic_zy,
        'hsic_zc': hsic_zc,
        'imp_zx': imp_zx,
        'imp_zy': imp_zy
        
    }

    return monitor

# %%
@jax.jit
def getParamsForGrad_LNC(params, rep, smpl):

    
    
    ln_sig_x_h = params["ln_sig_x_h"][rep]
    ln_sig_zx_h = params["ln_sig_zx_h"][rep]
    ln_sig_zy_h = params["ln_sig_zy_h"][rep]
    ln_sig_zc_h = params["ln_sig_zc_h"][rep]
    ln_sig_rx_h = params["ln_sig_rx_h"][rep]
    ln_sig_ry_h = params["ln_sig_ry_h"][rep]
    


    ln_sig_x_f = params["ln_sig_x_f"][rep]
    ln_sig_zx_f = params["ln_sig_zx_f"][rep]
    ln_sig_zy_f = params["ln_sig_zy_f"][rep]
    ln_sig_zc_f = params["ln_sig_zc_f"][rep]
    
    
  
    params_aux = params.copy()

    alpha_x = params["alpha_x"][:, rep]
    alpha_y = params["alpha_y"][:, rep]
    alpha_c = params["alpha_c"][:, rep]
    alpha_x = alpha_x[:,None]
    alpha_y = alpha_y[:,None]
    alpha_c = alpha_c[:,None]
    
    
    params_aux['alpha_x'] = alpha_x
    params_aux['alpha_y'] = alpha_y
    params_aux['alpha_c'] = alpha_c
    
    params_aux["ln_sig_x_h"] = ln_sig_x_h
    params_aux["ln_sig_zx_h"] = ln_sig_zx_h
    params_aux["ln_sig_zy_h"] = ln_sig_zy_h
    params_aux["ln_sig_zc_h"] = ln_sig_zc_h
    params_aux["ln_sig_rx_h"] = ln_sig_rx_h
    params_aux["ln_sig_ry_h"] = ln_sig_ry_h
    

    params_aux["ln_sig_x_f"] = ln_sig_x_f
    params_aux["ln_sig_zx_f"] = ln_sig_zx_f
    params_aux["ln_sig_zy_f"] = ln_sig_zy_f
    params_aux["ln_sig_zc_f"] = ln_sig_zc_f


    return params_aux

# %%
def updateParams_LNC(params, grad_params, smpl, iteration, rep, learning_rate):
     
    #idx_rows = smpl[:, None]
    n = params['alpha_x'].shape[0]
    idx_rows = np.linspace(0, n - 1, n, dtype=int)[:, None]
    idx_cols = np.array(rep)[None, None]
    idx = jax.ops.index[tuple([idx_rows, idx_cols])]
    
    #alpha_x
    A = params['alpha_x'][tuple([idx_rows, idx_cols])]
    B = learning_rate * grad_params['alpha_x']
    params['alpha_x'] = index_update(params['alpha_x'], idx, A - B)
    
    #alpha_y
    A = params['alpha_y'][tuple([idx_rows, idx_cols])]
    B = learning_rate * grad_params['alpha_y']
    params['alpha_y'] = index_update(params['alpha_y'], idx, A - B)
    
    #alpha_c
    A = params['alpha_c'][tuple([idx_rows, idx_cols])]
    B = learning_rate * grad_params['alpha_c']
    params['alpha_c'] = index_update(params['alpha_c'], idx, A - B)
    
    gpars = [grad_params["ln_sig_x_h"],
    grad_params["ln_sig_zx_h"],
    grad_params["ln_sig_zy_h"],
    grad_params["ln_sig_zc_h"],
    grad_params["ln_sig_rx_h"],
    grad_params["ln_sig_ry_h"],
    grad_params["ln_sig_x_f"],
    grad_params["ln_sig_zx_f"],
    grad_params["ln_sig_zy_f"],
    grad_params["ln_sig_zc_f"],
    grad_params["ln_sig_x_h"],
    grad_params["ln_sig_zx_h"],
    grad_params["ln_sig_zy_h"],
    grad_params["ln_sig_zc_h"],
    grad_params["ln_sig_rx_h"],
    grad_params["ln_sig_ry_h"],
    grad_params["ln_sig_x_f"],
    grad_params["ln_sig_zx_f"],
    grad_params["ln_sig_zy_f"],
    grad_params["ln_sig_zc_f"]]
    

    if (onp.sum(onp.isnan(B))!=0) | (onp.sum(onp.isinf(B))!=0) | (onp.sum(onp.isnan(gpars))!=0):
        idx_nan, _ = onp.where(onp.isnan(B))
        print("nans in grad Z, iteration: ", iteration, " rep: ", rep)
        raise ValueError('Nans in gradient.')
            
    
    
    return None

# %%
def getIniMonitor_LNC(epochs, report_freq, reps, parts): 
        num_reports = int(np.ceil(epochs / report_freq))+1 # initial report 
        print("num_reports: ", num_reports)
        monitors = {
            'loss': onp.zeros([num_reports, reps, parts]),
            'hsic_rx_ax': onp.zeros([num_reports, reps, parts]),
            'hsic_ry_ay': onp.zeros([num_reports, reps, parts]),
            'hsic_resids': onp.zeros([num_reports, reps, parts]),
            'hsic_zx_zy': onp.zeros([num_reports, reps, parts]),
            'hsic_zx_zc': onp.zeros([num_reports, reps, parts]),
            'hsic_zy_zc': onp.zeros([num_reports, reps, parts]),
            'hsic_zy_x': onp.zeros([num_reports, reps, parts]),
            'hsic_indep': onp.zeros([num_reports, reps, parts]),
            'mse_rx': onp.zeros([num_reports, reps, parts]),
            'mse_ry': onp.zeros([num_reports, reps, parts]),
            'mses': onp.zeros([num_reports, reps, parts]),
            'hsic_zx': onp.zeros([num_reports, reps, parts]),
            'hsic_zy': onp.zeros([num_reports, reps, parts]),
            'hsic_zc': onp.zeros([num_reports, reps, parts]),
            'imp_zx': onp.zeros([num_reports, reps, parts]),
            'imp_zy': onp.zeros([num_reports, reps, parts]),
            
        }
        return monitors

# %%
def fillMonitor_LNC(params, params_or, pars, loss_as_par, dloss_as_par_jitted, lossData, iteration, report_freq, rep, part, reps, monitors, K_t):
    
    
    _, _, lam, _,_ = pars
          
    
    monitor = model_LNC(params, lam, lossData, K_t)
    print("monitor")
    print(monitor)
    ws = np.ones(params["alpha_x"].shape[0])
    loss_val = loss_as_par(params, pars, lossData,ws)
    indxRep = int(iteration / report_freq) 
    print("indxRep:", indxRep, " iteration: ", iteration, " rep: ", rep, " part: ", part)
    
    monitors['loss'][indxRep, rep, part] = loss_val
    monitors['hsic_rx_ax'][indxRep, rep, part] = monitor['hsic_rx_ax']
    monitors['hsic_ry_ay'][indxRep, rep, part] = monitor['hsic_ry_ay']
    monitors['hsic_resids'][indxRep, rep, part] = monitor['hsic_resids']
    monitors['hsic_zx_zy'][indxRep, rep, part] = monitor['hsic_zx_zy']
    monitors['hsic_zx_zc'][indxRep, rep, part] = monitor['hsic_zx_zc']
    monitors['hsic_zy_zc'][indxRep, rep, part] = monitor['hsic_zy_zc']
    monitors['hsic_zy_x'][indxRep, rep, part] = monitor['hsic_zy_x']
    monitors['hsic_indep'][indxRep, rep, part] = monitor['hsic_indep']
    monitors['mse_rx'][indxRep, rep, part] = monitor['mse_rx']
    monitors['mse_ry'][indxRep, rep, part] = monitor['mse_ry']
    monitors['mses'][indxRep, rep, part] = monitor['mses']
    monitors['hsic_zx'][indxRep, rep, part] = monitor['hsic_zx']
    monitors['hsic_zy'][indxRep, rep, part] = monitor['hsic_zy']
    monitors['hsic_zc'][indxRep, rep, part] = monitor['hsic_zc']
    monitors['imp_zx'][indxRep, rep, part] = monitor['imp_zx']
    monitors['imp_zy'][indxRep, rep, part] = monitor['imp_zy']
    
                    
                    
    return monitors

# %%
def getLatentZ_LNC(params, loss_as_par, dloss_as_par_jitted, loss_data, pars, epochs, report_freq, reps, batch_size, batch_per_epoch, learning_rate, smplsParts, monitors, batches, batches2, K_t):
    N = params["alpha_x"].shape[0]
         
    print("report_freq: ", report_freq)
    parts = len(smplsParts)
    
    ms = onp.zeros([N, epochs+1, reps])
    vs = onp.zeros([N, epochs+1, reps])
    epochs2 = int(onp.floor(epochs/batch_per_epoch))
    loss_vals = onp.ones([epochs+1, reps])*onp.Inf
    loss_vals_epoch = onp.ones([epochs2, reps])*onp.Inf
    
    
    lrs = learning_rate*onp.ones(reps)
    adamOpt = False
    


    for iteration in range(epochs+1):
      
        # print("*********************")
        if (iteration % 50 == 0):
            print("iteration: ", iteration)
        #print("nans: ", onp.sum(onp.isnan(onp.array(params["Z"]))))

        epoch = (iteration-1) // batch_per_epoch
        batch = (iteration-1) % batch_per_epoch
        
        #epoch = bisect.bisect_left(cumbatches_per_epoch, iteration)-1
        #batch = iteration -cumbatches_per_epoch[epoch]-1
        
        #print("iteration: ", iteration)
        #print("epoch: ", epoch)
        #print("batch: ", batch)

        


        # get the gradient of the loss
        for rep in range(reps):
            #print("rep: ", rep)


            if(iteration == 0):
                smpl = onp.random.randint(low=0, high=N, size=batch_size)
                smpl2 = onp.random.randint(low=0, high=N, size=batch_size*2)
            else:
                #print(np.unique(np.hstack(batches[rep][epoch])).shape)
                #print(np.unique(np.hstack(batches2[rep][epoch])).shape)
                smpl = batches[rep][epoch][batch]
                smpl2 = batches2[rep][epoch][batch]
                

            #print("len smpl: ", len(smpl))
            #print("len smpl 2: ", len(smpl2))
             

            if iteration == 5:
                print("smpl: ", smpl[0:4])
            
            #smpl2 = onp.random.randint(low=0, high=N, size=batch_size)
            
            #smpl3 = onp.linspace(0,n-1,n, dtype=int)
            # sampling without replacemnt
            #smpl = onp.random.choice(a=n, size=batch_size, replace=False)

  
            loss_data_aux = getDataLoss_LNC(smpl, loss_data)
            loss_data_aux2 = getDataLoss_LNC(smpl2, loss_data)

  
            # equal weights
            ws = np.ones(batch_size)
            

            # algorithmic independence forcing

            # random weights - so that E[y|x] alg indep of p(x)
            #ws = getWeightsAlgoIndep(loss_data, batch_size, smpl)
            #print("ws: ", ws[0:5])

            
            # prepare parameters for grad calculation (subsample)
            
            #params_aux = getParamsForGrad(params, rep, optType, smpl)
            params_aux = getParamsForGrad_LNC(params, rep, smpl)
            params_aux2 = getParamsForGrad_LNC(params, rep, smpl2)
            #params_aux3 = getParamsForGrad(params, rep, smpl3)
           
            
             
            if adamOpt:
                grad_params = grad(loss_as_par, argnums=0)(params_aux, pars, loss_data_aux, ws)
                if iteration > 0:
                    m = ms[smpl,iteration-1,rep][:,None]
                    v = vs[smpl,iteration-1,rep][:,None]
                    m, v = updateParamsAdam2_LNC(params, grad_params, smpl, iteration, rep, lrs[rep], iteration-1, m, v)
                    ms[smpl,iteration,rep] = m[:,0]
                    vs[smpl,iteration,rep] = v[:,0]
            

            else:
                grad_params = dloss_as_par_jitted(params_aux, pars, loss_data_aux, ws)
                if iteration > 0:
                    updateParams_LNC(params, grad_params, smpl, iteration, rep, lrs[rep])

            ws = np.ones(batch_size*2)
            loss_vals[iteration, rep] = loss_as_par(params_aux2, pars, loss_data_aux2, ws)
            	

 
            if (iteration % report_freq == 0):# & (iteration != 0):
                #print("report")
                print("iteration report: ", iteration)
                
                for part in range(parts):
                    
                    smplPart = smplsParts[part]
                    params_part = getParamsForGrad_LNC(params, rep, smplPart)
                    #params_part = getParamsSmpl(params, smplPart)
                    loss_data_part = getDataLoss_LNC(smplPart, loss_data)
                    monitors = fillMonitor_LNC(params_part, params, pars, loss_as_par, dloss_as_par_jitted, loss_data_part, iteration, report_freq, rep, part, reps, monitors, K_t)
                               

                    #nPerPart = smplPart.shape[0]
                    #ws = np.ones(nPerPart)
                    #loss_val = loss_as_par(params_part, pars, loss_data_part, ws)
         
                              
                  
   
    return params, monitors #, resids, bestResids, bestZ

# %%
def getLatentZ_wrapper(x, y, Z, U, nm, pars, num_epochs, report_freq, num_reps, batch_size, learning_rate, job):
    print("nm:", nm)
    N = x.shape[0]
    

    D_x = covariance_matrix(sqeuclidean_distance, x, x)
    sigma_x_med = 1 / np.median(D_x)
    K_x = rbf_kernel_matrix({'gamma': sigma_x_med}, x, x)

    D_y = covariance_matrix(sqeuclidean_distance, y, y)
    sigma_y = 1 / np.median(D_y)
    K_y = rbf_kernel_matrix({'gamma': sigma_y}, y, y)
    
    D_u = covariance_matrix(sqeuclidean_distance, U, U)
    sigma_u = 1 / np.median(D_u)
    K_u = rbf_kernel_matrix({'gamma': sigma_u}, U, U)
    
    
    onp.random.seed(seed=job)
    
    maxMonitor = 1000
    parts = int(onp.ceil(N/maxMonitor))
    smplsParts = onp.random.choice(parts, size=N)
    

    smplsParts = [myWhere(smplsParts==i) for i in range(parts)]

    lossData = x, y, Z, K_u, D_x, K_y, D_y, K_x 
    
    

    onp.random.seed(seed=job+3)
    params = getIniPar_LNC(num_reps, lossData, pars, smplsParts)
    print("alpha x shape: ",params["alpha_x"].shape)
    
    res = []
    


    onp.random.seed(seed=job+123)
    batch_per_epoch = int(onp.ceil(N / batch_size))
    epochs2 = int(onp.ceil(num_epochs / batch_per_epoch))
    num_iters = int(epochs2*batch_per_epoch)
    batches = [[get_batches_one_epoch(batch_per_epoch, batch_size, N) for i in range(epochs2)] for j in range(num_reps)]
    #batches2 = [[get_batches_one_epoch(batch_per_epoch, batch_size, N) for i in range(epochs2)] for j in range(num_reps)]
    batches2 = [[ [onp.random.randint(low=0, high=N, size=batch_size*2) for k in range(batch_per_epoch)] for i in range(epochs2)] for j in range(num_reps)]
    print("N: ", N)
    print("batch size: ", batch_size)
    print("batch per_epoch: ", batch_per_epoch)
    print("epochs2: ", epochs2)
    print("epochs eff: ", len(batches[0]))
    print("num_iters: ", num_iters)

    report_freq2 = num_iters // 1

    path = getIniMonitor_LNC(num_iters, report_freq, num_reps, parts)
    


    loss_as_par = loss_LNC
    dloss_as_par_jitted = dloss_LNC_jitted
    

        
        
    start = time.process_time()
    params, path = getLatentZ_LNC(params, loss_as_par, dloss_as_par_jitted, loss_data=lossData, pars=pars,epochs=num_iters, report_freq=report_freq,
                                                         reps=num_reps, batch_size=batch_size, batch_per_epoch=batch_per_epoch, learning_rate=learning_rate, smplsParts=smplsParts, monitors=path, batches=batches, batches2=batches2, K_t=None)
    res.append(path)
    
    res = {k: onp.concatenate([r[k] for r in res], axis=0) for k in res[0].keys()}
    

    print("results")
    res = {"params": params, "path": res}
    print(res["path"])
    

    return resqe

# %% [markdown]
# ## optimize for hyperparameter choice

# %%
# beta: np.ndarray, neta: np.ndarray,  lam: np.ndarray, lu: np.ndarray
beta = np.array(0.1) # mse
neta = np.array(1.0) # indep zs
lam = np.array(0.001) # krr
nu = np.array(1.0) # z norm
lu = np.array(0.0) # CI indep
pars = (beta, neta, lam, nu, lu)

# %%
# epchs:int, bs:int, reps:int, lr: float, job:int
num_epochs = 100
report_freq = 10#num_epochs
num_reps = 7
batch_size = 100
learning_rate = 0.01
job = 1

# %%
# read file
import pandas as pd
folder = "/home/emiliano/Documents/ISP/postdoc/discoveringLatentConfounders/data/data_to_try/13:45:44_14092023/"
file = "5_exponential1gaussian1_dependent_10_1_100.csv"
# Out:
# 2023-09-18 14:01:20,457:INFO:NumExpr defaulting to 8 threads.

# %%
data = pd.read_csv(folder+file, skiprows=17)

# %%
data.head()
# Out:
#    Unnamed: 0       Z.1       Z.2       Z.3       Z.4       Z.5       Z.6  \
# 0           1 -4.257510 -2.628083  1.532396  2.106480  2.555447  0.548185
# 1           2 -6.186321  2.158373  4.087255  5.089037 -1.557615  0.354011
# 2           3  0.922623  2.829448 -3.500332  0.164894  2.403200  2.056119
# 3           4 -0.198229 -0.518078  2.199180 -3.302215 -4.793345  0.072418
# 4           5  5.846498  0.385424 -3.343436 -0.239071  4.617033  4.394828
#
#         Z.7       Z.8       Z.9  ...       U.93      U.94       U.95  \
# 0 -0.873037 -2.582866  1.201632  ...   2.943411  3.433972 -12.059140
# 1 -0.410917  1.112464  3.247618  ...  11.557239  6.252577  -4.917907
# 2  2.282143  2.957012 -3.086380  ...  -2.903270  2.379708  -3.457482
# 3 -2.818797  0.556005 -1.828017  ...  -4.262228 -2.821497   6.181105
# 4  5.976737  1.227569 -1.022016  ...  -8.295679 -8.060914   3.325531
#
#         U.96       U.97       U.98       U.99     U.100         X          Y
# 0  -1.084468 -10.062209   2.632646  -2.679277 -6.939442  2.196186  -6.230360
# 1  -7.701617  -0.418536  -5.409675  -6.676294  4.506038 -0.358376  -8.280630
# 2  24.731770  11.718584  -7.371640  15.737050 -0.989652  2.461117   0.630075
# 3  -9.139552  -6.957557 -11.686181   8.437655  0.999168  3.134817  -3.971889
# 4  24.612512  13.523935  13.928673   5.056496  4.155581  0.975887  10.689424
#
# [5 rows x 113 columns]

# %%
data.columns[10]
# Out:
# 'Z.10'

# %%
data.shape
# Out:
# (1000, 113)

# %%
zcols = ["Z."+str(i) for i in range(1,11)]
ucols = ["U."+str(i) for i in range(1,101)]

# %%
# X = np.array(norml_mat(X))
x= np.array(data["X"])[:,None]
y= np.array(data["Y"])[:,None]
Z= np.array(data[zcols])
U= np.array(data[ucols])

# %%
embedding = Isomap(n_components=10)
xy = onp.hstack([x, y])
xy_transformed = embedding.fit_transform(xy)
zc_ini = np.array(xy_transformed[:,3])[:,None]

# %%
hsicRBF(x, y)
# Out:
# DeviceArray(0.011, dtype=float32)

# %%
hsicRBF(zc_ini, y)
# Out:
# DeviceArray(0.135, dtype=float32)

# %%
hsicRBF(zc_ini, x)
# Out:
# DeviceArray(0.072, dtype=float32)

# %%
y.shape
# Out:
# (1000, 1)

# %%
# ix c(8, 2, 3)
# iy c(1, 7, 6)
# ic 10
Z[:,[7,1,2]]
# Out:
# DeviceArray([[-2.583, -2.628,  1.532],
#              [ 1.112,  2.158,  4.087],
#              [ 2.957,  2.829, -3.5  ],
#              ...,
#              [ 2.101,  0.742, -0.046],
#              [-1.906,  0.307, -0.398],
#              [-2.585, -1.338,  3.065]], dtype=float32)

# %%
nm = "test"

# %%
res = getLatentZ_wrapper(x, y, Z, U, nm, pars, num_epochs, report_freq, num_reps, batch_size, learning_rate, job)
# Out:
# nm: test
# alpha x shape:  (1000, 7)
# N:  1000
# batch size:  100
# batch per_epoch:  10
# epochs2:  50
# epochs eff:  50
# num_iters:  500
# num_reports:  51
# report_freq:  10
# iteration:  0
# iteration report:  0
# monitor
# {'hsic_indep': DeviceArray(-14.458, dtype=float32), 'hsic_resids': DeviceArray(-4.825, dtype=float32), 'hsic_rx_ax': DeviceArray(0.074, dtype=float32), 'hsic_ry_ay': DeviceArray(0.109, dtype=float32), 'hsic_zc': DeviceArray(0.087, dtype=float32), 'hsic_zx': DeviceArray(0.144, dtype=float32), 'hsic_zx_zc': DeviceArray(0.042, dtype=float32), 'hsic_zx_zy': DeviceArray(0.016, dtype=float32), 'hsic_zy': DeviceArray(0.186, dtype=float32), 'hsic_zy_x': DeviceArray(0.009, dtype=float32), 'hsic_zy_zc': DeviceArray(0.088, dtype=float32), 'mse_rx': DeviceArray(0.298, dtype=float32), 'mse_ry': DeviceArray(0.173, dtype=float32), 'mses': DeviceArray(-2.965, dtype=float32)}
# indxRep: 0  iteration:  0  rep:  0  part:  0
# iteration report:  0
# monitor
# {'hsic_indep': DeviceArray(-14.148, dtype=float32), 'hsic_resids': DeviceArray(-6.166, dtype=float32), 'hsic_rx_ax': DeviceArray(0.03, dtype=float32), 'hsic_ry_ay': DeviceArray(0.069, dtype=float32), 'hsic_zc': DeviceArray(0.143, dtype=float32), 'hsic_zx': DeviceArray(0.258, dtype=float32), 'hsic_zx_zc': DeviceArray(0.063, dtype=float32), 'hsic_zx_zy': DeviceArray(0.009, dtype=float32), 'hsic_zy': DeviceArray(0.34, dtype=float32), 'hsic_zy_x': DeviceArray(0.009, dtype=float32), 'hsic_zy_zc': DeviceArray(0.15, dtype=float32), 'mse_rx': DeviceArray(0.458, dtype=float32), 'mse_ry': DeviceArray(0.473, dtype=float32), 'mses': DeviceArray(-1.528, dtype=float32)}
# indxRep: 0  iteration:  0  rep:  1  part:  0
# iteration report:  0
# monitor
# {'hsic_indep': DeviceArray(-13.758, dtype=float32), 'hsic_resids': DeviceArray(-6.617, dtype=float32), 'hsic_rx_ax': DeviceArray(0.025, dtype=float32), 'hsic_ry_ay': DeviceArray(0.054, dtype=float32), 'hsic_zc': DeviceArray(0.172, dtype=float32), 'hsic_zx': DeviceArray(0.343, dtype=float32), 'hsic_zx_zc': DeviceArray(0.076, dtype=float32), 'hsic_zx_zy': DeviceArray(0.009, dtype=float32), 'hsic_zy': DeviceArray(0.443, dtype=float32), 'hsic_zy_x': DeviceArray(0.009, dtype=float32), 'hsic_zy_zc': DeviceArray(0.159, dtype=float32), 'mse_rx': DeviceArray(0.487, dtype=float32), 'mse_ry': DeviceArray(0.566, dtype=float32), 'mses': DeviceArray(-1.289, dtype=float32)}
# indxRep: 0  iteration:  0  rep:  2  part:  0
# iteration report:  0
# monitor
# {'hsic_indep': DeviceArray(-13.742, dtype=float32), 'hsic_resids': DeviceArray(-7.01, dtype=float32), 'hsic_rx_ax': DeviceArray(0.023, dtype=float32), 'hsic_ry_ay': DeviceArray(0.039, dtype=float32), 'hsic_zc': DeviceArray(0.188, dtype=float32), 'hsic_zx': DeviceArray(0.398, dtype=float32), 'hsic_zx_zc': DeviceArray(0.071, dtype=float32), 'hsic_zx_zy': DeviceArray(0.012, dtype=float32), 'hsic_zy': DeviceArray(0.5, dtype=float32), 'hsic_zy_x': DeviceArray(0.01, dtype=float32), 'hsic_zy_zc': DeviceArray(0.136, dtype=float32), 'mse_rx': DeviceArray(0.495, dtype=float32), 'mse_ry': DeviceArray(0.603, dtype=float32), 'mses': DeviceArray(-1.21, dtype=float32)}
# indxRep: 0  iteration:  0  rep:  3  part:  0
# iteration report:  0
# monitor
# {'hsic_indep': DeviceArray(-14.564, dtype=float32), 'hsic_resids': DeviceArray(-7.695, dtype=float32), 'hsic_rx_ax': DeviceArray(0.019, dtype=float32), 'hsic_ry_ay': DeviceArray(0.024, dtype=float32), 'hsic_zc': DeviceArray(0.193, dtype=float32), 'hsic_zx': DeviceArray(0.421, dtype=float32), 'hsic_zx_zc': DeviceArray(0.045, dtype=float32), 'hsic_zx_zy': DeviceArray(0.013, dtype=float32), 'hsic_zy': DeviceArray(0.51, dtype=float32), 'hsic_zy_x': DeviceArray(0.009, dtype=float32), 'hsic_zy_zc': DeviceArray(0.085, dtype=float32), 'mse_rx': DeviceArray(0.5, dtype=float32), 'mse_ry': DeviceArray(0.632, dtype=float32), 'mses': DeviceArray(-1.152, dtype=float32)}
# indxRep: 0  iteration:  0  rep:  4  part:  0
# iteration report:  0
# monitor
# {'hsic_indep': DeviceArray(-16.413, dtype=float32), 'hsic_resids': DeviceArray(-8.506, dtype=float32), 'hsic_rx_ax': DeviceArray(0.012, dtype=float32), 'hsic_ry_ay': DeviceArray(0.016, dtype=float32), 'hsic_zc': DeviceArray(0.185, dtype=float32), 'hsic_zx': DeviceArray(0.41, dtype=float32), 'hsic_zx_zc': DeviceArray(0.018, dtype=float32), 'hsic_zx_zy': DeviceArray(0.013, dtype=float32), 'hsic_zy': DeviceArray(0.48, dtype=float32), 'hsic_zy_x': DeviceArray(0.008, dtype=float32), 'hsic_zy_zc': DeviceArray(0.038, dtype=float32), 'mse_rx': DeviceArray(0.503, dtype=float32), 'mse_ry': DeviceArray(0.649, dtype=float32), 'mses': DeviceArray(-1.119, dtype=float32)}
# indxRep: 0  iteration:  0  rep:  5  part:  0
# iteration report:  0
# monitor
# {'hsic_indep': DeviceArray(-21.014, dtype=float32), 'hsic_resids': DeviceArray(-9.298, dtype=float32), 'hsic_rx_ax': DeviceArray(0.009, dtype=float32), 'hsic_ry_ay': DeviceArray(0.011, dtype=float32), 'hsic_zc': DeviceArray(0.167, dtype=float32), 'hsic_zx': DeviceArray(0.385, dtype=float32), 'hsic_zx_zc': DeviceArray(0.002, dtype=float32), 'hsic_zx_zy': DeviceArray(0.012, dtype=float32), 'hsic_zy': DeviceArray(0.435, dtype=float32), 'hsic_zy_x': DeviceArray(0.007, dtype=float32), 'hsic_zy_zc': DeviceArray(0.006, dtype=float32), 'mse_rx': DeviceArray(0.505, dtype=float32), 'mse_ry': DeviceArray(0.663, dtype=float32), 'mses': DeviceArray(-1.093, dtype=float32)}
# indxRep: 0  iteration:  0  rep:  6  part:  0
# /home/emiliano/anaconda3/lib/python3.7/site-packages/jax/lax/lax.py:5946: UserWarning: Explicitly requested dtype <class 'int'> requested in linspace is not available, and will be truncated to dtype int32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   warnings.warn(msg.format(dtype, fun_name , truncated_dtype))
# smpl:  [26 48 59 63]
# smpl:  [ 4  5 26 29]
# smpl:  [ 8 11 14 24]
# smpl:  [ 3  4 29 52]
# smpl:  [1 2 3 9]
# smpl:  [ 1  5 31 35]
# smpl:  [ 4  8 25 26]
# iteration report:  10
# monitor
# {'hsic_indep': DeviceArray(-16.424, dtype=float32), 'hsic_resids': DeviceArray(-6.045, dtype=float32), 'hsic_rx_ax': DeviceArray(0.071, dtype=float32), 'hsic_ry_ay': DeviceArray(0.033, dtype=float32), 'hsic_zc': DeviceArray(0.011, dtype=float32), 'hsic_zx': DeviceArray(0.125, dtype=float32), 'hsic_zx_zc': DeviceArray(0.022, dtype=float32), 'hsic_zx_zy': DeviceArray(0.017, dtype=float32), 'hsic_zy': DeviceArray(0.185, dtype=float32), 'hsic_zy_x': DeviceArray(0.008, dtype=float32), 'hsic_zy_zc': DeviceArray(0.023, dtype=float32), 'mse_rx': DeviceArray(0.285, dtype=float32), 'mse_ry': DeviceArray(0.036, dtype=float32), 'mses': DeviceArray(-4.585, dtype=float32)}
# indxRep: 1  iteration:  10  rep:  0  part:  0
# iteration report:  10
# monitor
# {'hsic_indep': DeviceArray(-16.638, dtype=float32), 'hsic_resids': DeviceArray(-6.089, dtype=float32), 'hsic_rx_ax': DeviceArray(0.031, dtype=float32), 'hsic_ry_ay': DeviceArray(0.072, dtype=float32), 'hsic_zc': DeviceArray(0.062, dtype=float32), 'hsic_zx': DeviceArray(0.264, dtype=float32), 'hsic_zx_zc': DeviceArray(0.03, dtype=float32), 'hsic_zx_zy': DeviceArray(0.008, dtype=float32), 'hsic_zy': DeviceArray(0.338, dtype=float32), 'hsic_zy_x': DeviceArray(0.007, dtype=float32), 'hsic_zy_zc': DeviceArray(0.036, dtype=float32), 'mse_rx': DeviceArray(0.468, dtype=float32), 'mse_ry': DeviceArray(0.434, dtype=float32), 'mses': DeviceArray(-1.594, dtype=float32)}
# indxRep: 1  iteration:  10  rep:  1  part:  0
# iteration report:  10
# monitor
# {'hsic_indep': DeviceArray(-16.484, dtype=float32), 'hsic_resids': DeviceArray(-6.669, dtype=float32), 'hsic_rx_ax': DeviceArray(0.022, dtype=float32), 'hsic_ry_ay': DeviceArray(0.057, dtype=float32), 'hsic_zc': DeviceArray(0.185, dtype=float32), 'hsic_zx': DeviceArray(0.345, dtype=float32), 'hsic_zx_zc': DeviceArray(0.037, dtype=float32), 'hsic_zx_zy': DeviceArray(0.003, dtype=float32), 'hsic_zy': DeviceArray(0.457, dtype=float32), 'hsic_zy_x': DeviceArray(0.006, dtype=float32), 'hsic_zy_zc': DeviceArray(0.091, dtype=float32), 'mse_rx': DeviceArray(0.533, dtype=float32), 'mse_ry': DeviceArray(0.555, dtype=float32), 'mses': DeviceArray(-1.217, dtype=float32)}
# indxRep: 1  iteration:  10  rep:  2  part:  0
# iteration report:  10
# monitor
# {'hsic_indep': DeviceArray(-17.423, dtype=float32), 'hsic_resids': DeviceArray(-6.463, dtype=float32), 'hsic_rx_ax': DeviceArray(0.03, dtype=float32), 'hsic_ry_ay': DeviceArray(0.052, dtype=float32), 'hsic_zc': DeviceArray(0.09, dtype=float32), 'hsic_zx': DeviceArray(0.386, dtype=float32), 'hsic_zx_zc': DeviceArray(0.067, dtype=float32), 'hsic_zx_zy': DeviceArray(0.001, dtype=float32), 'hsic_zy': DeviceArray(0.523, dtype=float32), 'hsic_zy_x': DeviceArray(0.004, dtype=float32), 'hsic_zy_zc': DeviceArray(0.122, dtype=float32), 'mse_rx': DeviceArray(0.569, dtype=float32), 'mse_ry': DeviceArray(0.612, dtype=float32), 'mses': DeviceArray(-1.055, dtype=float32)}
# indxRep: 1  iteration:  10  rep:  3  part:  0
# iteration report:  10
# monitor
# {'hsic_indep': DeviceArray(-18.376, dtype=float32), 'hsic_resids': DeviceArray(-7.255, dtype=float32), 'hsic_rx_ax': DeviceArray(0.021, dtype=float32), 'hsic_ry_ay': DeviceArray(0.033, dtype=float32), 'hsic_zc': DeviceArray(0.012, dtype=float32), 'hsic_zx': DeviceArray(0.397, dtype=float32), 'hsic_zx_zc': DeviceArray(0.027, dtype=float32), 'hsic_zx_zy': DeviceArray(0.004, dtype=float32), 'hsic_zy': DeviceArray(0.524, dtype=float32), 'hsic_zy_x': DeviceArray(0.003, dtype=float32), 'hsic_zy_zc': DeviceArray(0.03, dtype=float32), 'mse_rx': DeviceArray(0.702, dtype=float32), 'mse_ry': DeviceArray(0.648, dtype=float32), 'mses': DeviceArray(-0.787, dtype=float32)}
# indxRep: 1  iteration:  10  rep:  4  part:  0
# iteration report:  10
# monitor
# {'hsic_indep': DeviceArray(-18.083, dtype=float32), 'hsic_resids': DeviceArray(-8.278, dtype=float32), 'hsic_rx_ax': DeviceArray(0.013, dtype=float32), 'hsic_ry_ay': DeviceArray(0.019, dtype=float32), 'hsic_zc': DeviceArray(0.025, dtype=float32), 'hsic_zx': DeviceArray(0.386, dtype=float32), 'hsic_zx_zc': DeviceArray(0.089, dtype=float32), 'hsic_zx_zy': DeviceArray(0.008, dtype=float32), 'hsic_zy': DeviceArray(0.497, dtype=float32), 'hsic_zy_x': DeviceArray(0.002, dtype=float32), 'hsic_zy_zc': DeviceArray(0.011, dtype=float32), 'mse_rx': DeviceArray(0.71, dtype=float32), 'mse_ry': DeviceArray(0.663, dtype=float32), 'mses': DeviceArray(-0.754, dtype=float32)}
# indxRep: 1  iteration:  10  rep:  5  part:  0
# iteration report:  10
# monitor
# {'hsic_indep': DeviceArray(-19.824, dtype=float32), 'hsic_resids': DeviceArray(-10.743, dtype=float32), 'hsic_rx_ax': DeviceArray(0.003, dtype=float32), 'hsic_ry_ay': DeviceArray(0.006, dtype=float32), 'hsic_zc': DeviceArray(0.162, dtype=float32), 'hsic_zx': DeviceArray(0.326, dtype=float32), 'hsic_zx_zc': DeviceArray(0.004, dtype=float32), 'hsic_zx_zy': DeviceArray(0.059, dtype=float32), 'hsic_zy': DeviceArray(0.451, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.01, dtype=float32), 'mse_rx': DeviceArray(1.219, dtype=float32), 'mse_ry': DeviceArray(0.683, dtype=float32), 'mses': DeviceArray(-0.182, dtype=float32)}
# indxRep: 1  iteration:  10  rep:  6  part:  0
# iteration report:  20
# monitor
# {'hsic_indep': DeviceArray(-16.525, dtype=float32), 'hsic_resids': DeviceArray(-5.842, dtype=float32), 'hsic_rx_ax': DeviceArray(0.069, dtype=float32), 'hsic_ry_ay': DeviceArray(0.042, dtype=float32), 'hsic_zc': DeviceArray(0.012, dtype=float32), 'hsic_zx': DeviceArray(0.136, dtype=float32), 'hsic_zx_zc': DeviceArray(0.02, dtype=float32), 'hsic_zx_zy': DeviceArray(0.016, dtype=float32), 'hsic_zy': DeviceArray(0.184, dtype=float32), 'hsic_zy_x': DeviceArray(0.008, dtype=float32), 'hsic_zy_zc': DeviceArray(0.025, dtype=float32), 'mse_rx': DeviceArray(0.259, dtype=float32), 'mse_ry': DeviceArray(0.032, dtype=float32), 'mses': DeviceArray(-4.799, dtype=float32)}
# indxRep: 2  iteration:  20  rep:  0  part:  0
# iteration report:  20
# monitor
# {'hsic_indep': DeviceArray(-19.455, dtype=float32), 'hsic_resids': DeviceArray(-6.412, dtype=float32), 'hsic_rx_ax': DeviceArray(0.026, dtype=float32), 'hsic_ry_ay': DeviceArray(0.063, dtype=float32), 'hsic_zc': DeviceArray(0.022, dtype=float32), 'hsic_zx': DeviceArray(0.255, dtype=float32), 'hsic_zx_zc': DeviceArray(0.01, dtype=float32), 'hsic_zx_zy': DeviceArray(0.005, dtype=float32), 'hsic_zy': DeviceArray(0.334, dtype=float32), 'hsic_zy_x': DeviceArray(0.006, dtype=float32), 'hsic_zy_zc': DeviceArray(0.012, dtype=float32), 'mse_rx': DeviceArray(0.508, dtype=float32), 'mse_ry': DeviceArray(0.395, dtype=float32), 'mses': DeviceArray(-1.606, dtype=float32)}
# indxRep: 2  iteration:  20  rep:  1  part:  0
# iteration report:  20
# monitor
# {'hsic_indep': DeviceArray(-21.36, dtype=float32), 'hsic_resids': DeviceArray(-7.222, dtype=float32), 'hsic_rx_ax': DeviceArray(0.018, dtype=float32), 'hsic_ry_ay': DeviceArray(0.041, dtype=float32), 'hsic_zc': DeviceArray(0.054, dtype=float32), 'hsic_zx': DeviceArray(0.355, dtype=float32), 'hsic_zx_zc': DeviceArray(0.007, dtype=float32), 'hsic_zx_zy': DeviceArray(0.002, dtype=float32), 'hsic_zy': DeviceArray(0.476, dtype=float32), 'hsic_zy_x': DeviceArray(0.003, dtype=float32), 'hsic_zy_zc': DeviceArray(0.014, dtype=float32), 'mse_rx': DeviceArray(0.527, dtype=float32), 'mse_ry': DeviceArray(0.565, dtype=float32), 'mses': DeviceArray(-1.211, dtype=float32)}
# indxRep: 2  iteration:  20  rep:  2  part:  0
# iteration report:  20
# monitor
# {'hsic_indep': DeviceArray(-20.461, dtype=float32), 'hsic_resids': DeviceArray(-6.171, dtype=float32), 'hsic_rx_ax': DeviceArray(0.043, dtype=float32), 'hsic_ry_ay': DeviceArray(0.048, dtype=float32), 'hsic_zc': DeviceArray(0.014, dtype=float32), 'hsic_zx': DeviceArray(0.398, dtype=float32), 'hsic_zx_zc': DeviceArray(0.026, dtype=float32), 'hsic_zx_zy': DeviceArray(0.002, dtype=float32), 'hsic_zy': DeviceArray(0.526, dtype=float32), 'hsic_zy_x': DeviceArray(0.002, dtype=float32), 'hsic_zy_zc': DeviceArray(0.013, dtype=float32), 'mse_rx': DeviceArray(0.531, dtype=float32), 'mse_ry': DeviceArray(0.629, dtype=float32), 'mses': DeviceArray(-1.097, dtype=float32)}
# indxRep: 2  iteration:  20  rep:  3  part:  0
# iteration report:  20
# monitor
# {'hsic_indep': DeviceArray(-22.392, dtype=float32), 'hsic_resids': DeviceArray(-7.265, dtype=float32), 'hsic_rx_ax': DeviceArray(0.027, dtype=float32), 'hsic_ry_ay': DeviceArray(0.026, dtype=float32), 'hsic_zc': DeviceArray(0.013, dtype=float32), 'hsic_zx': DeviceArray(0.407, dtype=float32), 'hsic_zx_zc': DeviceArray(0.005, dtype=float32), 'hsic_zx_zy': DeviceArray(0.004, dtype=float32), 'hsic_zy': DeviceArray(0.529, dtype=float32), 'hsic_zy_x': DeviceArray(0.002, dtype=float32), 'hsic_zy_zc': DeviceArray(0.005, dtype=float32), 'mse_rx': DeviceArray(0.672, dtype=float32), 'mse_ry': DeviceArray(0.668, dtype=float32), 'mses': DeviceArray(-0.801, dtype=float32)}
# indxRep: 2  iteration:  20  rep:  4  part:  0
# iteration report:  20
# monitor
# {'hsic_indep': DeviceArray(-18.434, dtype=float32), 'hsic_resids': DeviceArray(-9.174, dtype=float32), 'hsic_rx_ax': DeviceArray(0.007, dtype=float32), 'hsic_ry_ay': DeviceArray(0.015, dtype=float32), 'hsic_zc': DeviceArray(0.053, dtype=float32), 'hsic_zx': DeviceArray(0.407, dtype=float32), 'hsic_zx_zc': DeviceArray(0.012, dtype=float32), 'hsic_zx_zy': DeviceArray(0.003, dtype=float32), 'hsic_zy': DeviceArray(0.493, dtype=float32), 'hsic_zy_x': DeviceArray(0.003, dtype=float32), 'hsic_zy_zc': DeviceArray(0.089, dtype=float32), 'mse_rx': DeviceArray(0.575, dtype=float32), 'mse_ry': DeviceArray(0.65, dtype=float32), 'mses': DeviceArray(-0.985, dtype=float32)}
# indxRep: 2  iteration:  20  rep:  5  part:  0
# iteration report:  20
# monitor
# {'hsic_indep': DeviceArray(-16.575, dtype=float32), 'hsic_resids': DeviceArray(-9.908, dtype=float32), 'hsic_rx_ax': DeviceArray(0.007, dtype=float32), 'hsic_ry_ay': DeviceArray(0.008, dtype=float32), 'hsic_zc': DeviceArray(0.156, dtype=float32), 'hsic_zx': DeviceArray(0.384, dtype=float32), 'hsic_zx_zc': DeviceArray(0.017, dtype=float32), 'hsic_zx_zy': DeviceArray(0.036, dtype=float32), 'hsic_zy': DeviceArray(0.429, dtype=float32), 'hsic_zy_x': DeviceArray(0.006, dtype=float32), 'hsic_zy_zc': DeviceArray(0.017, dtype=float32), 'mse_rx': DeviceArray(0.705, dtype=float32), 'mse_ry': DeviceArray(0.701, dtype=float32), 'mses': DeviceArray(-0.704, dtype=float32)}
# indxRep: 2  iteration:  20  rep:  6  part:  0
# iteration report:  30
# monitor
# {'hsic_indep': DeviceArray(-16.607, dtype=float32), 'hsic_resids': DeviceArray(-5.699, dtype=float32), 'hsic_rx_ax': DeviceArray(0.07, dtype=float32), 'hsic_ry_ay': DeviceArray(0.048, dtype=float32), 'hsic_zc': DeviceArray(0.012, dtype=float32), 'hsic_zx': DeviceArray(0.129, dtype=float32), 'hsic_zx_zc': DeviceArray(0.02, dtype=float32), 'hsic_zx_zy': DeviceArray(0.015, dtype=float32), 'hsic_zy': DeviceArray(0.187, dtype=float32), 'hsic_zy_x': DeviceArray(0.008, dtype=float32), 'hsic_zy_zc': DeviceArray(0.025, dtype=float32), 'mse_rx': DeviceArray(0.272, dtype=float32), 'mse_ry': DeviceArray(0.035, dtype=float32), 'mses': DeviceArray(-4.649, dtype=float32)}
# indxRep: 3  iteration:  30  rep:  0  part:  0
# iteration report:  30
# monitor
# {'hsic_indep': DeviceArray(-20.049, dtype=float32), 'hsic_resids': DeviceArray(-6.566, dtype=float32), 'hsic_rx_ax': DeviceArray(0.023, dtype=float32), 'hsic_ry_ay': DeviceArray(0.061, dtype=float32), 'hsic_zc': DeviceArray(0.022, dtype=float32), 'hsic_zx': DeviceArray(0.251, dtype=float32), 'hsic_zx_zc': DeviceArray(0.008, dtype=float32), 'hsic_zx_zy': DeviceArray(0.005, dtype=float32), 'hsic_zy': DeviceArray(0.335, dtype=float32), 'hsic_zy_x': DeviceArray(0.005, dtype=float32), 'hsic_zy_zc': DeviceArray(0.009, dtype=float32), 'mse_rx': DeviceArray(0.547, dtype=float32), 'mse_ry': DeviceArray(0.382, dtype=float32), 'mses': DeviceArray(-1.565, dtype=float32)}
# indxRep: 3  iteration:  30  rep:  1  part:  0
# iteration report:  30
# monitor
# {'hsic_indep': DeviceArray(-22.959, dtype=float32), 'hsic_resids': DeviceArray(-7.139, dtype=float32), 'hsic_rx_ax': DeviceArray(0.022, dtype=float32), 'hsic_ry_ay': DeviceArray(0.037, dtype=float32), 'hsic_zc': DeviceArray(0.064, dtype=float32), 'hsic_zx': DeviceArray(0.349, dtype=float32), 'hsic_zx_zc': DeviceArray(0.004, dtype=float32), 'hsic_zx_zy': DeviceArray(0.001, dtype=float32), 'hsic_zy': DeviceArray(0.477, dtype=float32), 'hsic_zy_x': DeviceArray(0.003, dtype=float32), 'hsic_zy_zc': DeviceArray(0.007, dtype=float32), 'mse_rx': DeviceArray(0.569, dtype=float32), 'mse_ry': DeviceArray(0.575, dtype=float32), 'mses': DeviceArray(-1.117, dtype=float32)}
# indxRep: 3  iteration:  30  rep:  2  part:  0
# iteration report:  30
# monitor
# {'hsic_indep': DeviceArray(-23.775, dtype=float32), 'hsic_resids': DeviceArray(-6.861, dtype=float32), 'hsic_rx_ax': DeviceArray(0.026, dtype=float32), 'hsic_ry_ay': DeviceArray(0.04, dtype=float32), 'hsic_zc': DeviceArray(0.011, dtype=float32), 'hsic_zx': DeviceArray(0.412, dtype=float32), 'hsic_zx_zc': DeviceArray(0.008, dtype=float32), 'hsic_zx_zy': DeviceArray(0.001, dtype=float32), 'hsic_zy': DeviceArray(0.521, dtype=float32), 'hsic_zy_x': DeviceArray(0.002, dtype=float32), 'hsic_zy_zc': DeviceArray(0.005, dtype=float32), 'mse_rx': DeviceArray(0.546, dtype=float32), 'mse_ry': DeviceArray(0.648, dtype=float32), 'mses': DeviceArray(-1.038, dtype=float32)}
# indxRep: 3  iteration:  30  rep:  3  part:  0
# iteration report:  30
# monitor
# {'hsic_indep': DeviceArray(-20.541, dtype=float32), 'hsic_resids': DeviceArray(-7.676, dtype=float32), 'hsic_rx_ax': DeviceArray(0.019, dtype=float32), 'hsic_ry_ay': DeviceArray(0.024, dtype=float32), 'hsic_zc': DeviceArray(0.009, dtype=float32), 'hsic_zx': DeviceArray(0.399, dtype=float32), 'hsic_zx_zc': DeviceArray(0.006, dtype=float32), 'hsic_zx_zy': DeviceArray(0.009, dtype=float32), 'hsic_zy': DeviceArray(0.538, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.034, dtype=float32), 'mse_rx': DeviceArray(0.671, dtype=float32), 'mse_ry': DeviceArray(0.689, dtype=float32), 'mses': DeviceArray(-0.772, dtype=float32)}
# indxRep: 3  iteration:  30  rep:  4  part:  0
# iteration report:  30
# monitor
# {'hsic_indep': DeviceArray(-19.348, dtype=float32), 'hsic_resids': DeviceArray(-9.147, dtype=float32), 'hsic_rx_ax': DeviceArray(0.009, dtype=float32), 'hsic_ry_ay': DeviceArray(0.012, dtype=float32), 'hsic_zc': DeviceArray(0.011, dtype=float32), 'hsic_zx': DeviceArray(0.411, dtype=float32), 'hsic_zx_zc': DeviceArray(0.001, dtype=float32), 'hsic_zx_zy': DeviceArray(0.041, dtype=float32), 'hsic_zy': DeviceArray(0.499, dtype=float32), 'hsic_zy_x': DeviceArray(0.004, dtype=float32), 'hsic_zy_zc': DeviceArray(0.021, dtype=float32), 'mse_rx': DeviceArray(0.713, dtype=float32), 'mse_ry': DeviceArray(0.654, dtype=float32), 'mses': DeviceArray(-0.762, dtype=float32)}
# indxRep: 3  iteration:  30  rep:  5  part:  0
# iteration report:  30
# monitor
# {'hsic_indep': DeviceArray(-18.737, dtype=float32), 'hsic_resids': DeviceArray(-10.417, dtype=float32), 'hsic_rx_ax': DeviceArray(0.004, dtype=float32), 'hsic_ry_ay': DeviceArray(0.008, dtype=float32), 'hsic_zc': DeviceArray(0.149, dtype=float32), 'hsic_zx': DeviceArray(0.37, dtype=float32), 'hsic_zx_zc': DeviceArray(0.018, dtype=float32), 'hsic_zx_zy': DeviceArray(0.031, dtype=float32), 'hsic_zy': DeviceArray(0.453, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.025, dtype=float32), 'mse_rx': DeviceArray(0.91, dtype=float32), 'mse_ry': DeviceArray(0.791, dtype=float32), 'mses': DeviceArray(-0.329, dtype=float32)}
# indxRep: 3  iteration:  30  rep:  6  part:  0
# iteration report:  40
# monitor
# {'hsic_indep': DeviceArray(-16.596, dtype=float32), 'hsic_resids': DeviceArray(-6.257, dtype=float32), 'hsic_rx_ax': DeviceArray(0.067, dtype=float32), 'hsic_ry_ay': DeviceArray(0.029, dtype=float32), 'hsic_zc': DeviceArray(0.011, dtype=float32), 'hsic_zx': DeviceArray(0.109, dtype=float32), 'hsic_zx_zc': DeviceArray(0.02, dtype=float32), 'hsic_zx_zy': DeviceArray(0.015, dtype=float32), 'hsic_zy': DeviceArray(0.191, dtype=float32), 'hsic_zy_x': DeviceArray(0.008, dtype=float32), 'hsic_zy_zc': DeviceArray(0.025, dtype=float32), 'mse_rx': DeviceArray(0.459, dtype=float32), 'mse_ry': DeviceArray(0.036, dtype=float32), 'mses': DeviceArray(-4.094, dtype=float32)}
# indxRep: 4  iteration:  40  rep:  0  part:  0
# iteration report:  40
# monitor
# {'hsic_indep': DeviceArray(-20.366, dtype=float32), 'hsic_resids': DeviceArray(-6.485, dtype=float32), 'hsic_rx_ax': DeviceArray(0.026, dtype=float32), 'hsic_ry_ay': DeviceArray(0.059, dtype=float32), 'hsic_zc': DeviceArray(0.018, dtype=float32), 'hsic_zx': DeviceArray(0.255, dtype=float32), 'hsic_zx_zc': DeviceArray(0.009, dtype=float32), 'hsic_zx_zy': DeviceArray(0.005, dtype=float32), 'hsic_zy': DeviceArray(0.342, dtype=float32), 'hsic_zy_x': DeviceArray(0.005, dtype=float32), 'hsic_zy_zc': DeviceArray(0.008, dtype=float32), 'mse_rx': DeviceArray(0.535, dtype=float32), 'mse_ry': DeviceArray(0.378, dtype=float32), 'mses': DeviceArray(-1.598, dtype=float32)}
# indxRep: 4  iteration:  40  rep:  1  part:  0
# iteration report:  40
# monitor
# {'hsic_indep': DeviceArray(-22.519, dtype=float32), 'hsic_resids': DeviceArray(-6.944, dtype=float32), 'hsic_rx_ax': DeviceArray(0.026, dtype=float32), 'hsic_ry_ay': DeviceArray(0.038, dtype=float32), 'hsic_zc': DeviceArray(0.063, dtype=float32), 'hsic_zx': DeviceArray(0.343, dtype=float32), 'hsic_zx_zc': DeviceArray(0.004, dtype=float32), 'hsic_zx_zy': DeviceArray(0.003, dtype=float32), 'hsic_zy': DeviceArray(0.483, dtype=float32), 'hsic_zy_x': DeviceArray(0.002, dtype=float32), 'hsic_zy_zc': DeviceArray(0.009, dtype=float32), 'mse_rx': DeviceArray(0.611, dtype=float32), 'mse_ry': DeviceArray(0.582, dtype=float32), 'mses': DeviceArray(-1.034, dtype=float32)}
# indxRep: 4  iteration:  40  rep:  2  part:  0
# iteration report:  40
# monitor
# {'hsic_indep': DeviceArray(-24.019, dtype=float32), 'hsic_resids': DeviceArray(-7.248, dtype=float32), 'hsic_rx_ax': DeviceArray(0.019, dtype=float32), 'hsic_ry_ay': DeviceArray(0.038, dtype=float32), 'hsic_zc': DeviceArray(0.014, dtype=float32), 'hsic_zx': DeviceArray(0.418, dtype=float32), 'hsic_zx_zc': DeviceArray(0.003, dtype=float32), 'hsic_zx_zy': DeviceArray(0.002, dtype=float32), 'hsic_zy': DeviceArray(0.524, dtype=float32), 'hsic_zy_x': DeviceArray(0.002, dtype=float32), 'hsic_zy_zc': DeviceArray(0.003, dtype=float32), 'mse_rx': DeviceArray(0.51, dtype=float32), 'mse_ry': DeviceArray(0.632, dtype=float32), 'mses': DeviceArray(-1.132, dtype=float32)}
# indxRep: 4  iteration:  40  rep:  3  part:  0
# iteration report:  40
# monitor
# {'hsic_indep': DeviceArray(-26.332, dtype=float32), 'hsic_resids': DeviceArray(-8.053, dtype=float32), 'hsic_rx_ax': DeviceArray(0.015, dtype=float32), 'hsic_ry_ay': DeviceArray(0.022, dtype=float32), 'hsic_zc': DeviceArray(0.01, dtype=float32), 'hsic_zx': DeviceArray(0.431, dtype=float32), 'hsic_zx_zc': DeviceArray(0.002, dtype=float32), 'hsic_zx_zy': DeviceArray(0., dtype=float32), 'hsic_zy': DeviceArray(0.527, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.01, dtype=float32), 'mse_rx': DeviceArray(0.529, dtype=float32), 'mse_ry': DeviceArray(0.682, dtype=float32), 'mses': DeviceArray(-1.02, dtype=float32)}
# indxRep: 4  iteration:  40  rep:  4  part:  0
# iteration report:  40
# monitor
# {'hsic_indep': DeviceArray(-22.372, dtype=float32), 'hsic_resids': DeviceArray(-9.509, dtype=float32), 'hsic_rx_ax': DeviceArray(0.006, dtype=float32), 'hsic_ry_ay': DeviceArray(0.012, dtype=float32), 'hsic_zc': DeviceArray(0.033, dtype=float32), 'hsic_zx': DeviceArray(0.376, dtype=float32), 'hsic_zx_zc': DeviceArray(0.001, dtype=float32), 'hsic_zx_zy': DeviceArray(0.012, dtype=float32), 'hsic_zy': DeviceArray(0.495, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.022, dtype=float32), 'mse_rx': DeviceArray(0.827, dtype=float32), 'mse_ry': DeviceArray(0.715, dtype=float32), 'mses': DeviceArray(-0.525, dtype=float32)}
# indxRep: 4  iteration:  40  rep:  5  part:  0
# iteration report:  40
# monitor
# {'hsic_indep': DeviceArray(-24.951, dtype=float32), 'hsic_resids': DeviceArray(-8.43, dtype=float32), 'hsic_rx_ax': DeviceArray(0.028, dtype=float32), 'hsic_ry_ay': DeviceArray(0.008, dtype=float32), 'hsic_zc': DeviceArray(0.146, dtype=float32), 'hsic_zx': DeviceArray(0.405, dtype=float32), 'hsic_zx_zc': DeviceArray(0.046, dtype=float32), 'hsic_zx_zy': DeviceArray(0., dtype=float32), 'hsic_zy': DeviceArray(0.443, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.01, dtype=float32), 'mse_rx': DeviceArray(0.635, dtype=float32), 'mse_ry': DeviceArray(0.777, dtype=float32), 'mses': DeviceArray(-0.706, dtype=float32)}
# indxRep: 4  iteration:  40  rep:  6  part:  0
# iteration:  50
# iteration report:  50
# monitor
# {'hsic_indep': DeviceArray(-16.509, dtype=float32), 'hsic_resids': DeviceArray(-6.106, dtype=float32), 'hsic_rx_ax': DeviceArray(0.066, dtype=float32), 'hsic_ry_ay': DeviceArray(0.034, dtype=float32), 'hsic_zc': DeviceArray(0.014, dtype=float32), 'hsic_zx': DeviceArray(0.107, dtype=float32), 'hsic_zx_zc': DeviceArray(0.019, dtype=float32), 'hsic_zx_zy': DeviceArray(0.017, dtype=float32), 'hsic_zy': DeviceArray(0.193, dtype=float32), 'hsic_zy_x': DeviceArray(0.008, dtype=float32), 'hsic_zy_zc': DeviceArray(0.028, dtype=float32), 'mse_rx': DeviceArray(0.491, dtype=float32), 'mse_ry': DeviceArray(0.03, dtype=float32), 'mses': DeviceArray(-4.226, dtype=float32)}
# indxRep: 5  iteration:  50  rep:  0  part:  0
# iteration report:  50
# monitor
# {'hsic_indep': DeviceArray(-20.517, dtype=float32), 'hsic_resids': DeviceArray(-6.458, dtype=float32), 'hsic_rx_ax': DeviceArray(0.026, dtype=float32), 'hsic_ry_ay': DeviceArray(0.059, dtype=float32), 'hsic_zc': DeviceArray(0.016, dtype=float32), 'hsic_zx': DeviceArray(0.258, dtype=float32), 'hsic_zx_zc': DeviceArray(0.007, dtype=float32), 'hsic_zx_zy': DeviceArray(0.005, dtype=float32), 'hsic_zy': DeviceArray(0.342, dtype=float32), 'hsic_zy_x': DeviceArray(0.005, dtype=float32), 'hsic_zy_zc': DeviceArray(0.008, dtype=float32), 'mse_rx': DeviceArray(0.515, dtype=float32), 'mse_ry': DeviceArray(0.391, dtype=float32), 'mses': DeviceArray(-1.602, dtype=float32)}
# indxRep: 5  iteration:  50  rep:  1  part:  0
# iteration report:  50
# monitor
# {'hsic_indep': DeviceArray(-22.913, dtype=float32), 'hsic_resids': DeviceArray(-7.04, dtype=float32), 'hsic_rx_ax': DeviceArray(0.023, dtype=float32), 'hsic_ry_ay': DeviceArray(0.037, dtype=float32), 'hsic_zc': DeviceArray(0.083, dtype=float32), 'hsic_zx': DeviceArray(0.353, dtype=float32), 'hsic_zx_zc': DeviceArray(0.004, dtype=float32), 'hsic_zx_zy': DeviceArray(0.002, dtype=float32), 'hsic_zy': DeviceArray(0.476, dtype=float32), 'hsic_zy_x': DeviceArray(0.002, dtype=float32), 'hsic_zy_zc': DeviceArray(0.009, dtype=float32), 'mse_rx': DeviceArray(0.57, dtype=float32), 'mse_ry': DeviceArray(0.584, dtype=float32), 'mses': DeviceArray(-1.101, dtype=float32)}
# indxRep: 5  iteration:  50  rep:  2  part:  0
# iteration report:  50
# monitor
# {'hsic_indep': DeviceArray(-23.328, dtype=float32), 'hsic_resids': DeviceArray(-7.372, dtype=float32), 'hsic_rx_ax': DeviceArray(0.019, dtype=float32), 'hsic_ry_ay': DeviceArray(0.034, dtype=float32), 'hsic_zc': DeviceArray(0.013, dtype=float32), 'hsic_zx': DeviceArray(0.41, dtype=float32), 'hsic_zx_zc': DeviceArray(0.004, dtype=float32), 'hsic_zx_zy': DeviceArray(0.002, dtype=float32), 'hsic_zy': DeviceArray(0.531, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.009, dtype=float32), 'mse_rx': DeviceArray(0.555, dtype=float32), 'mse_ry': DeviceArray(0.659, dtype=float32), 'mses': DeviceArray(-1.006, dtype=float32)}
# indxRep: 5  iteration:  50  rep:  3  part:  0
# iteration report:  50
# monitor
# {'hsic_indep': DeviceArray(-24.891, dtype=float32), 'hsic_resids': DeviceArray(-7.991, dtype=float32), 'hsic_rx_ax': DeviceArray(0.015, dtype=float32), 'hsic_ry_ay': DeviceArray(0.022, dtype=float32), 'hsic_zc': DeviceArray(0.011, dtype=float32), 'hsic_zx': DeviceArray(0.43, dtype=float32), 'hsic_zx_zc': DeviceArray(0.005, dtype=float32), 'hsic_zx_zy': DeviceArray(0.001, dtype=float32), 'hsic_zy': DeviceArray(0.527, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.003, dtype=float32), 'mse_rx': DeviceArray(0.567, dtype=float32), 'mse_ry': DeviceArray(0.696, dtype=float32), 'mses': DeviceArray(-0.93, dtype=float32)}
# indxRep: 5  iteration:  50  rep:  4  part:  0
# iteration report:  50
# monitor
# {'hsic_indep': DeviceArray(-20.132, dtype=float32), 'hsic_resids': DeviceArray(-9.38, dtype=float32), 'hsic_rx_ax': DeviceArray(0.009, dtype=float32), 'hsic_ry_ay': DeviceArray(0.009, dtype=float32), 'hsic_zc': DeviceArray(0.034, dtype=float32), 'hsic_zx': DeviceArray(0.395, dtype=float32), 'hsic_zx_zc': DeviceArray(0.01, dtype=float32), 'hsic_zx_zy': DeviceArray(0.005, dtype=float32), 'hsic_zy': DeviceArray(0.482, dtype=float32), 'hsic_zy_x': DeviceArray(0.002, dtype=float32), 'hsic_zy_zc': DeviceArray(0.021, dtype=float32), 'mse_rx': DeviceArray(0.685, dtype=float32), 'mse_ry': DeviceArray(0.692, dtype=float32), 'mses': DeviceArray(-0.747, dtype=float32)}
# indxRep: 5  iteration:  50  rep:  5  part:  0
# iteration report:  50
# monitor
# {'hsic_indep': DeviceArray(-19.192, dtype=float32), 'hsic_resids': DeviceArray(-9.451, dtype=float32), 'hsic_rx_ax': DeviceArray(0.011, dtype=float32), 'hsic_ry_ay': DeviceArray(0.007, dtype=float32), 'hsic_zc': DeviceArray(0.135, dtype=float32), 'hsic_zx': DeviceArray(0.354, dtype=float32), 'hsic_zx_zc': DeviceArray(0.104, dtype=float32), 'hsic_zx_zy': DeviceArray(0.002, dtype=float32), 'hsic_zy': DeviceArray(0.445, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.018, dtype=float32), 'mse_rx': DeviceArray(0.747, dtype=float32), 'mse_ry': DeviceArray(0.775, dtype=float32), 'mses': DeviceArray(-0.546, dtype=float32)}
# indxRep: 5  iteration:  50  rep:  6  part:  0
# iteration report:  60
# monitor
# {'hsic_indep': DeviceArray(-16.559, dtype=float32), 'hsic_resids': DeviceArray(-7.311, dtype=float32), 'hsic_rx_ax': DeviceArray(0.06, dtype=float32), 'hsic_ry_ay': DeviceArray(0.011, dtype=float32), 'hsic_zc': DeviceArray(0.012, dtype=float32), 'hsic_zx': DeviceArray(0.094, dtype=float32), 'hsic_zx_zc': DeviceArray(0.018, dtype=float32), 'hsic_zx_zy': DeviceArray(0.018, dtype=float32), 'hsic_zy': DeviceArray(0.193, dtype=float32), 'hsic_zy_x': DeviceArray(0.007, dtype=float32), 'hsic_zy_zc': DeviceArray(0.026, dtype=float32), 'mse_rx': DeviceArray(0.583, dtype=float32), 'mse_ry': DeviceArray(0.025, dtype=float32), 'mses': DeviceArray(-4.21, dtype=float32)}
# indxRep: 6  iteration:  60  rep:  0  part:  0
# iteration report:  60
# monitor
# {'hsic_indep': DeviceArray(-20.56, dtype=float32), 'hsic_resids': DeviceArray(-6.573, dtype=float32), 'hsic_rx_ax': DeviceArray(0.025, dtype=float32), 'hsic_ry_ay': DeviceArray(0.055, dtype=float32), 'hsic_zc': DeviceArray(0.015, dtype=float32), 'hsic_zx': DeviceArray(0.26, dtype=float32), 'hsic_zx_zc': DeviceArray(0.006, dtype=float32), 'hsic_zx_zy': DeviceArray(0.005, dtype=float32), 'hsic_zy': DeviceArray(0.339, dtype=float32), 'hsic_zy_x': DeviceArray(0.004, dtype=float32), 'hsic_zy_zc': DeviceArray(0.008, dtype=float32), 'mse_rx': DeviceArray(0.518, dtype=float32), 'mse_ry': DeviceArray(0.379, dtype=float32), 'mses': DeviceArray(-1.628, dtype=float32)}
# indxRep: 6  iteration:  60  rep:  1  part:  0
# iteration report:  60
# monitor
# {'hsic_indep': DeviceArray(-23.229, dtype=float32), 'hsic_resids': DeviceArray(-7.253, dtype=float32), 'hsic_rx_ax': DeviceArray(0.019, dtype=float32), 'hsic_ry_ay': DeviceArray(0.038, dtype=float32), 'hsic_zc': DeviceArray(0.049, dtype=float32), 'hsic_zx': DeviceArray(0.361, dtype=float32), 'hsic_zx_zc': DeviceArray(0.004, dtype=float32), 'hsic_zx_zy': DeviceArray(0.002, dtype=float32), 'hsic_zy': DeviceArray(0.48, dtype=float32), 'hsic_zy_x': DeviceArray(0.002, dtype=float32), 'hsic_zy_zc': DeviceArray(0.008, dtype=float32), 'mse_rx': DeviceArray(0.504, dtype=float32), 'mse_ry': DeviceArray(0.588, dtype=float32), 'mses': DeviceArray(-1.216, dtype=float32)}
# indxRep: 6  iteration:  60  rep:  2  part:  0
# iteration report:  60
# monitor
# {'hsic_indep': DeviceArray(-24.948, dtype=float32), 'hsic_resids': DeviceArray(-7.211, dtype=float32), 'hsic_rx_ax': DeviceArray(0.021, dtype=float32), 'hsic_ry_ay': DeviceArray(0.036, dtype=float32), 'hsic_zc': DeviceArray(0.016, dtype=float32), 'hsic_zx': DeviceArray(0.417, dtype=float32), 'hsic_zx_zc': DeviceArray(0.003, dtype=float32), 'hsic_zx_zy': DeviceArray(0.001, dtype=float32), 'hsic_zy': DeviceArray(0.518, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.003, dtype=float32), 'mse_rx': DeviceArray(0.566, dtype=float32), 'mse_ry': DeviceArray(0.638, dtype=float32), 'mses': DeviceArray(-1.019, dtype=float32)}
# indxRep: 6  iteration:  60  rep:  3  part:  0
# iteration report:  60
# monitor
# {'hsic_indep': DeviceArray(-25.259, dtype=float32), 'hsic_resids': DeviceArray(-7.836, dtype=float32), 'hsic_rx_ax': DeviceArray(0.017, dtype=float32), 'hsic_ry_ay': DeviceArray(0.023, dtype=float32), 'hsic_zc': DeviceArray(0.022, dtype=float32), 'hsic_zx': DeviceArray(0.452, dtype=float32), 'hsic_zx_zc': DeviceArray(0.002, dtype=float32), 'hsic_zx_zy': DeviceArray(0.004, dtype=float32), 'hsic_zy': DeviceArray(0.528, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.001, dtype=float32), 'mse_rx': DeviceArray(0.562, dtype=float32), 'mse_ry': DeviceArray(0.693, dtype=float32), 'mses': DeviceArray(-0.942, dtype=float32)}
# indxRep: 6  iteration:  60  rep:  4  part:  0
# iteration report:  60
# monitor
# {'hsic_indep': DeviceArray(-22.258, dtype=float32), 'hsic_resids': DeviceArray(-9.262, dtype=float32), 'hsic_rx_ax': DeviceArray(0.007, dtype=float32), 'hsic_ry_ay': DeviceArray(0.013, dtype=float32), 'hsic_zc': DeviceArray(0.019, dtype=float32), 'hsic_zx': DeviceArray(0.385, dtype=float32), 'hsic_zx_zc': DeviceArray(0.01, dtype=float32), 'hsic_zx_zy': DeviceArray(0.015, dtype=float32), 'hsic_zy': DeviceArray(0.496, dtype=float32), 'hsic_zy_x': DeviceArray(0., dtype=float32), 'hsic_zy_zc': DeviceArray(0.003, dtype=float32), 'mse_rx': DeviceArray(0.752, dtype=float32), 'mse_ry': DeviceArray(0.735, dtype=float32), 'mses': DeviceArray(-0.594, dtype=float32)}
# indxRep: 6  iteration:  60  rep:  5  part:  0
# iteration report:  60
# monitor
# {'hsic_indep': DeviceArray(-17.797, dtype=float32), 'hsic_resids': DeviceArray(-8.896, dtype=float32), 'hsic_rx_ax': DeviceArray(0.021, dtype=float32), 'hsic_ry_ay': DeviceArray(0.006, dtype=float32), 'hsic_zc': DeviceArray(0.147, dtype=float32), 'hsic_zx': DeviceArray(0.414, dtype=float32), 'hsic_zx_zc': DeviceArray(0.003, dtype=float32), 'hsic_zx_zy': DeviceArray(0.088, dtype=float32), 'hsic_zy': DeviceArray(0.436, dtype=float32), 'hsic_zy_x': DeviceArray(0.003, dtype=float32), 'hsic_zy_zc': DeviceArray(0.025, dtype=float32), 'mse_rx': DeviceArray(1.078, dtype=float32), 'mse_ry': DeviceArray(0.793, dtype=float32), 'mses': DeviceArray(-0.157, dtype=float32)}
# indxRep: 6  iteration:  60  rep:  6  part:  0
# iteration report:  70
# monitor
# {'hsic_indep': DeviceArray(-16.256, dtype=float32), 'hsic_resids': DeviceArray(-7.512, dtype=float32), 'hsic_rx_ax': DeviceArray(0.065, dtype=float32), 'hsic_ry_ay': DeviceArray(0.008, dtype=float32), 'hsic_zc': DeviceArray(0.016, dtype=float32), 'hsic_zx': DeviceArray(0.076, dtype=float32), 'hsic_zx_zc': DeviceArray(0.019, dtype=float32), 'hsic_zx_zy': DeviceArray(0.021, dtype=float32), 'hsic_zy': DeviceArray(0.194, dtype=float32), 'hsic_zy_x': DeviceArray(0.007, dtype=float32), 'hsic_zy_zc': DeviceArray(0.029, dtype=float32), 'mse_rx': DeviceArray(0.846, dtype=float32), 'mse_ry': DeviceArray(0.03, dtype=float32), 'mses': DeviceArray(-3.681, dtype=float32)}
# indxRep: 7  iteration:  70  rep:  0  part:  0
# iteration report:  70
# monitor
# {'hsic_indep': DeviceArray(-20.68, dtype=float32), 'hsic_resids': DeviceArray(-6.557, dtype=float32), 'hsic_rx_ax': DeviceArray(0.025, dtype=float32), 'hsic_ry_ay': DeviceArray(0.057, dtype=float32), 'hsic_zc': DeviceArray(0.018, dtype=float32), 'hsic_zx': DeviceArray(0.259, dtype=float32), 'hsic_zx_zc': DeviceArray(0.006, dtype=float32), 'hsic_zx_zy': DeviceArray(0.005, dtype=float32), 'hsic_zy': DeviceArray(0.338, dtype=float32), 'hsic_zy_x': DeviceArray(0.004, dtype=float32), 'hsic_zy_zc': DeviceArray(0.008, dtype=float32), 'mse_rx': DeviceArray(0.517, dtype=float32), 'mse_ry': DeviceArray(0.381, dtype=float32), 'mses': DeviceArray(-1.623, dtype=float32)}
# indxRep: 7  iteration:  70  rep:  1  part:  0
# iteration report:  70
# monitor
# {'hsic_indep': DeviceArray(-23.653, dtype=float32), 'hsic_resids': DeviceArray(-7.183, dtype=float32), 'hsic_rx_ax': DeviceArray(0.019, dtype=float32), 'hsic_ry_ay': DeviceArray(0.04, dtype=float32), 'hsic_zc': DeviceArray(0.057, dtype=float32), 'hsic_zx': DeviceArray(0.354, dtype=float32), 'hsic_zx_zc': DeviceArray(0.003, dtype=float32), 'hsic_zx_zy': DeviceArray(0.001, dtype=float32), 'hsic_zy': DeviceArray(0.479, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.008, dtype=float32), 'mse_rx': DeviceArray(0.508, dtype=float32), 'mse_ry': DeviceArray(0.597, dtype=float32), 'mses': DeviceArray(-1.193, dtype=float32)}
# indxRep: 7  iteration:  70  rep:  2  part:  0
# iteration report:  70
# monitor
# {'hsic_indep': DeviceArray(-24.09, dtype=float32), 'hsic_resids': DeviceArray(-7.412, dtype=float32), 'hsic_rx_ax': DeviceArray(0.018, dtype=float32), 'hsic_ry_ay': DeviceArray(0.034, dtype=float32), 'hsic_zc': DeviceArray(0.022, dtype=float32), 'hsic_zx': DeviceArray(0.411, dtype=float32), 'hsic_zx_zc': DeviceArray(0.005, dtype=float32), 'hsic_zx_zy': DeviceArray(0.001, dtype=float32), 'hsic_zy': DeviceArray(0.521, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.004, dtype=float32), 'mse_rx': DeviceArray(0.577, dtype=float32), 'mse_ry': DeviceArray(0.635, dtype=float32), 'mses': DeviceArray(-1.003, dtype=float32)}
# indxRep: 7  iteration:  70  rep:  3  part:  0
# iteration report:  70
# monitor
# {'hsic_indep': DeviceArray(-22.151, dtype=float32), 'hsic_resids': DeviceArray(-8.179, dtype=float32), 'hsic_rx_ax': DeviceArray(0.014, dtype=float32), 'hsic_ry_ay': DeviceArray(0.02, dtype=float32), 'hsic_zc': DeviceArray(0.034, dtype=float32), 'hsic_zx': DeviceArray(0.452, dtype=float32), 'hsic_zx_zc': DeviceArray(0.014, dtype=float32), 'hsic_zx_zy': DeviceArray(0.004, dtype=float32), 'hsic_zy': DeviceArray(0.541, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.003, dtype=float32), 'mse_rx': DeviceArray(0.563, dtype=float32), 'mse_ry': DeviceArray(0.683, dtype=float32), 'mses': DeviceArray(-0.956, dtype=float32)}
# indxRep: 7  iteration:  70  rep:  4  part:  0
# iteration report:  70
# monitor
# {'hsic_indep': DeviceArray(-21.603, dtype=float32), 'hsic_resids': DeviceArray(-9.462, dtype=float32), 'hsic_rx_ax': DeviceArray(0.006, dtype=float32), 'hsic_ry_ay': DeviceArray(0.012, dtype=float32), 'hsic_zc': DeviceArray(0.005, dtype=float32), 'hsic_zx': DeviceArray(0.416, dtype=float32), 'hsic_zx_zc': DeviceArray(0.028, dtype=float32), 'hsic_zx_zy': DeviceArray(0.007, dtype=float32), 'hsic_zy': DeviceArray(0.489, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.003, dtype=float32), 'mse_rx': DeviceArray(0.749, dtype=float32), 'mse_ry': DeviceArray(0.762, dtype=float32), 'mses': DeviceArray(-0.561, dtype=float32)}
# indxRep: 7  iteration:  70  rep:  5  part:  0
# iteration report:  70
# monitor
# {'hsic_indep': DeviceArray(-19.473, dtype=float32), 'hsic_resids': DeviceArray(-9.186, dtype=float32), 'hsic_rx_ax': DeviceArray(0.012, dtype=float32), 'hsic_ry_ay': DeviceArray(0.009, dtype=float32), 'hsic_zc': DeviceArray(0.159, dtype=float32), 'hsic_zx': DeviceArray(0.41, dtype=float32), 'hsic_zx_zc': DeviceArray(0.218, dtype=float32), 'hsic_zx_zy': DeviceArray(0.004, dtype=float32), 'hsic_zy': DeviceArray(0.446, dtype=float32), 'hsic_zy_x': DeviceArray(0., dtype=float32), 'hsic_zy_zc': DeviceArray(0.009, dtype=float32), 'mse_rx': DeviceArray(0.816, dtype=float32), 'mse_ry': DeviceArray(0.929, dtype=float32), 'mses': DeviceArray(-0.278, dtype=float32)}
# indxRep: 7  iteration:  70  rep:  6  part:  0
# iteration report:  80
# monitor
# {'hsic_indep': DeviceArray(-16.216, dtype=float32), 'hsic_resids': DeviceArray(-6.386, dtype=float32), 'hsic_rx_ax': DeviceArray(0.051, dtype=float32), 'hsic_ry_ay': DeviceArray(0.033, dtype=float32), 'hsic_zc': DeviceArray(0.014, dtype=float32), 'hsic_zx': DeviceArray(0.066, dtype=float32), 'hsic_zx_zc': DeviceArray(0.02, dtype=float32), 'hsic_zx_zy': DeviceArray(0.022, dtype=float32), 'hsic_zy': DeviceArray(0.193, dtype=float32), 'hsic_zy_x': DeviceArray(0.007, dtype=float32), 'hsic_zy_zc': DeviceArray(0.029, dtype=float32), 'mse_rx': DeviceArray(0.924, dtype=float32), 'mse_ry': DeviceArray(0.059, dtype=float32), 'mses': DeviceArray(-2.911, dtype=float32)}
# indxRep: 8  iteration:  80  rep:  0  part:  0
# iteration report:  80
# monitor
# {'hsic_indep': DeviceArray(-21.033, dtype=float32), 'hsic_resids': DeviceArray(-6.438, dtype=float32), 'hsic_rx_ax': DeviceArray(0.026, dtype=float32), 'hsic_ry_ay': DeviceArray(0.062, dtype=float32), 'hsic_zc': DeviceArray(0.015, dtype=float32), 'hsic_zx': DeviceArray(0.259, dtype=float32), 'hsic_zx_zc': DeviceArray(0.006, dtype=float32), 'hsic_zx_zy': DeviceArray(0.004, dtype=float32), 'hsic_zy': DeviceArray(0.334, dtype=float32), 'hsic_zy_x': DeviceArray(0.004, dtype=float32), 'hsic_zy_zc': DeviceArray(0.007, dtype=float32), 'mse_rx': DeviceArray(0.519, dtype=float32), 'mse_ry': DeviceArray(0.385, dtype=float32), 'mses': DeviceArray(-1.611, dtype=float32)}
# indxRep: 8  iteration:  80  rep:  1  part:  0
# iteration report:  80
# monitor
# {'hsic_indep': DeviceArray(-23.217, dtype=float32), 'hsic_resids': DeviceArray(-7.093, dtype=float32), 'hsic_rx_ax': DeviceArray(0.022, dtype=float32), 'hsic_ry_ay': DeviceArray(0.037, dtype=float32), 'hsic_zc': DeviceArray(0.046, dtype=float32), 'hsic_zx': DeviceArray(0.357, dtype=float32), 'hsic_zx_zc': DeviceArray(0.005, dtype=float32), 'hsic_zx_zy': DeviceArray(0.002, dtype=float32), 'hsic_zy': DeviceArray(0.48, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.007, dtype=float32), 'mse_rx': DeviceArray(0.509, dtype=float32), 'mse_ry': DeviceArray(0.604, dtype=float32), 'mses': DeviceArray(-1.18, dtype=float32)}
# indxRep: 8  iteration:  80  rep:  2  part:  0
# iteration report:  80
# monitor
# {'hsic_indep': DeviceArray(-23.731, dtype=float32), 'hsic_resids': DeviceArray(-7.451, dtype=float32), 'hsic_rx_ax': DeviceArray(0.017, dtype=float32), 'hsic_ry_ay': DeviceArray(0.034, dtype=float32), 'hsic_zc': DeviceArray(0.024, dtype=float32), 'hsic_zx': DeviceArray(0.422, dtype=float32), 'hsic_zx_zc': DeviceArray(0.007, dtype=float32), 'hsic_zx_zy': DeviceArray(0.001, dtype=float32), 'hsic_zy': DeviceArray(0.527, dtype=float32), 'hsic_zy_x': DeviceArray(0.002, dtype=float32), 'hsic_zy_zc': DeviceArray(0.004, dtype=float32), 'mse_rx': DeviceArray(0.533, dtype=float32), 'mse_ry': DeviceArray(0.621, dtype=float32), 'mses': DeviceArray(-1.106, dtype=float32)}
# indxRep: 8  iteration:  80  rep:  3  part:  0
# iteration report:  80
# monitor
# {'hsic_indep': DeviceArray(-23.421, dtype=float32), 'hsic_resids': DeviceArray(-8.494, dtype=float32), 'hsic_rx_ax': DeviceArray(0.01, dtype=float32), 'hsic_ry_ay': DeviceArray(0.021, dtype=float32), 'hsic_zc': DeviceArray(0.017, dtype=float32), 'hsic_zx': DeviceArray(0.442, dtype=float32), 'hsic_zx_zc': DeviceArray(0.01, dtype=float32), 'hsic_zx_zy': DeviceArray(0.002, dtype=float32), 'hsic_zy': DeviceArray(0.54, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.006, dtype=float32), 'mse_rx': DeviceArray(0.582, dtype=float32), 'mse_ry': DeviceArray(0.673, dtype=float32), 'mses': DeviceArray(-0.937, dtype=float32)}
# indxRep: 8  iteration:  80  rep:  4  part:  0
# iteration report:  80
# monitor
# {'hsic_indep': DeviceArray(-24.352, dtype=float32), 'hsic_resids': DeviceArray(-8.993, dtype=float32), 'hsic_rx_ax': DeviceArray(0.01, dtype=float32), 'hsic_ry_ay': DeviceArray(0.012, dtype=float32), 'hsic_zc': DeviceArray(0.005, dtype=float32), 'hsic_zx': DeviceArray(0.399, dtype=float32), 'hsic_zx_zc': DeviceArray(0.003, dtype=float32), 'hsic_zx_zy': DeviceArray(0.001, dtype=float32), 'hsic_zy': DeviceArray(0.496, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.01, dtype=float32), 'mse_rx': DeviceArray(0.813, dtype=float32), 'mse_ry': DeviceArray(0.712, dtype=float32), 'mses': DeviceArray(-0.547, dtype=float32)}
# indxRep: 8  iteration:  80  rep:  5  part:  0
# iteration report:  80
# monitor
# {'hsic_indep': DeviceArray(-21.324, dtype=float32), 'hsic_resids': DeviceArray(-9.448, dtype=float32), 'hsic_rx_ax': DeviceArray(0.009, dtype=float32), 'hsic_ry_ay': DeviceArray(0.008, dtype=float32), 'hsic_zc': DeviceArray(0.133, dtype=float32), 'hsic_zx': DeviceArray(0.4, dtype=float32), 'hsic_zx_zc': DeviceArray(0.012, dtype=float32), 'hsic_zx_zy': DeviceArray(0.013, dtype=float32), 'hsic_zy': DeviceArray(0.444, dtype=float32), 'hsic_zy_x': DeviceArray(0., dtype=float32), 'hsic_zy_zc': DeviceArray(0.008, dtype=float32), 'mse_rx': DeviceArray(0.936, dtype=float32), 'mse_ry': DeviceArray(0.974, dtype=float32), 'mses': DeviceArray(-0.093, dtype=float32)}
# indxRep: 8  iteration:  80  rep:  6  part:  0
# iteration report:  90
# monitor
# ...
#
#        [[0.066],
#         [0.274],
#         [0.315],
#         [0.423],
#         [0.436],
#         [0.446],
#         [0.427]],
#
#        [[0.077],
#         [0.264],
#         [0.318],
#         [0.432],
#         [0.457],
#         [0.477],
#         [0.442]],
#
#        [[0.083],
#         [0.27 ],
#         [0.332],
#         [0.44 ],
#         [0.472],
#         [0.438],
#         [0.425]],
#
#        [[0.087],
#         [0.277],
#         [0.313],
#         [0.425],
#         [0.483],
#         [0.506],
#         [0.464]],
#
#        [[0.094],
#         [0.275],
#         [0.317],
#         [0.433],
#         [0.469],
#         [0.481],
#         [0.441]],
#
#        [[0.095],
#         [0.278],
#         [0.328],
#         [0.442],
#         [0.477],
#         [0.488],
#         [0.451]],
#
#        [[0.087],
#         [0.271],
#         [0.33 ],
#         [0.441],
#         [0.481],
#         [0.482],
#         [0.454]],
#
#        [[0.083],
#         [0.269],
#         [0.336],
#         [0.452],
#         [0.467],
#         [0.488],
#         [0.449]],
#
#        [[0.105],
#         [0.264],
#         [0.317],
#         [0.449],
#         [0.466],
#         [0.496],
#         [0.446]],
#
#        [[0.1  ],
#         [0.259],
#         [0.31 ],
#         [0.448],
#         [0.465],
#         [0.473],
#         [0.503]],
#
#        [[0.091],
#         [0.258],
#         [0.327],
#         [0.452],
#         [0.458],
#         [0.484],
#         [0.487]],
#
#        [[0.105],
#         [0.256],
#         [0.316],
#         [0.443],
#         [0.456],
#         [0.493],
#         [0.481]],
#
#        [[0.11 ],
#         [0.261],
#         [0.322],
#         [0.448],
#         [0.477],
#         [0.469],
#         [0.491]],
#
#        [[0.105],
#         [0.264],
#         [0.314],
#         [0.45 ],
#         [0.484],
#         [0.486],
#         [0.476]],
#
#        [[0.103],
#         [0.265],
#         [0.321],
#         [0.455],
#         [0.496],
#         [0.483],
#         [0.475]],
#
#        [[0.104],
#         [0.262],
#         [0.323],
#         [0.445],
#         [0.475],
#         [0.42 ],
#         [0.474]],
#
#        [[0.106],
#         [0.266],
#         [0.329],
#         [0.417],
#         [0.478],
#         [0.425],
#         [0.473]],
#
#        [[0.101],
#         [0.264],
#         [0.33 ],
#         [0.45 ],
#         [0.459],
#         [0.469],
#         [0.464]],
#
#        [[0.1  ],
#         [0.262],
#         [0.341],
#         [0.436],
#         [0.473],
#         [0.458],
#         [0.507]],
#
#        [[0.098],
#         [0.264],
#         [0.329],
#         [0.445],
#         [0.466],
#         [0.479],
#         [0.487]],
#
#        [[0.094],
#         [0.262],
#         [0.324],
#         [0.437],
#         [0.488],
#         [0.495],
#         [0.497]],
#
#        [[0.097],
#         [0.265],
#         [0.328],
#         [0.446],
#         [0.482],
#         [0.478],
#         [0.474]],
#
#        [[0.102],
#         [0.261],
#         [0.324],
#         [0.439],
#         [0.493],
#         [0.482],
#         [0.47 ]],
#
#        [[0.094],
#         [0.262],
#         [0.33 ],
#         [0.44 ],
#         [0.469],
#         [0.48 ],
#         [0.47 ]],
#
#        [[0.095],
#         [0.26 ],
#         [0.336],
#         [0.444],
#         [0.472],
#         [0.49 ],
#         [0.477]],
#
#        [[0.095],
#         [0.264],
#         [0.327],
#         [0.441],
#         [0.447],
#         [0.473],
#         [0.473]],
#
#        [[0.094],
#         [0.263],
#         [0.322],
#         [0.443],
#         [0.485],
#         [0.502],
#         [0.472]],
#
#        [[0.098],
#         [0.266],
#         [0.33 ],
#         [0.432],
#         [0.468],
#         [0.467],
#         [0.483]],
#
#        [[0.096],
#         [0.264],
#         [0.331],
#         [0.446],
#         [0.49 ],
#         [0.5  ],
#         [0.461]],
#
#        [[0.094],
#         [0.267],
#         [0.348],
#         [0.435],
#         [0.487],
#         [0.5  ],
#         [0.459]]]), 'hsic_zy': array([[[0.186],
#         [0.34 ],
#         [0.443],
#         [0.5  ],
#         [0.51 ],
#         [0.48 ],
#         [0.435]],
#
#        [[0.185],
#         [0.338],
#         [0.457],
#         [0.523],
#         [0.524],
#         [0.497],
#         [0.451]],
#
#        [[0.184],
#         [0.334],
#         [0.476],
#         [0.526],
#         [0.529],
#         [0.493],
#         [0.429]],
#
#        [[0.187],
#         [0.335],
#         [0.477],
#         [0.521],
#         [0.538],
#         [0.499],
#         [0.453]],
#
#        [[0.191],
#         [0.342],
#         [0.483],
#         [0.524],
#         [0.527],
#         [0.495],
#         [0.443]],
#
#        [[0.193],
#         [0.342],
#         [0.476],
#         [0.531],
#         [0.527],
#         [0.482],
#         [0.445]],
#
#        [[0.193],
#         [0.339],
#         [0.48 ],
#         [0.518],
#         [0.528],
#         [0.496],
#         [0.436]],
#
#        [[0.194],
#         [0.338],
#         [0.479],
#         [0.521],
#         [0.541],
#         [0.489],
#         [0.446]],
#
#        [[0.193],
#         [0.334],
#         [0.48 ],
#         [0.527],
#         [0.54 ],
#         [0.496],
#         [0.444]],
#
#        [[0.187],
#         [0.338],
#         [0.474],
#         [0.526],
#         [0.525],
#         [0.503],
#         [0.45 ]],
#
#        [[0.181],
#         [0.336],
#         [0.468],
#         [0.518],
#         [0.521],
#         [0.509],
#         [0.446]],
#
#        [[0.179],
#         [0.333],
#         [0.47 ],
#         [0.525],
#         [0.532],
#         [0.495],
#         [0.473]],
#
#        [[0.179],
#         [0.328],
#         [0.475],
#         [0.521],
#         [0.541],
#         [0.503],
#         [0.47 ]],
#
#        [[0.179],
#         [0.321],
#         [0.477],
#         [0.525],
#         [0.53 ],
#         [0.494],
#         [0.462]],
#
#        [[0.181],
#         [0.319],
#         [0.474],
#         [0.514],
#         [0.53 ],
#         [0.496],
#         [0.453]],
#
#        [[0.186],
#         [0.32 ],
#         [0.466],
#         [0.517],
#         [0.532],
#         [0.489],
#         [0.453]],
#
#        [[0.186],
#         [0.321],
#         [0.47 ],
#         [0.513],
#         [0.525],
#         [0.486],
#         [0.462]],
#
#        [[0.184],
#         [0.326],
#         [0.471],
#         [0.512],
#         [0.528],
#         [0.484],
#         [0.46 ]],
#
#        [[0.182],
#         [0.333],
#         [0.47 ],
#         [0.518],
#         [0.531],
#         [0.481],
#         [0.446]],
#
#        [[0.182],
#         [0.339],
#         [0.469],
#         [0.511],
#         [0.544],
#         [0.492],
#         [0.453]],
#
#        [[0.18 ],
#         [0.335],
#         [0.468],
#         [0.519],
#         [0.539],
#         [0.472],
#         [0.447]],
#
#        [[0.177],
#         [0.335],
#         [0.468],
#         [0.518],
#         [0.541],
#         [0.498],
#         [0.455]],
#
#        [[0.176],
#         [0.337],
#         [0.464],
#         [0.509],
#         [0.546],
#         [0.476],
#         [0.441]],
#
#        [[0.181],
#         [0.333],
#         [0.463],
#         [0.514],
#         [0.533],
#         [0.498],
#         [0.433]],
#
#        [[0.181],
#         [0.333],
#         [0.468],
#         [0.514],
#         [0.535],
#         [0.482],
#         [0.448]],
#
#        [[0.181],
#         [0.334],
#         [0.467],
#         [0.516],
#         [0.54 ],
#         [0.48 ],
#         [0.441]],
#
#        [[0.182],
#         [0.336],
#         [0.467],
#         [0.52 ],
#         [0.535],
#         [0.483],
#         [0.446]],
#
#        [[0.177],
#         [0.339],
#         [0.468],
#         [0.512],
#         [0.529],
#         [0.485],
#         [0.455]],
#
#        [[0.181],
#         [0.348],
#         [0.466],
#         [0.508],
#         [0.527],
#         [0.492],
#         [0.459]],
#
#        [[0.18 ],
#         [0.345],
#         [0.468],
#         [0.524],
#         [0.538],
#         [0.486],
#         [0.409]],
#
#        [[0.178],
#         [0.34 ],
#         [0.469],
#         [0.527],
#         [0.54 ],
#         [0.49 ],
#         [0.404]],
#
#        [[0.189],
#         [0.336],
#         [0.47 ],
#         [0.526],
#         [0.534],
#         [0.496],
#         [0.439]],
#
#        [[0.191],
#         [0.336],
#         [0.469],
#         [0.53 ],
#         [0.527],
#         [0.493],
#         [0.46 ]],
#
#        [[0.189],
#         [0.336],
#         [0.466],
#         [0.525],
#         [0.52 ],
#         [0.515],
#         [0.443]],
#
#        [[0.186],
#         [0.337],
#         [0.467],
#         [0.517],
#         [0.525],
#         [0.495],
#         [0.425]],
#
#        [[0.193],
#         [0.328],
#         [0.464],
#         [0.516],
#         [0.519],
#         [0.509],
#         [0.447]],
#
#        [[0.194],
#         [0.322],
#         [0.465],
#         [0.525],
#         [0.536],
#         [0.511],
#         [0.438]],
#
#        [[0.199],
#         [0.323],
#         [0.466],
#         [0.522],
#         [0.532],
#         [0.499],
#         [0.377]],
#
#        [[0.199],
#         [0.316],
#         [0.468],
#         [0.513],
#         [0.547],
#         [0.5  ],
#         [0.417]],
#
#        [[0.195],
#         [0.32 ],
#         [0.467],
#         [0.513],
#         [0.532],
#         [0.508],
#         [0.38 ]],
#
#        [[0.195],
#         [0.32 ],
#         [0.473],
#         [0.516],
#         [0.536],
#         [0.501],
#         [0.44 ]],
#
#        [[0.192],
#         [0.317],
#         [0.47 ],
#         [0.522],
#         [0.532],
#         [0.504],
#         [0.43 ]],
#
#        [[0.19 ],
#         [0.316],
#         [0.475],
#         [0.51 ],
#         [0.524],
#         [0.501],
#         [0.409]],
#
#        [[0.189],
#         [0.316],
#         [0.469],
#         [0.521],
#         [0.522],
#         [0.502],
#         [0.407]],
#
#        [[0.188],
#         [0.313],
#         [0.47 ],
#         [0.523],
#         [0.532],
#         [0.517],
#         [0.434]],
#
#        [[0.188],
#         [0.316],
#         [0.475],
#         [0.523],
#         [0.531],
#         [0.495],
#         [0.448]],
#
#        [[0.188],
#         [0.318],
#         [0.474],
#         [0.526],
#         [0.529],
#         [0.507],
#         [0.435]],
#
#        [[0.194],
#         [0.32 ],
#         [0.47 ],
#         [0.532],
#         [0.528],
#         [0.498],
#         [0.425]],
#
#        [[0.195],
#         [0.315],
#         [0.474],
#         [0.525],
#         [0.541],
#         [0.501],
#         [0.431]],
#
#        [[0.193],
#         [0.321],
#         [0.478],
#         [0.518],
#         [0.532],
#         [0.499],
#         [0.451]],
#
#        [[0.194],
#         [0.32 ],
#         [0.476],
#         [0.517],
#         [0.531],
#         [0.517],
#         [0.448]]]), 'hsic_zc': array([[[0.087],
#         [0.143],
#         [0.172],
#         [0.188],
#         [0.193],
#         [0.185],
#         [0.167]],
#
#        [[0.011],
#         [0.062],
#         [0.185],
#         [0.09 ],
#         [0.012],
#         [0.025],
#         [0.162]],
#
#        [[0.012],
#         [0.022],
#         [0.054],
#         [0.014],
#         [0.013],
#         [0.053],
#         [0.156]],
#
#        [[0.012],
#         [0.022],
#         [0.064],
#         [0.011],
#         [0.009],
#         [0.011],
#         [0.149]],
#
#        [[0.011],
#         [0.018],
#         [0.063],
#         [0.014],
#         [0.01 ],
#         [0.033],
#         [0.146]],
#
#        [[0.014],
#         [0.016],
#         [0.083],
#         [0.013],
#         [0.011],
#         [0.034],
#         [0.135]],
#
#        [[0.012],
#         [0.015],
#         [0.049],
#         [0.016],
#         [0.022],
#         [0.019],
#         [0.147]],
#
#        [[0.016],
#         [0.018],
#         [0.057],
#         [0.022],
#         [0.034],
#         [0.005],
#         [0.159]],
#
#        [[0.014],
#         [0.015],
#         [0.046],
#         [0.024],
#         [0.017],
#         [0.005],
#         [0.133]],
#
#        [[0.015],
#         [0.015],
#         [0.038],
#         [0.029],
#         [0.013],
#         [0.006],
#         [0.122]],
#
#        [[0.014],
#         [0.014],
#         [0.039],
#         [0.031],
#         [0.082],
#         [0.004],
#         [0.133]],
#
#        [[0.017],
#         [0.016],
#         [0.043],
#         [0.016],
#         [0.017],
#         [0.013],
#         [0.114]],
#
#        [[0.016],
#         [0.014],
#         [0.037],
#         [0.015],
#         [0.017],
#         [0.009],
#         [0.109]],
#
#        [[0.015],
#         [0.014],
#         [0.03 ],
#         [0.015],
#         [0.042],
#         [0.012],
#         [0.108]],
#
#        [[0.019],
#         [0.012],
#         [0.028],
#         [0.018],
#         [0.053],
#         [0.011],
#         [0.101]],
#
#        [[0.02 ],
#         [0.013],
#         [0.033],
#         [0.024],
#         [0.033],
#         [0.01 ],
#         [0.102]],
#
#        [[0.019],
#         [0.012],
#         [0.03 ],
#         [0.025],
#         [0.03 ],
#         [0.011],
#         [0.088]],
#
#        [[0.02 ],
#         [0.012],
#         [0.028],
#         [0.029],
#         [0.018],
#         [0.008],
#         [0.086]],
#
#        [[0.019],
#         [0.013],
#         [0.021],
#         [0.029],
#         [0.022],
#         [0.014],
#         [0.086]],
#
#        [[0.025],
#         [0.011],
#         [0.023],
#         [0.029],
#         [0.022],
#         [0.023],
#         [0.081]],
#
#        [[0.017],
#         [0.012],
#         [0.023],
#         [0.039],
#         [0.032],
#         [0.027],
#         [0.082]],
#
#        [[0.016],
#         [0.013],
#         [0.022],
#         [0.026],
#         [0.033],
#         [0.018],
#         [0.064]],
#
#        [[0.019],
#         [0.011],
#         [0.022],
#         [0.038],
#         [0.027],
#         [0.053],
#         [0.069]],
#
#        [[0.02 ],
#         [0.012],
#         [0.019],
#         [0.028],
#         [0.038],
#         [0.031],
#         [0.052]],
#
#        [[0.02 ],
#         [0.015],
#         [0.026],
#         [0.027],
#         [0.033],
#         [0.022],
#         [0.032]],
#
#        [[0.019],
#         [0.012],
#         [0.027],
#         [0.023],
#         [0.02 ],
#         [0.025],
#         [0.039]],
#
#        [[0.019],
#         [0.011],
#         [0.02 ],
#         [0.018],
#         [0.031],
#         [0.026],
#         [0.02 ]],
#
#        [[0.019],
#         [0.011],
#         [0.019],
#         [0.018],
#         [0.038],
#         [0.03 ],
#         [0.01 ]],
#
#        [[0.018],
#         [0.011],
#         [0.027],
#         [0.02 ],
#         [0.037],
#         [0.017],
#         [0.016]],
#
#        [[0.019],
#         [0.011],
#         [0.026],
#         [0.022],
#         [0.022],
#         [0.02 ],
#         [0.064]],
#
#        [[0.019],
#         [0.011],
#         [0.022],
#         [0.018],
#         [0.025],
#         [0.03 ],
#         [0.023]],
#
#        [[0.019],
#         [0.011],
#         [0.028],
#         [0.034],
#         [0.023],
#         [0.018],
#         [0.011]],
#
#        [[0.02 ],
#         [0.011],
#         [0.027],
#         [0.029],
#         [0.02 ],
#         [0.015],
#         [0.007]],
#
#        [[0.021],
#         [0.012],
#         [0.026],
#         [0.039],
#         [0.02 ],
#         [0.019],
#         [0.008]],
#
#        [[0.021],
#         [0.012],
#         [0.02 ],
#         [0.026],
#         [0.02 ],
#         [0.034],
#         [0.017]],
#
#        [[0.021],
#         [0.014],
#         [0.024],
#         [0.04 ],
#         [0.022],
#         [0.025],
#         [0.005]],
#
#        [[0.02 ],
#         [0.01 ],
#         [0.03 ],
#         [0.021],
#         [0.031],
#         [0.05 ],
#         [0.004]],
#
#        [[0.019],
#         [0.01 ],
#         [0.04 ],
#         [0.031],
#         [0.036],
#         [0.056],
#         [0.027]],
#
#        [[0.021],
#         [0.01 ],
#         [0.035],
#         [0.025],
#         [0.029],
#         [0.028],
#         [0.005]],
#
#        [[0.023],
#         [0.009],
#         [0.028],
#         [0.033],
#         [0.024],
#         [0.023],
#         [0.002]],
#
#        [[0.026],
#         [0.009],
#         [0.02 ],
#         [0.025],
#         [0.034],
#         [0.031],
#         [0.006]],
#
#        [[0.025],
#         [0.01 ],
#         [0.026],
#         [0.021],
#         [0.025],
#         [0.012],
#         [0.005]],
#
#        [[0.025],
#         [0.01 ],
#         [0.02 ],
#         [0.04 ],
#         [0.041],
#         [0.024],
#         [0.001]],
#
#        [[0.026],
#         [0.011],
#         [0.02 ],
#         [0.025],
#         [0.029],
#         [0.017],
#         [0.007]],
#
#        [[0.023],
#         [0.012],
#         [0.018],
#         [0.023],
#         [0.034],
#         [0.006],
#         [0.004]],
#
#        [[0.021],
#         [0.01 ],
#         [0.02 ],
#         [0.029],
#         [0.03 ],
#         [0.016],
#         [0.001]],
#
#        [[0.021],
#         [0.01 ],
#         [0.025],
#         [0.024],
#         [0.027],
#         [0.017],
#         [0.011]],
#
#        [[0.022],
#         [0.01 ],
#         [0.032],
#         [0.023],
#         [0.031],
#         [0.012],
#         [0.015]],
#
#        [[0.022],
#         [0.01 ],
#         [0.024],
#         [0.025],
#         [0.022],
#         [0.022],
#         [0.003]],
#
#        [[0.021],
#         [0.01 ],
#         [0.03 ],
#         [0.028],
#         [0.025],
#         [0.015],
#         [0.002]],
#
#        [[0.022],
#         [0.009],
#         [0.024],
#         [0.04 ],
#         [0.02 ],
#         [0.008],
#         [0.002]]])}

# %%
res.keys()
# Out:
# dict_keys(['params', 'path'])

# %%
res["path"].keys()
# Out:
# dict_keys(['loss', 'hsic_rx_ax', 'hsic_ry_ay', 'hsic_resids', 'hsic_zx_zy', 'hsic_zx_zc', 'hsic_zy_zc', 'hsic_zy_x', 'hsic_indep', 'mse_rx', 'mse_ry', 'mses', 'hsic_zx', 'hsic_zy', 'hsic_zc'])

# %%
res["path"]["loss"].shape
# Out:
# (51, 7, 1)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["loss"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7fa0bc2f8310>,
#  <matplotlib.lines.Line2D at 0x7fa1b8341a90>,
#  <matplotlib.lines.Line2D at 0x7fa0bc4bef50>,
#  <matplotlib.lines.Line2D at 0x7fa0bc28a590>,
#  <matplotlib.lines.Line2D at 0x7fa0bc28a690>,
#  <matplotlib.lines.Line2D at 0x7fa0bc28a6d0>,
#  <matplotlib.lines.Line2D at 0x7fa0bc28a910>]

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["hsic_indep"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7fa0bc14a110>,
#  <matplotlib.lines.Line2D at 0x7fa0bc13a450>,
#  <matplotlib.lines.Line2D at 0x7fa0bc14a350>,
#  <matplotlib.lines.Line2D at 0x7fa0bc14a450>,
#  <matplotlib.lines.Line2D at 0x7fa0bc14a550>,
#  <matplotlib.lines.Line2D at 0x7fa0bc14a590>,
#  <matplotlib.lines.Line2D at 0x7fa0bc14a7d0>]

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["hsic_resids"][:,::,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7fa0bc06b050>,
#  <matplotlib.lines.Line2D at 0x7fa0bc05b2d0>,
#  <matplotlib.lines.Line2D at 0x7fa0bc06b290>,
#  <matplotlib.lines.Line2D at 0x7fa0bc06b390>,
#  <matplotlib.lines.Line2D at 0x7fa0bc06b490>,
#  <matplotlib.lines.Line2D at 0x7fa0bc06b4d0>,
#  <matplotlib.lines.Line2D at 0x7fa0bc06b710>]

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["mses"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7fa0a7fe1990>,
#  <matplotlib.lines.Line2D at 0x7fa0a7fd4c50>,
#  <matplotlib.lines.Line2D at 0x7fa0a7fe1bd0>,
#  <matplotlib.lines.Line2D at 0x7fa0a7fe1cd0>,
#  <matplotlib.lines.Line2D at 0x7fa0a7fe1dd0>,
#  <matplotlib.lines.Line2D at 0x7fa0a7fe1e10>,
#  <matplotlib.lines.Line2D at 0x7fa0a7fe1f50>]

# %% [markdown]
# ## resids

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["hsic_rx_ax"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7fa0a7f71d50>,
#  <matplotlib.lines.Line2D at 0x7fa0a7f62fd0>,
#  <matplotlib.lines.Line2D at 0x7fa0a7f71f90>,
#  <matplotlib.lines.Line2D at 0x7fa0a7f71fd0>,
#  <matplotlib.lines.Line2D at 0x7fa0a7f001d0>,
#  <matplotlib.lines.Line2D at 0x7fa0a7f00210>,
#  <matplotlib.lines.Line2D at 0x7fa0a7f00450>]

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["hsic_ry_ay"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7fa0a7e98050>,
#  <matplotlib.lines.Line2D at 0x7fa0a7e882d0>,
#  <matplotlib.lines.Line2D at 0x7fa0a7e98290>,
#  <matplotlib.lines.Line2D at 0x7fa0a7e98390>,
#  <matplotlib.lines.Line2D at 0x7fa0a7e98490>,
#  <matplotlib.lines.Line2D at 0x7fa0a7e984d0>,
#  <matplotlib.lines.Line2D at 0x7fa0a7e98710>]

# %% [markdown]
# ## indeps

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["hsic_zx_zy"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7fa0a7e24510>,
#  <matplotlib.lines.Line2D at 0x7fa0a7e16890>,
#  <matplotlib.lines.Line2D at 0x7fa0a7e24750>,
#  <matplotlib.lines.Line2D at 0x7fa0a7e24850>,
#  <matplotlib.lines.Line2D at 0x7fa0a7e24950>,
#  <matplotlib.lines.Line2D at 0x7fa0a7e24990>,
#  <matplotlib.lines.Line2D at 0x7fa0a7e24bd0>]

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["hsic_zx_zc"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7fa0a7db3410>,
#  <matplotlib.lines.Line2D at 0x7fa0a7da56d0>,
#  <matplotlib.lines.Line2D at 0x7fa0a7db3650>,
#  <matplotlib.lines.Line2D at 0x7fa0a7db3750>,
#  <matplotlib.lines.Line2D at 0x7fa0a7db3850>,
#  <matplotlib.lines.Line2D at 0x7fa0a7db3890>,
#  <matplotlib.lines.Line2D at 0x7fa0a7db3ad0>]

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["hsic_zy_zc"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7fa0a7cc82d0>,
#  <matplotlib.lines.Line2D at 0x7fa0a7d38590>,
#  <matplotlib.lines.Line2D at 0x7fa0a7cc8510>,
#  <matplotlib.lines.Line2D at 0x7fa0a7cc8610>,
#  <matplotlib.lines.Line2D at 0x7fa0a7cc8710>,
#  <matplotlib.lines.Line2D at 0x7fa0a7cc8750>,
#  <matplotlib.lines.Line2D at 0x7fa0a7cc8990>]

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["hsic_zy_x"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7fa0a7c5bad0>,
#  <matplotlib.lines.Line2D at 0x7fa0a7c48e90>,
#  <matplotlib.lines.Line2D at 0x7fa0a7c5bd10>,
#  <matplotlib.lines.Line2D at 0x7fa0a7c5be10>,
#  <matplotlib.lines.Line2D at 0x7fa0a7c5bf10>,
#  <matplotlib.lines.Line2D at 0x7fa0a7c6a090>,
#  <matplotlib.lines.Line2D at 0x7fa0a7c6a1d0>]

# %% [markdown]
# # mses

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["mse_rx"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7fa0a7bf7090>,
#  <matplotlib.lines.Line2D at 0x7fa0a7be9350>,
#  <matplotlib.lines.Line2D at 0x7fa0a7bf72d0>,
#  <matplotlib.lines.Line2D at 0x7fa0a7bf73d0>,
#  <matplotlib.lines.Line2D at 0x7fa0a7bf74d0>,
#  <matplotlib.lines.Line2D at 0x7fa0a7bf7510>,
#  <matplotlib.lines.Line2D at 0x7fa0a7bf7750>]

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["mse_ry"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7fa0a7b10290>,
#  <matplotlib.lines.Line2D at 0x7fa0a7b01510>,
#  <matplotlib.lines.Line2D at 0x7fa0a7b104d0>,
#  <matplotlib.lines.Line2D at 0x7fa0a7b105d0>,
#  <matplotlib.lines.Line2D at 0x7fa0a7b106d0>,
#  <matplotlib.lines.Line2D at 0x7fa0a7b10710>,
#  <matplotlib.lines.Line2D at 0x7fa0a7b10950>]

# %% [markdown]
# ## zs vs z_est

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["hsic_zx"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7fa0a7a9b890>,
#  <matplotlib.lines.Line2D at 0x7fa0a7a8eb50>,
#  <matplotlib.lines.Line2D at 0x7fa0a7a9bad0>,
#  <matplotlib.lines.Line2D at 0x7fa0a7a9bbd0>,
#  <matplotlib.lines.Line2D at 0x7fa0a7a9bcd0>,
#  <matplotlib.lines.Line2D at 0x7fa0a7a9bd10>,
#  <matplotlib.lines.Line2D at 0x7fa0a7a9bf50>]

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["hsic_zy"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7fa0a7a2c790>,
#  <matplotlib.lines.Line2D at 0x7fa0a7a1da10>,
#  <matplotlib.lines.Line2D at 0x7fa0a7a2c9d0>,
#  <matplotlib.lines.Line2D at 0x7fa0a7a2cad0>,
#  <matplotlib.lines.Line2D at 0x7fa0a7a2cbd0>,
#  <matplotlib.lines.Line2D at 0x7fa0a7a2cc10>,
#  <matplotlib.lines.Line2D at 0x7fa0a7a2ce50>]

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["hsic_zc"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7fa0a7943a10>,
#  <matplotlib.lines.Line2D at 0x7fa0a79b6c90>,
#  <matplotlib.lines.Line2D at 0x7fa0a7943c50>,
#  <matplotlib.lines.Line2D at 0x7fa0a7943d50>,
#  <matplotlib.lines.Line2D at 0x7fa0a7943e50>,
#  <matplotlib.lines.Line2D at 0x7fa0a7943e90>,
#  <matplotlib.lines.Line2D at 0x7fa0a7943fd0>]

# %% [markdown]
# ## solution

# %%
params = res["params"]

# %%
params["alpha_x"].shape
# Out:
# (1000, 7)

# %%
N = x.shape[0]
    

D_x = covariance_matrix(sqeuclidean_distance, x, x)
sigma_x_med = 1 / np.median(D_x)
K_x = rbf_kernel_matrix({'gamma': sigma_x_med}, x, x)

D_y = covariance_matrix(sqeuclidean_distance, y, y)
sigma_y = 1 / np.median(D_y)
K_y = rbf_kernel_matrix({'gamma': sigma_y}, y, y)
    
D_u = covariance_matrix(sqeuclidean_distance, U, U)
sigma_u = 1 / np.median(D_u)
K_u = rbf_kernel_matrix({'gamma': sigma_u}, U, U)

# %%
rep = 3
alpha_x = params["alpha_x"][:,rep][:,None]
alpha_y = params["alpha_y"][:,rep][:,None]
alpha_c = params["alpha_c"][:,rep][:,None]
    
zx = K_u@alpha_x
zy = K_u@alpha_y
zc = K_u@alpha_c
    
zx = (zx - np.mean(zx)) / (np.std(zx))
zy = (zy - np.mean(zy)) / (np.std(zy))
zc = (zc - np.mean(zc)) / (np.std(zc))

    
sig_x_h = np.exp(params["ln_sig_x_h"])
sig_zx_h = np.exp(params["ln_sig_zx_h"])
sig_zy_h = np.exp(params["ln_sig_zy_h"])
sig_zc_h = np.exp(params["ln_sig_zc_h"])
sig_rx_h = np.exp(params["ln_sig_rx_h"])
sig_ry_h = np.exp(params["ln_sig_ry_h"])
    


sig_x_f = np.exp(params["ln_sig_x_f"])
sig_zx_f = np.exp(params["ln_sig_zx_f"])
sig_zy_f = np.exp(params["ln_sig_zy_f"])
sig_zc_f = np.exp(params["ln_sig_zc_f"])
    
    
sigs_f = np.hstack([sig_x_f, sig_zx_f, sig_zy_f, sig_zc_f])
K_ax_f, K_ay_f, K_ax_h, K_ay_h, K_x_h, K_zx_h, K_zy_h, K_zc_h = kernel_mat_LNC(D_x, x, zx, zy, zc, sig_x_h, sig_zx_h, sig_zy_h, sig_zc_h, sigs_f) 
n = K_ax_f.shape[0]

ws = np.ones(n)
weights_y, resids_y, y_hat = krrModel(lam, K_ay_f, y, ws)
weights_x, resids_x, x_hat = krrModel(lam, K_ax_f, x, ws)

# %%
(alpha_x*np.ones(7))[0:10,:]
# Out:
# DeviceArray([[-757.008, -757.008, -757.008, -757.008, -757.008, -757.008,
#               -757.008],
#              [ 137.805,  137.805,  137.805,  137.805,  137.805,  137.805,
#                137.805],
#              [2982.975, 2982.975, 2982.975, 2982.975, 2982.975, 2982.975,
#               2982.975],
#              [-603.319, -603.319, -603.319, -603.319, -603.319, -603.319,
#               -603.319],
#              [-330.53 , -330.53 , -330.53 , -330.53 , -330.53 , -330.53 ,
#               -330.53 ],
#              [ 186.284,  186.284,  186.284,  186.284,  186.284,  186.284,
#                186.284],
#              [ 123.764,  123.764,  123.764,  123.764,  123.764,  123.764,
#                123.764],
#              [-134.77 , -134.77 , -134.77 , -134.77 , -134.77 , -134.77 ,
#               -134.77 ],
#              [  -6.1  ,   -6.1  ,   -6.1  ,   -6.1  ,   -6.1  ,   -6.1  ,
#                 -6.1  ],
#              [-183.721, -183.721, -183.721, -183.721, -183.721, -183.721,
#               -183.721]], dtype=float32)

# %%
plt.scatter(x, x_hat)

# %%
_, _, xu_hat = krrModel(lam, K_u, x, ws)

# %%
plt.scatter(x, xu_hat)

# %%
plt.scatter(y, y_hat)

# %%
K_ayu_f  = K_x_h*K_u

# %%
weights_yu, resids_yu, yu_hat = krrModel(lam, K_ayu_f, y, ws)

# %%
plt.scatter(y, yu_hat)

# %%
_, _, yx_hat = krrModel(lam, K_x_h, y, ws)

# %%
plt.scatter(y, yx_hat)
