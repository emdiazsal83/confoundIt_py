# %%
import sys

# %%
sys.path.insert(1,'../src')
sys.path.insert(1,'../src/ITE-1.1_code')

# %%
from latentNoise_funcs_gen   import *
# Out:
# [1] "in func_entropy_v1.R"
# $platform
# [1] "x86_64-conda-linux-gnu"
#
# $arch
# [1] "x86_64"
#
# $os
# [1] "linux-gnu"
#
# $system
# [1] "x86_64, linux-gnu"
#
# $status
# [1] ""
#
# $major
# [1] "4"
#
# $minor
# [1] "0.5"
#
# $year
# [1] "2021"
#
# $month
# [1] "03"
#
# $day
# [1] "31"
#
# $`svn rev`
# [1] "80133"
#
# $language
# [1] "R"
#
# $version.string
# [1] "R version 4.0.5 (2021-03-31)"
#
# $nickname
# [1] "Shake and Throw"
#
# enters latentNoise_funcs_gen.py

# %% [markdown]
# # Generate Data

# %% [markdown]
# ## generate $z_x,z_y,z_c$

# %% [markdown]
# ## generate $x$

# %% [markdown]
# ## generate $y$

# %% [markdown]
# ## generate $u$

# %% [markdown]
# # Adapt ln-krr

# %% [markdown]
# ## Adapt model function

# %% [markdown]
# ## Adapt loss function

# %%
@jax.jit
def getDataLoss_LNC(smpl, loss_data):
    
    x, y, Z, K_u, D_x, K_y, D_y, K_x = loss_data 
    

    D_x_aux = D_x[smpl, :]
    D_x_aux = D_x_aux[:, smpl]
    #K_zmani_aux = K_zmani[smpl,:]
    #K_zmani_aux = K_zmani_aux[:,smpl]
    K_y_aux = K_y[smpl,:]
    K_y_aux = K_y_aux[:,smpl]
    K_u_aux = K_u[smpl,:]
    #K_u_aux = K_u_aux[:,smpl]
                
    x_aux = x[smpl,]
    y_aux = y[smpl,]
    

    if Z is not None:
        Z_aux = Z[smpl,]
    else:
        Z_aux = None
        
            
    return x_aux, y_aux, Z_aux, K_u_aux, D_x_aux, K_y_aux, None, None

# %%
onp.random.normal(size=100)[:,None].shape
# Out:
# (100, 1)

# %%
from sklearn.manifold import Isomap


def getIniPar_LNC(reps, loss_data, pars, smplsParts): #N, m, reps, y, M
    
    
    _, _, lam, _ , _ = pars 
    x, y, Z, K_u, D_x, K_y, D_y, K_x = loss_data
    
    n = x.shape[0]
    

    # initialize z_x to x, z_y to y and z_c manifold of z_c
    # we actually have to initialize alpha_x, alpha_y and alpha_c so in each case
    # we have to work out what z = U*alpha -> cholesky decomposition of U
    
    zx_ini = x
    zy_ini = y 
    
    embedding = Isomap(n_components=10)
    xy = onp.hstack([x, y])
    xy_transformed = embedding.fit_transform(xy)
    zc_ini = np.array(xy_transformed[:,3])[:,None]
    
    
    #L = linalg.cho_factor(np.dot(U.T, U) + 0.0001 * np.eye(m))
    #alpha_x = linalg.cho_solve(L, np.dot(U.T, zx_ini))
    #alpha_y = linalg.cho_solve(L, np.dot(U.T, zy_ini))
    #alpha_c = linalg.cho_solve(L, np.dot(U.T, zc_ini))
    
    
    ws = np.ones(n)
    alpha_x, _, _ = krrModel(lam, K_u, zx_ini, ws)
    alpha_x = alpha_x * np.ones(reps)
    alpha_y, _, _ = krrModel(lam, K_u, zy_ini, ws)
    alpha_y = alpha_y * np.ones(reps)
    alpha_c, _, _ = krrModel(lam, K_u, zc_ini, ws)
    alpha_c = alpha_c * np.ones(reps)
    
    #alpha_x = onp.random.normal(size=(n,reps))#[:,None]
    #alpha_y = onp.random.normal(size=(n,reps))#[:,None]
    #alpha_c = onp.random.normal(size=(n,reps))#[:,None]
    
    
    params = {
            'alpha_x': alpha_x,
            'alpha_y': alpha_y,
            'alpha_c': alpha_c,
    }
    
    #onp.random.seed(seed=4)
    
    zx_ini = np.array(onp.apply_along_axis(normalize, 0, zx_ini))
    zy_ini = np.array(onp.apply_along_axis(normalize, 0, zy_ini))
    zc_ini = np.array(onp.apply_along_axis(normalize, 0, zc_ini))
    

    
    sigma_x_med = 1 / np.median(D_x)
    sigma_y = 1 / np.median(D_y)
    

    
    D_zx = covariance_matrix(sqeuclidean_distance, zx_ini, zx_ini)
    sigma_zx_med = 1 / np.median(D_zx)
    
    D_zy= covariance_matrix(sqeuclidean_distance, zy_ini, zy_ini)
    sigma_zy_med = 1 / np.median(D_zy)
    
    D_zc = covariance_matrix(sqeuclidean_distance, zc_ini, zc_ini)
    sigma_zc_med = 1 / np.median(D_zc)
    
    
    
    K_zx = rbf_kernel_matrix({'gamma': sigma_zx_med}, zx_ini, zx_ini)
    K_zy = rbf_kernel_matrix({'gamma': sigma_zy_med}, zy_ini, zy_ini)
    K_zc = rbf_kernel_matrix({'gamma': sigma_zc_med}, zc_ini, zc_ini)
    K_yhat = K_x*K_zc*K_zy
    K_xhat = K_zc*K_zx

    
    smplPart1 = smplsParts[0]
    N_part1 = smplPart1.shape[0]
    y_part1 = y[smplPart1,]
    x_part1 = x[smplPart1,]
    K_yhat_part1 = K_yhat[smplPart1, :]
    K_yhat_part1 = K_yhat_part1[:, smplPart1]
    K_xhat_part1 = K_xhat[smplPart1, :]
    K_xhat_part1 = K_xhat_part1[:, smplPart1]
    ws = np.ones(N_part1)
    
    
    weights_y, resids_y, y_hat = krrModel(lam, K_yhat_part1, y_part1, ws)
    weights_x, resids_x, x_hat = krrModel(lam, K_xhat_part1, x_part1, ws)
    
    # right now we simply overwrite residual lengthscale sig_r_h to be median heuristic
    distsRx = covariance_matrix(sqeuclidean_distance, resids_x, resids_x)
    sigma_rx_med = 1 / np.quantile(distsRx, 0.5)
    distsRy = covariance_matrix(sqeuclidean_distance, resids_y, resids_y)
    sigma_ry_med = 1 / np.quantile(distsRy, 0.5)
    
    

    qs = [0.1, 0.3, 0.5, 0.7,0.9,0.99, 1]
    qs_smpl_zx_f = np.array(qs)
    sigs_zx_f= 1/np.quantile(D_zx, qs_smpl_zx_f)
    
    qs_smpl_zy_f = np.array(qs)
    sigs_zy_f= 1/np.quantile(D_zy, qs_smpl_zy_f)
    
    qs_smpl_zc_f = np.array(qs)
    sigs_zc_f= 1/np.quantile(D_zc, qs_smpl_zc_f)
    
    
    sigs_x_f= sigma_x_med * np.ones(reps)
    
    sigs_zx_h= sigma_zx_med * np.ones(reps)
    sigs_zy_h= sigma_zy_med * np.ones(reps)
    sigs_zc_h= sigma_zc_med * np.ones(reps)
    sigs_x_h= sigma_x_med * np.ones(reps)
    sigs_rx_h= sigma_rx_med * np.ones(reps)
    sigs_ry_h= sigma_rx_med * np.ones(reps)
    
    params['ln_sig_zx_f']= np.log(sigs_zx_f)
    params['ln_sig_zy_f']= np.log(sigs_zy_f)
    params['ln_sig_zc_f']= np.log(sigs_zc_f)
    params['ln_sig_x_f']= np.log(sigs_x_f)
    
    params['ln_sig_zx_h']= np.log(sigs_zx_h)
    params['ln_sig_zy_h']= np.log(sigs_zy_h)
    params['ln_sig_zc_h']= np.log(sigs_zc_h)
    params['ln_sig_x_h']= np.log(sigs_x_h)
    params['ln_sig_rx_h']= np.log(sigs_rx_h)
    params['ln_sig_ry_h']= np.log(sigs_ry_h)
    
    
    return params

# %%
@jax.jit
def kernel_mat_LNC(D_x, x, zx, zy, zc, sig_x_h, sig_zx_h, sig_zy_h, sig_zc_h, sigs_f):
    # sigs_f = np.hstack([sig_x_f, sig_zx_f, sig_zy_f, sig_zc_f])
    sig_x_f = sigs_f[0]
    sig_zx_f = sigs_f[1]
    sig_zy_f = sigs_f[2]
    sig_zc_f = sigs_f[3]
    
    K_x_f = np.exp(-sig_x_f * D_x)
    K_zx_f = rbf_kernel_matrix({'gamma': sig_zx_f}, zx, zx)
    K_zy_f = rbf_kernel_matrix({'gamma': sig_zy_f}, zy, zy)
    K_zc_f = rbf_kernel_matrix({'gamma': sig_zc_f}, zc, zc)
    

    K_x_h = K_x_f #np.exp(-sig_x_h * D_x)
    K_zx_h = K_zx_f #rbf_kernel_matrix({'gamma': sig_z_h}, z, z)
    K_zy_h = K_zy_f #rbf_kernel_matrix({'gamma': sig_z_h}, z, z)
    K_zc_h = K_zc_f #rbf_kernel_matrix({'gamma': sig_z_h}, z, z)
    # x causes - to compare to rx
    K_ax_h = K_zx_h * K_zc_h
    # y causes - to compare to ry
    K_ay_h = K_x_h*K_zy_h * K_zc_h
    #K_a_f = 2 * K_x_f + 2 * K_z_f + K_xz_f + K_zx_f
    K_ax_f = K_ax_h
    K_ay_f = K_ay_h

    return K_ax_f, K_ay_f, K_ax_h, K_ay_h, K_x_h, K_zx_h, K_zy_h, K_zc_h

# %%
# loss 
@jax.jit
def loss_LNC(params, pars, loss_data, ws):
    
    beta, neta, lam, nu, lu = pars 
    
    
    x, y, Z, K_u, D_x, K_y, D_y, K_x = loss_data
    
    alpha_x = params["alpha_x"]
    alpha_y = params["alpha_y"]
    alpha_c = params["alpha_c"]
    
    zx = K_u@alpha_x
    zy = K_u@alpha_y
    zc = K_u@alpha_c
    
    zx = (zx - np.mean(zx)) / (np.std(zx))
    zy = (zy - np.mean(zy)) / (np.std(zy))
    zc = (zc - np.mean(zc)) / (np.std(zc))

    
    sig_x_h = np.exp(params["ln_sig_x_h"])
    sig_zx_h = np.exp(params["ln_sig_zx_h"])
    sig_zy_h = np.exp(params["ln_sig_zy_h"])
    sig_zc_h = np.exp(params["ln_sig_zc_h"])
    sig_rx_h = np.exp(params["ln_sig_rx_h"])
    sig_ry_h = np.exp(params["ln_sig_ry_h"])
    


    sig_x_f = np.exp(params["ln_sig_x_f"])
    sig_zx_f = np.exp(params["ln_sig_zx_f"])
    sig_zy_f = np.exp(params["ln_sig_zy_f"])
    sig_zc_f = np.exp(params["ln_sig_zc_f"])
    
    
    sigs_f = np.hstack([sig_x_f, sig_zx_f, sig_zy_f, sig_zc_f])
    K_ax_f, K_ay_f, K_ax_h, K_ay_h, K_x_h, K_zx_h, K_zy_h, K_zc_h = kernel_mat_LNC(D_x, x, zx, zy, zc, sig_x_h, sig_zx_h, sig_zy_h, sig_zc_h, sigs_f) 
    n = K_ax_f.shape[0]
 
    weights_y, resids_y, y_hat = krrModel(lam, K_ay_f, y, ws)
    weights_x, resids_x, x_hat = krrModel(lam, K_ax_f, x, ws)
    
    # right now we simply overwrite residual lengthscale sig_r_h to be median heuristic
    distsRx = covariance_matrix(sqeuclidean_distance, resids_x, resids_x)
    sig_rx_h = 1 / np.quantile(distsRx, 0.5)
    distsRy = covariance_matrix(sqeuclidean_distance, resids_y, resids_y)
    sig_ry_h = 1 / np.quantile(distsRx, 0.5)
    


    K_rx_h = rbf_kernel_matrix({'gamma': sig_rx_h}, resids_x, resids_x)
    K_ry_h = rbf_kernel_matrix({'gamma': sig_ry_h}, resids_y, resids_y)

    
    # additivity
    # hsic resids_x, (zx, zc)
    hsic_rx_ax = hsic(K_rx_h, K_ax_h)
    # hsic resids_y, (x, zx, zc)
    hsic_ry_ay = hsic(K_ry_h, K_ay_h)
    hsic_resids = np.log(hsic_rx_ax) +  np.log(hsic_ry_ay)

    # indep causes: between (zx, zy, zc) and between zy and x
    hsic_zx_zy = hsic(K_zx_h, K_zy_h)
    #hsic_zx_zy = np.max(np.array([hsic_zx_zy, 0.01]))
    hsic_zx_zc = hsic(K_zx_h, K_zc_h)
    #hsic_zx_zc = np.max(np.array([hsic_zx_zc, 0.01]))
    hsic_zy_zc = hsic(K_zy_h, K_zc_h)
    #hsic_zy_zc = np.max(np.array([hsic_zy_zc, 0.01]))
    hsic_zy_x  = hsic(K_zy_h, K_x_h)
    #hsic_zy_x = np.max(np.array([hsic_zy_x, 0.01]))
    hsic_indep = np.log(hsic_zx_zy) + np.log(hsic_zx_zc) + np.log(hsic_zy_zc) + np.log(hsic_zy_x)
     
    # desirable hsics of x, y vs zc    
    hsic_x_zc = hsic(K_x_h, K_zc_h)
    hsic_y_zc = hsic(K_y, K_zc_h)
    hsic_xy_zc = np.log(hsic_x_zc) + np.log(hsic_y_zc)
    
    # mse residual
    mse_rx = mse(x, x_hat)
    mse_ry = mse(y, y_hat)
    mses = np.log(mse_rx) +  np.log(mse_ry)
    
    # CI condition
    
    # Zs size
    zx_norm = np.dot(zx.T, zx)[1,1]
    zy_norm = np.dot(zy.T, zy)[1,1]
    zc_norm = np.dot(zc.T, zc)[1,1]
    z_norm = np.log(zx_norm) + np.log(zy_norm) + np.log(zc_norm)
    
    # alpha_c norm
    alphac_norm = np.dot(alpha_c.T, alpha_c)[1,1]
    
    # calcualte compute los
    loss_value = 0*hsic_resids + beta * mses  + neta*hsic_indep   + nu*z_norm - hsic_xy_zc
    
    return loss_value

# %%
dloss_LNC = jax.grad(loss_LNC, )
dloss_LNC_jitted = jax.jit(dloss_LNC)

# %%
# for reporting purposes give back 3 terms separatley
@jax.jit
def model_LNC(params, lam, loss_data, K_t):

    x, y, Z, K_u, D_x, K_y, D_y, K_x = loss_data

    alpha_x = params["alpha_x"]
    alpha_y = params["alpha_y"]
    alpha_c = params["alpha_c"]
    
    zx = K_u@alpha_x
    zy = K_u@alpha_y
    zc = K_u@alpha_c
    
    zx = (zx - np.mean(zx)) / (np.std(zx))
    zy = (zy - np.mean(zy)) / (np.std(zy))
    zc = (zc - np.mean(zc)) / (np.std(zc))

    
    sig_x_h = np.exp(params["ln_sig_x_h"])
    sig_zx_h = np.exp(params["ln_sig_zx_h"])
    sig_zy_h = np.exp(params["ln_sig_zy_h"])
    sig_zc_h = np.exp(params["ln_sig_zc_h"])
    sig_rx_h = np.exp(params["ln_sig_rx_h"])
    sig_ry_h = np.exp(params["ln_sig_ry_h"])
    


    sig_x_f = np.exp(params["ln_sig_x_f"])
    sig_zx_f = np.exp(params["ln_sig_zx_f"])
    sig_zy_f = np.exp(params["ln_sig_zy_f"])
    sig_zc_f = np.exp(params["ln_sig_zc_f"])
    
    
    sigs_f = np.hstack([sig_x_f, sig_zx_f, sig_zy_f, sig_zc_f])
    K_ax_f, K_ay_f, K_ax_h, K_ay_h, K_x_h, K_zx_h, K_zy_h, K_zc_h = kernel_mat_LNC(D_x, x, zx, zy, zc, sig_x_h, sig_zx_h, sig_zy_h, sig_zc_h, sigs_f) 
    n = K_ax_f.shape[0]

    ws = np.ones(n)
    weights_y, resids_y, y_hat = krrModel(lam, K_ay_f, y, ws)
    weights_x, resids_x, x_hat = krrModel(lam, K_ax_f, x, ws)
    
    # right now we simply overwrite residual lengthscale sig_r_h to be median heuristic
    distsRx = covariance_matrix(sqeuclidean_distance, resids_x, resids_x)
    sig_rx_h = 1 / np.quantile(distsRx, 0.5)
    distsRy = covariance_matrix(sqeuclidean_distance, resids_y, resids_y)
    sig_ry_h = 1 / np.quantile(distsRx, 0.5)
    K_rx_h = rbf_kernel_matrix({'gamma': sig_rx_h}, resids_x, resids_x)
    K_ry_h = rbf_kernel_matrix({'gamma': sig_ry_h}, resids_y, resids_y)

    
    # additivity
    # hsic resids_x, (zx, zc)
    hsic_rx_ax = hsic(K_rx_h, K_ax_h)
    # hsic resids_y, (x, zx, zc)
    hsic_ry_ay = hsic(K_ry_h, K_ay_h)
    hsic_resids = np.log(hsic_rx_ax) +  np.log(hsic_ry_ay)

    
    # indep causes: between (zx, zy, zc) and between zy and x
    hsic_zx_zy = hsic(K_zx_h, K_zy_h)
    hsic_zx_zc = hsic(K_zx_h, K_zc_h)
    hsic_zy_zc = hsic(K_zy_h, K_zc_h)
    hsic_zy_x  = hsic(K_zy_h, K_x_h)
    hsic_indep = np.log(hsic_zx_zy) + np.log(hsic_zx_zc) + np.log(hsic_zy_zc) + np.log(hsic_zy_x)
     
    
    # desirable hsics of x, y vs zc    
    hsic_x_zc = hsic(K_x_h, K_zc_h)
    hsic_y_zc = hsic(K_y, K_zc_h)  
    hsic_xy_zc = np.log(hsic_x_zc) + np.log(hsic_y_zc)
        
    # mse residual
    mse_rx = mse(x, x_hat)
    mse_ry = mse(y, y_hat)
    mses = np.log(mse_rx) +  np.log(mse_ry)

    
    

    # hsic (zs, zs_reals)
    
    # only valid for "5_exponential1gaussian1_dependent_10_1_100.csv"
    # ix c(8, 2, 3)
    # iy c(1, 7, 6)
    # ic 10    
    zx_real = Z[:,[7,1,2]]
    zy_real = Z[:,[0,6,5]]
    zc_real = Z[:,9]
    
    distsZx_real = covariance_matrix(sqeuclidean_distance, zx_real, zx_real)
    sig_zx_real = 1 / np.quantile(distsZx_real, 0.5)
    K_zx_real = rbf_kernel_matrix({'gamma': sig_zx_real}, zx_real, zx_real)
    
    distsZy_real = covariance_matrix(sqeuclidean_distance, zy_real, zy_real)
    sig_zy_real = 1 / np.quantile(distsZy_real, 0.5)
    K_zy_real = rbf_kernel_matrix({'gamma': sig_zy_real}, zy_real, zy_real)
    
    distsZc_real = covariance_matrix(sqeuclidean_distance, zc_real, zc_real)
    sig_zc_real = 1 / np.quantile(distsZc_real, 0.5)
    K_zc_real = rbf_kernel_matrix({'gamma': sig_zc_real}, zc_real, zc_real)
    
    
    hsic_zx = hsic(K_zx_h, K_zx_real)
    hsic_zy = hsic(K_zy_h, K_zy_real)
    hsic_zc = hsic(K_zc_h, K_zc_real)
    
    imp_zx = hsic(K_zx_h, K_zc_real)
    imp_zy = hsic(K_zy_h, K_zc_real)
    
    
    
    monitor = {}
    monitor = {    
        'hsic_rx_ax': hsic_rx_ax,
        'hsic_ry_ay': hsic_ry_ay,
        'hsic_resids': hsic_resids,
        'hsic_zx_zy': hsic_zx_zy,
        'hsic_zx_zc': hsic_zx_zc,
        'hsic_zy_zc': hsic_zy_zc,
        'hsic_zy_x': hsic_zy_x,
        'hsic_indep': hsic_indep,
        'mse_rx': mse_rx,
        'mse_ry': mse_ry,
        'mses': mses,
        'hsic_zx': hsic_zx,
        'hsic_zy': hsic_zy,
        'hsic_zc': hsic_zc,
        'imp_zx': imp_zx,
        'imp_zy': imp_zy,
        'hsic_x_zc': hsic_x_zc,
        'hsic_y_zc': hsic_y_zc,
        'hsic_xy_zc': hsic_xy_zc
        
    }

    return monitor

# %%
@jax.jit
def getParamsForGrad_LNC(params, rep, smpl):

    
    
    ln_sig_x_h = params["ln_sig_x_h"][rep]
    ln_sig_zx_h = params["ln_sig_zx_h"][rep]
    ln_sig_zy_h = params["ln_sig_zy_h"][rep]
    ln_sig_zc_h = params["ln_sig_zc_h"][rep]
    ln_sig_rx_h = params["ln_sig_rx_h"][rep]
    ln_sig_ry_h = params["ln_sig_ry_h"][rep]
    


    ln_sig_x_f = params["ln_sig_x_f"][rep]
    ln_sig_zx_f = params["ln_sig_zx_f"][rep]
    ln_sig_zy_f = params["ln_sig_zy_f"][rep]
    ln_sig_zc_f = params["ln_sig_zc_f"][rep]
    
    
  
    params_aux = params.copy()

    alpha_x = params["alpha_x"][:, rep]
    alpha_y = params["alpha_y"][:, rep]
    alpha_c = params["alpha_c"][:, rep]
    alpha_x = alpha_x[:,None]
    alpha_y = alpha_y[:,None]
    alpha_c = alpha_c[:,None]
    
    
    params_aux['alpha_x'] = alpha_x
    params_aux['alpha_y'] = alpha_y
    params_aux['alpha_c'] = alpha_c
    
    params_aux["ln_sig_x_h"] = ln_sig_x_h
    params_aux["ln_sig_zx_h"] = ln_sig_zx_h
    params_aux["ln_sig_zy_h"] = ln_sig_zy_h
    params_aux["ln_sig_zc_h"] = ln_sig_zc_h
    params_aux["ln_sig_rx_h"] = ln_sig_rx_h
    params_aux["ln_sig_ry_h"] = ln_sig_ry_h
    

    params_aux["ln_sig_x_f"] = ln_sig_x_f
    params_aux["ln_sig_zx_f"] = ln_sig_zx_f
    params_aux["ln_sig_zy_f"] = ln_sig_zy_f
    params_aux["ln_sig_zc_f"] = ln_sig_zc_f


    return params_aux

# %%
def updateParams_LNC(params, grad_params, smpl, iteration, rep, learning_rate):
     
    #idx_rows = smpl[:, None]
    n = params['alpha_x'].shape[0]
    idx_rows = np.linspace(0, n - 1, n, dtype=int)[:, None]
    idx_cols = np.array(rep)[None, None]
    idx = jax.ops.index[tuple([idx_rows, idx_cols])]
    
    #alpha_x
    A = params['alpha_x'][tuple([idx_rows, idx_cols])]
    B = learning_rate * grad_params['alpha_x']
    params['alpha_x'] = index_update(params['alpha_x'], idx, A - B)
    
    #alpha_y
    A = params['alpha_y'][tuple([idx_rows, idx_cols])]
    B = learning_rate * grad_params['alpha_y']
    params['alpha_y'] = index_update(params['alpha_y'], idx, A - B)
    
    #alpha_c
    A = params['alpha_c'][tuple([idx_rows, idx_cols])]
    B = learning_rate * grad_params['alpha_c']
    params['alpha_c'] = index_update(params['alpha_c'], idx, A - B)
    
    gpars = [grad_params["ln_sig_x_h"],
    grad_params["ln_sig_zx_h"],
    grad_params["ln_sig_zy_h"],
    grad_params["ln_sig_zc_h"],
    grad_params["ln_sig_rx_h"],
    grad_params["ln_sig_ry_h"],
    grad_params["ln_sig_x_f"],
    grad_params["ln_sig_zx_f"],
    grad_params["ln_sig_zy_f"],
    grad_params["ln_sig_zc_f"],
    grad_params["ln_sig_x_h"],
    grad_params["ln_sig_zx_h"],
    grad_params["ln_sig_zy_h"],
    grad_params["ln_sig_zc_h"],
    grad_params["ln_sig_rx_h"],
    grad_params["ln_sig_ry_h"],
    grad_params["ln_sig_x_f"],
    grad_params["ln_sig_zx_f"],
    grad_params["ln_sig_zy_f"],
    grad_params["ln_sig_zc_f"]]
    

    if (onp.sum(onp.isnan(B))!=0) | (onp.sum(onp.isinf(B))!=0) | (onp.sum(onp.isnan(gpars))!=0):
        idx_nan, _ = onp.where(onp.isnan(B))
        print("nans in grad Z, iteration: ", iteration, " rep: ", rep)
        raise ValueError('Nans in gradient.')
            
    
    
    return None

# %%
def getIniMonitor_LNC(epochs, report_freq, reps, parts): 
        num_reports = int(np.ceil(epochs / report_freq))+1 # initial report 
        print("num_reports: ", num_reports)
        monitors = {
            'loss': onp.zeros([num_reports, reps, parts]),
            'hsic_rx_ax': onp.zeros([num_reports, reps, parts]),
            'hsic_ry_ay': onp.zeros([num_reports, reps, parts]),
            'hsic_resids': onp.zeros([num_reports, reps, parts]),
            'hsic_zx_zy': onp.zeros([num_reports, reps, parts]),
            'hsic_zx_zc': onp.zeros([num_reports, reps, parts]),
            'hsic_zy_zc': onp.zeros([num_reports, reps, parts]),
            'hsic_zy_x': onp.zeros([num_reports, reps, parts]),
            'hsic_indep': onp.zeros([num_reports, reps, parts]),
            'hsic_x_zc': onp.zeros([num_reports, reps, parts]),
            'hsic_y_zc': onp.zeros([num_reports, reps, parts]),
            'hsic_xy_zc': onp.zeros([num_reports, reps, parts]),
            'mse_rx': onp.zeros([num_reports, reps, parts]),
            'mse_ry': onp.zeros([num_reports, reps, parts]),
            'mses': onp.zeros([num_reports, reps, parts]),
            'hsic_zx': onp.zeros([num_reports, reps, parts]),
            'hsic_zy': onp.zeros([num_reports, reps, parts]),
            'hsic_zc': onp.zeros([num_reports, reps, parts]),
            'imp_zx': onp.zeros([num_reports, reps, parts]),
            'imp_zy': onp.zeros([num_reports, reps, parts]),
            
        }
        return monitors

# %%
def fillMonitor_LNC(params, params_or, pars, loss_as_par, dloss_as_par_jitted, lossData, iteration, report_freq, rep, part, reps, monitors, K_t):
    
    
    _, _, lam, _,_ = pars
          
    
    monitor = model_LNC(params, lam, lossData, K_t)
    print("monitor")
    print(monitor)
    ws = np.ones(params["alpha_x"].shape[0])
    loss_val = loss_as_par(params, pars, lossData,ws)
    indxRep = int(iteration / report_freq) 
    print("indxRep:", indxRep, " iteration: ", iteration, " rep: ", rep, " part: ", part)
    
    monitors['loss'][indxRep, rep, part] = loss_val
    monitors['hsic_rx_ax'][indxRep, rep, part] = monitor['hsic_rx_ax']
    monitors['hsic_ry_ay'][indxRep, rep, part] = monitor['hsic_ry_ay']
    monitors['hsic_resids'][indxRep, rep, part] = monitor['hsic_resids']
    monitors['hsic_zx_zy'][indxRep, rep, part] = monitor['hsic_zx_zy']
    monitors['hsic_zx_zc'][indxRep, rep, part] = monitor['hsic_zx_zc']
    monitors['hsic_zy_zc'][indxRep, rep, part] = monitor['hsic_zy_zc']
    monitors['hsic_zy_x'][indxRep, rep, part] = monitor['hsic_zy_x']
    monitors['hsic_indep'][indxRep, rep, part] = monitor['hsic_indep']
    monitors['hsic_x_zc'][indxRep, rep, part] = monitor['hsic_x_zc']
    monitors['hsic_y_zc'][indxRep, rep, part] = monitor['hsic_y_zc']
    monitors['hsic_xy_zc'][indxRep, rep, part] = monitor['hsic_xy_zc']
    monitors['mse_rx'][indxRep, rep, part] = monitor['mse_rx']
    monitors['mse_ry'][indxRep, rep, part] = monitor['mse_ry']
    monitors['mses'][indxRep, rep, part] = monitor['mses']
    monitors['hsic_zx'][indxRep, rep, part] = monitor['hsic_zx']
    monitors['hsic_zy'][indxRep, rep, part] = monitor['hsic_zy']
    monitors['hsic_zc'][indxRep, rep, part] = monitor['hsic_zc']
    monitors['imp_zx'][indxRep, rep, part] = monitor['imp_zx']
    monitors['imp_zy'][indxRep, rep, part] = monitor['imp_zy']
    
                    
                    
    return monitors

# %%
def getLatentZ_LNC(params, loss_as_par, dloss_as_par_jitted, loss_data, pars, epochs, report_freq, reps, batch_size, batch_per_epoch, learning_rate, smplsParts, monitors, batches, batches2, K_t):
    N = params["alpha_x"].shape[0]
         
    print("report_freq: ", report_freq)
    parts = len(smplsParts)
    
    ms = onp.zeros([N, epochs+1, reps])
    vs = onp.zeros([N, epochs+1, reps])
    epochs2 = int(onp.floor(epochs/batch_per_epoch))
    loss_vals = onp.ones([epochs+1, reps])*onp.Inf
    loss_vals_epoch = onp.ones([epochs2, reps])*onp.Inf
    
    
    lrs = learning_rate*onp.ones(reps)
    adamOpt = False
    


    for iteration in range(epochs+1):
      
        # print("*********************")
        if (iteration % 50 == 0):
            print("iteration: ", iteration)
        #print("nans: ", onp.sum(onp.isnan(onp.array(params["Z"]))))

        epoch = (iteration-1) // batch_per_epoch
        batch = (iteration-1) % batch_per_epoch
        
        #epoch = bisect.bisect_left(cumbatches_per_epoch, iteration)-1
        #batch = iteration -cumbatches_per_epoch[epoch]-1
        
        #print("iteration: ", iteration)
        #print("epoch: ", epoch)
        #print("batch: ", batch)

        


        # get the gradient of the loss
        for rep in range(reps):
            #print("rep: ", rep)


            if(iteration == 0):
                smpl = onp.random.randint(low=0, high=N, size=batch_size)
                smpl2 = onp.random.randint(low=0, high=N, size=batch_size*2)
            else:
                #print(np.unique(np.hstack(batches[rep][epoch])).shape)
                #print(np.unique(np.hstack(batches2[rep][epoch])).shape)
                smpl = batches[rep][epoch][batch]
                smpl2 = batches2[rep][epoch][batch]
                

            #print("len smpl: ", len(smpl))
            #print("len smpl 2: ", len(smpl2))
             

            if iteration == 5:
                print("smpl: ", smpl[0:4])
            
            #smpl2 = onp.random.randint(low=0, high=N, size=batch_size)
            
            #smpl3 = onp.linspace(0,n-1,n, dtype=int)
            # sampling without replacemnt
            #smpl = onp.random.choice(a=n, size=batch_size, replace=False)

  
            loss_data_aux = getDataLoss_LNC(smpl, loss_data)
            loss_data_aux2 = getDataLoss_LNC(smpl2, loss_data)

  
            # equal weights
            ws = np.ones(batch_size)
            

            # algorithmic independence forcing

            # random weights - so that E[y|x] alg indep of p(x)
            #ws = getWeightsAlgoIndep(loss_data, batch_size, smpl)
            #print("ws: ", ws[0:5])

            
            # prepare parameters for grad calculation (subsample)
            
            #params_aux = getParamsForGrad(params, rep, optType, smpl)
            params_aux = getParamsForGrad_LNC(params, rep, smpl)
            params_aux2 = getParamsForGrad_LNC(params, rep, smpl2)
            #params_aux3 = getParamsForGrad(params, rep, smpl3)
           
            
             
            if adamOpt:
                grad_params = grad(loss_as_par, argnums=0)(params_aux, pars, loss_data_aux, ws)
                if iteration > 0:
                    m = ms[smpl,iteration-1,rep][:,None]
                    v = vs[smpl,iteration-1,rep][:,None]
                    m, v = updateParamsAdam2_LNC(params, grad_params, smpl, iteration, rep, lrs[rep], iteration-1, m, v)
                    ms[smpl,iteration,rep] = m[:,0]
                    vs[smpl,iteration,rep] = v[:,0]
            

            else:
                grad_params = dloss_as_par_jitted(params_aux, pars, loss_data_aux, ws)
                if iteration > 0:
                    updateParams_LNC(params, grad_params, smpl, iteration, rep, lrs[rep])

            ws = np.ones(batch_size*2)
            loss_vals[iteration, rep] = loss_as_par(params_aux2, pars, loss_data_aux2, ws)
            	

 
            if (iteration % report_freq == 0):# & (iteration != 0):
                #print("report")
                print("iteration report: ", iteration)
                
                for part in range(parts):
                    
                    smplPart = smplsParts[part]
                    params_part = getParamsForGrad_LNC(params, rep, smplPart)
                    #params_part = getParamsSmpl(params, smplPart)
                    loss_data_part = getDataLoss_LNC(smplPart, loss_data)
                    monitors = fillMonitor_LNC(params_part, params, pars, loss_as_par, dloss_as_par_jitted, loss_data_part, iteration, report_freq, rep, part, reps, monitors, K_t)
                               

                    #nPerPart = smplPart.shape[0]
                    #ws = np.ones(nPerPart)
                    #loss_val = loss_as_par(params_part, pars, loss_data_part, ws)
         
                              
                  
   
    return params, monitors #, resids, bestResids, bestZ

# %%
def getLatentZ_wrapper(x, y, Z, U, nm, pars, num_epochs, report_freq, num_reps, batch_size, learning_rate, job):
    print("nm:", nm)
    N = x.shape[0]
    

    D_x = covariance_matrix(sqeuclidean_distance, x, x)
    sigma_x_med = 1 / np.median(D_x)
    K_x = rbf_kernel_matrix({'gamma': sigma_x_med}, x, x)

    D_y = covariance_matrix(sqeuclidean_distance, y, y)
    sigma_y = 1 / np.median(D_y)
    K_y = rbf_kernel_matrix({'gamma': sigma_y}, y, y)
    
    D_u = covariance_matrix(sqeuclidean_distance, U, U)
    sigma_u = 1 / np.median(D_u)
    K_u = rbf_kernel_matrix({'gamma': sigma_u}, U, U)
    
    
    onp.random.seed(seed=job)
    
    maxMonitor = 1000
    parts = int(onp.ceil(N/maxMonitor))
    smplsParts = onp.random.choice(parts, size=N)
    

    smplsParts = [myWhere(smplsParts==i) for i in range(parts)]

    lossData = x, y, Z, K_u, D_x, K_y, D_y, K_x 
    
    

    onp.random.seed(seed=job+3)
    params = getIniPar_LNC(num_reps, lossData, pars, smplsParts)
    print("alpha x shape: ",params["alpha_x"].shape)
    
    res = []
    


    onp.random.seed(seed=job+123)
    batch_per_epoch = int(onp.ceil(N / batch_size))
    epochs2 = int(onp.ceil(num_epochs / batch_per_epoch))
    num_iters = int(epochs2*batch_per_epoch)
    batches = [[get_batches_one_epoch(batch_per_epoch, batch_size, N) for i in range(epochs2)] for j in range(num_reps)]
    #batches2 = [[get_batches_one_epoch(batch_per_epoch, batch_size, N) for i in range(epochs2)] for j in range(num_reps)]
    batches2 = [[ [onp.random.randint(low=0, high=N, size=batch_size*2) for k in range(batch_per_epoch)] for i in range(epochs2)] for j in range(num_reps)]
    print("N: ", N)
    print("batch size: ", batch_size)
    print("batch per_epoch: ", batch_per_epoch)
    print("epochs2: ", epochs2)
    print("epochs eff: ", len(batches[0]))
    print("num_iters: ", num_iters)

    report_freq2 = num_iters // 1

    path = getIniMonitor_LNC(num_iters, report_freq, num_reps, parts)
    


    loss_as_par = loss_LNC
    dloss_as_par_jitted = dloss_LNC_jitted
    

        
        
    start = time.process_time()
    params, path = getLatentZ_LNC(params, loss_as_par, dloss_as_par_jitted, loss_data=lossData, pars=pars,epochs=num_iters, report_freq=report_freq,
                                                         reps=num_reps, batch_size=batch_size, batch_per_epoch=batch_per_epoch, learning_rate=learning_rate, smplsParts=smplsParts, monitors=path, batches=batches, batches2=batches2, K_t=None)
    res.append(path)
    
    res = {k: onp.concatenate([r[k] for r in res], axis=0) for k in res[0].keys()}
    

    print("results")
    res = {"params": params, "path": res}
    #print(res["path"])
    

    return res

# %% [markdown]
# ## optimize for hyperparameter choice

# %%
# beta: np.ndarray, neta: np.ndarray,  lam: np.ndarray, lu: np.ndarray
beta = np.array(1.0) # mse
neta = np.array(1.0) # indep zs
lam = np.array(0.01) # krr
nu = np.array(1.0) # z norm
lu = np.array(0.0) # CI indep
pars = (beta, neta, lam, nu, lu)

# %%
# epchs:int, bs:int, reps:int, lr: float, job:int
num_epochs = 1000
report_freq = 10#num_epochs
num_reps = 7
batch_size = 100
learning_rate = 0.001
job = 1

# %%
# read file
import pandas as pd
folder = "/home/emiliano/Documents/ISP/postdoc/discoveringLatentConfounders/data/data_to_try/13:45:44_14092023/"
file = "5_exponential1gaussian1_dependent_10_1_100.csv"
# Out:
# 2023-09-18 23:29:39,433:INFO:NumExpr defaulting to 8 threads.

# %%
data = pd.read_csv(folder+file, skiprows=17)

# %%
data.head()
# Out:
#    Unnamed: 0       Z.1       Z.2       Z.3       Z.4       Z.5       Z.6  \
# 0           1 -4.257510 -2.628083  1.532396  2.106480  2.555447  0.548185
# 1           2 -6.186321  2.158373  4.087255  5.089037 -1.557615  0.354011
# 2           3  0.922623  2.829448 -3.500332  0.164894  2.403200  2.056119
# 3           4 -0.198229 -0.518078  2.199180 -3.302215 -4.793345  0.072418
# 4           5  5.846498  0.385424 -3.343436 -0.239071  4.617033  4.394828
#
#         Z.7       Z.8       Z.9  ...       U.93      U.94       U.95  \
# 0 -0.873037 -2.582866  1.201632  ...   2.943411  3.433972 -12.059140
# 1 -0.410917  1.112464  3.247618  ...  11.557239  6.252577  -4.917907
# 2  2.282143  2.957012 -3.086380  ...  -2.903270  2.379708  -3.457482
# 3 -2.818797  0.556005 -1.828017  ...  -4.262228 -2.821497   6.181105
# 4  5.976737  1.227569 -1.022016  ...  -8.295679 -8.060914   3.325531
#
#         U.96       U.97       U.98       U.99     U.100         X          Y
# 0  -1.084468 -10.062209   2.632646  -2.679277 -6.939442  2.196186  -6.230360
# 1  -7.701617  -0.418536  -5.409675  -6.676294  4.506038 -0.358376  -8.280630
# 2  24.731770  11.718584  -7.371640  15.737050 -0.989652  2.461117   0.630075
# 3  -9.139552  -6.957557 -11.686181   8.437655  0.999168  3.134817  -3.971889
# 4  24.612512  13.523935  13.928673   5.056496  4.155581  0.975887  10.689424
#
# [5 rows x 113 columns]

# %%
data.columns[10]
# Out:
# 'Z.10'

# %%
data.shape
# Out:
# (1000, 113)

# %%
zcols = ["Z."+str(i) for i in range(1,11)]
ucols = ["U."+str(i) for i in range(1,101)]

# %%
# X = np.array(norml_mat(X))
x= np.array(data["X"])[:,None]
y= np.array(data["Y"])[:,None]
Z= np.array(data[zcols])
U= np.array(data[ucols])

# %%
embedding = Isomap(n_components=10)
xy = onp.hstack([x, y])
xy_transformed = embedding.fit_transform(xy)
zc_ini = np.array(xy_transformed[:,3])[:,None]

# %%
hsicRBF(x, y)
# Out:
# DeviceArray(0.011, dtype=float32)

# %%
hsicRBF(zc_ini, y)
# Out:
# DeviceArray(0.135, dtype=float32)

# %%
hsicRBF(zc_ini, x)
# Out:
# DeviceArray(0.072, dtype=float32)

# %%
y.shape
# Out:
# (1000, 1)

# %%
# ix c(8, 2, 3)
# iy c(1, 7, 6)
# ic 10
Z[:,[7,1,2]]
# Out:
# DeviceArray([[-2.583, -2.628,  1.532],
#              [ 1.112,  2.158,  4.087],
#              [ 2.957,  2.829, -3.5  ],
#              ...,
#              [ 2.101,  0.742, -0.046],
#              [-1.906,  0.307, -0.398],
#              [-2.585, -1.338,  3.065]], dtype=float32)

# %%
nm = "test"

# %%
res = getLatentZ_wrapper(x, y, Z, U, nm, pars, num_epochs, report_freq, num_reps, batch_size, learning_rate, job)
# Out:
# nm: test
# alpha x shape:  (1000, 7)
# N:  1000
# batch size:  100
# batch per_epoch:  10
# epochs2:  100
# epochs eff:  100
# num_iters:  1000
# num_reports:  101
# report_freq:  10
# iteration:  0
# iteration report:  0
# monitor
# {'hsic_indep': DeviceArray(-14.484, dtype=float32), 'hsic_resids': DeviceArray(-5.431, dtype=float32), 'hsic_rx_ax': DeviceArray(0.049, dtype=float32), 'hsic_ry_ay': DeviceArray(0.09, dtype=float32), 'hsic_x_zc': DeviceArray(0.036, dtype=float32), 'hsic_xy_zc': DeviceArray(-5.916, dtype=float32), 'hsic_y_zc': DeviceArray(0.075, dtype=float32), 'hsic_zc': DeviceArray(0.092, dtype=float32), 'hsic_zx': DeviceArray(0.146, dtype=float32), 'hsic_zx_zc': DeviceArray(0.039, dtype=float32), 'hsic_zx_zy': DeviceArray(0.016, dtype=float32), 'hsic_zy': DeviceArray(0.19, dtype=float32), 'hsic_zy_x': DeviceArray(0.01, dtype=float32), 'hsic_zy_zc': DeviceArray(0.083, dtype=float32), 'imp_zx': DeviceArray(0.073, dtype=float32), 'imp_zy': DeviceArray(0.07, dtype=float32), 'mse_rx': DeviceArray(0.452, dtype=float32), 'mse_ry': DeviceArray(0.351, dtype=float32), 'mses': DeviceArray(-1.84, dtype=float32)}
# indxRep: 0  iteration:  0  rep:  0  part:  0
# iteration report:  0
# monitor
# {'hsic_indep': DeviceArray(-14.272, dtype=float32), 'hsic_resids': DeviceArray(-7.077, dtype=float32), 'hsic_rx_ax': DeviceArray(0.02, dtype=float32), 'hsic_ry_ay': DeviceArray(0.042, dtype=float32), 'hsic_x_zc': DeviceArray(0.052, dtype=float32), 'hsic_xy_zc': DeviceArray(-5.045, dtype=float32), 'hsic_y_zc': DeviceArray(0.123, dtype=float32), 'hsic_zc': DeviceArray(0.15, dtype=float32), 'hsic_zx': DeviceArray(0.265, dtype=float32), 'hsic_zx_zc': DeviceArray(0.058, dtype=float32), 'hsic_zx_zy': DeviceArray(0.009, dtype=float32), 'hsic_zy': DeviceArray(0.346, dtype=float32), 'hsic_zy_x': DeviceArray(0.008, dtype=float32), 'hsic_zy_zc': DeviceArray(0.148, dtype=float32), 'imp_zx': DeviceArray(0.13, dtype=float32), 'imp_zy': DeviceArray(0.127, dtype=float32), 'mse_rx': DeviceArray(0.664, dtype=float32), 'mse_ry': DeviceArray(0.721, dtype=float32), 'mses': DeviceArray(-0.737, dtype=float32)}
# indxRep: 0  iteration:  0  rep:  1  part:  0
# iteration report:  0
# monitor
# {'hsic_indep': DeviceArray(-13.926, dtype=float32), 'hsic_resids': DeviceArray(-7.778, dtype=float32), 'hsic_rx_ax': DeviceArray(0.015, dtype=float32), 'hsic_ry_ay': DeviceArray(0.028, dtype=float32), 'hsic_x_zc': DeviceArray(0.061, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.696, dtype=float32), 'hsic_y_zc': DeviceArray(0.149, dtype=float32), 'hsic_zc': DeviceArray(0.182, dtype=float32), 'hsic_zx': DeviceArray(0.352, dtype=float32), 'hsic_zx_zc': DeviceArray(0.067, dtype=float32), 'hsic_zx_zy': DeviceArray(0.009, dtype=float32), 'hsic_zy': DeviceArray(0.45, dtype=float32), 'hsic_zy_x': DeviceArray(0.009, dtype=float32), 'hsic_zy_zc': DeviceArray(0.16, dtype=float32), 'imp_zx': DeviceArray(0.177, dtype=float32), 'imp_zy': DeviceArray(0.174, dtype=float32), 'mse_rx': DeviceArray(0.701, dtype=float32), 'mse_ry': DeviceArray(0.812, dtype=float32), 'mses': DeviceArray(-0.564, dtype=float32)}
# indxRep: 0  iteration:  0  rep:  2  part:  0
# iteration report:  0
# monitor
# {'hsic_indep': DeviceArray(-13.951, dtype=float32), 'hsic_resids': DeviceArray(-8.319, dtype=float32), 'hsic_rx_ax': DeviceArray(0.014, dtype=float32), 'hsic_ry_ay': DeviceArray(0.017, dtype=float32), 'hsic_x_zc': DeviceArray(0.066, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.545, dtype=float32), 'hsic_y_zc': DeviceArray(0.161, dtype=float32), 'hsic_zc': DeviceArray(0.202, dtype=float32), 'hsic_zx': DeviceArray(0.409, dtype=float32), 'hsic_zx_zc': DeviceArray(0.06, dtype=float32), 'hsic_zx_zy': DeviceArray(0.011, dtype=float32), 'hsic_zy': DeviceArray(0.508, dtype=float32), 'hsic_zy_x': DeviceArray(0.009, dtype=float32), 'hsic_zy_zc': DeviceArray(0.142, dtype=float32), 'imp_zx': DeviceArray(0.214, dtype=float32), 'imp_zy': DeviceArray(0.208, dtype=float32), 'mse_rx': DeviceArray(0.712, dtype=float32), 'mse_ry': DeviceArray(0.855, dtype=float32), 'mses': DeviceArray(-0.497, dtype=float32)}
# indxRep: 0  iteration:  0  rep:  3  part:  0
# iteration report:  0
# monitor
# {'hsic_indep': DeviceArray(-14.853, dtype=float32), 'hsic_resids': DeviceArray(-8.906, dtype=float32), 'hsic_rx_ax': DeviceArray(0.011, dtype=float32), 'hsic_ry_ay': DeviceArray(0.012, dtype=float32), 'hsic_x_zc': DeviceArray(0.065, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.571, dtype=float32), 'hsic_y_zc': DeviceArray(0.159, dtype=float32), 'hsic_zc': DeviceArray(0.212, dtype=float32), 'hsic_zx': DeviceArray(0.431, dtype=float32), 'hsic_zx_zc': DeviceArray(0.037, dtype=float32), 'hsic_zx_zy': DeviceArray(0.012, dtype=float32), 'hsic_zy': DeviceArray(0.517, dtype=float32), 'hsic_zy_x': DeviceArray(0.008, dtype=float32), 'hsic_zy_zc': DeviceArray(0.094, dtype=float32), 'imp_zx': DeviceArray(0.235, dtype=float32), 'imp_zy': DeviceArray(0.226, dtype=float32), 'mse_rx': DeviceArray(0.723, dtype=float32), 'mse_ry': DeviceArray(0.888, dtype=float32), 'mses': DeviceArray(-0.443, dtype=float32)}
# indxRep: 0  iteration:  0  rep:  4  part:  0
# iteration report:  0
# monitor
# {'hsic_indep': DeviceArray(-16.765, dtype=float32), 'hsic_resids': DeviceArray(-9.634, dtype=float32), 'hsic_rx_ax': DeviceArray(0.008, dtype=float32), 'hsic_ry_ay': DeviceArray(0.008, dtype=float32), 'hsic_x_zc': DeviceArray(0.058, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.764, dtype=float32), 'hsic_y_zc': DeviceArray(0.147, dtype=float32), 'hsic_zc': DeviceArray(0.208, dtype=float32), 'hsic_zx': DeviceArray(0.419, dtype=float32), 'hsic_zx_zc': DeviceArray(0.015, dtype=float32), 'hsic_zx_zy': DeviceArray(0.012, dtype=float32), 'hsic_zy': DeviceArray(0.487, dtype=float32), 'hsic_zy_x': DeviceArray(0.007, dtype=float32), 'hsic_zy_zc': DeviceArray(0.044, dtype=float32), 'imp_zx': DeviceArray(0.237, dtype=float32), 'imp_zy': DeviceArray(0.223, dtype=float32), 'mse_rx': DeviceArray(0.727, dtype=float32), 'mse_ry': DeviceArray(0.918, dtype=float32), 'mses': DeviceArray(-0.404, dtype=float32)}
# indxRep: 0  iteration:  0  rep:  5  part:  0
# iteration report:  0
# monitor
# {'hsic_indep': DeviceArray(-21.218, dtype=float32), 'hsic_resids': DeviceArray(-10.292, dtype=float32), 'hsic_rx_ax': DeviceArray(0.006, dtype=float32), 'hsic_ry_ay': DeviceArray(0.006, dtype=float32), 'hsic_x_zc': DeviceArray(0.048, dtype=float32), 'hsic_xy_zc': DeviceArray(-5.086, dtype=float32), 'hsic_y_zc': DeviceArray(0.128, dtype=float32), 'hsic_zc': DeviceArray(0.194, dtype=float32), 'hsic_zx': DeviceArray(0.394, dtype=float32), 'hsic_zx_zc': DeviceArray(0.002, dtype=float32), 'hsic_zx_zy': DeviceArray(0.01, dtype=float32), 'hsic_zy': DeviceArray(0.441, dtype=float32), 'hsic_zy_x': DeviceArray(0.006, dtype=float32), 'hsic_zy_zc': DeviceArray(0.007, dtype=float32), 'imp_zx': DeviceArray(0.228, dtype=float32), 'imp_zy': DeviceArray(0.21, dtype=float32), 'mse_rx': DeviceArray(0.733, dtype=float32), 'mse_ry': DeviceArray(0.948, dtype=float32), 'mses': DeviceArray(-0.364, dtype=float32)}
# indxRep: 0  iteration:  0  rep:  6  part:  0
# /home/emiliano/anaconda3/lib/python3.7/site-packages/jax/lax/lax.py:5946: UserWarning: Explicitly requested dtype <class 'int'> requested in linspace is not available, and will be truncated to dtype int32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   warnings.warn(msg.format(dtype, fun_name , truncated_dtype))
# smpl:  [26 48 59 63]
# smpl:  [ 8 11 14 24]
# smpl:  [1 2 3 9]
# smpl:  [ 4  8 25 26]
# smpl:  [ 6 40 42 44]
# smpl:  [11 25 27 33]
# smpl:  [10 13 22 27]
# iteration report:  10
# monitor
# {'hsic_indep': DeviceArray(-16.48, dtype=float32), 'hsic_resids': DeviceArray(-5.773, dtype=float32), 'hsic_rx_ax': DeviceArray(0.05, dtype=float32), 'hsic_ry_ay': DeviceArray(0.062, dtype=float32), 'hsic_x_zc': DeviceArray(0.01, dtype=float32), 'hsic_xy_zc': DeviceArray(-8.806, dtype=float32), 'hsic_y_zc': DeviceArray(0.014, dtype=float32), 'hsic_zc': DeviceArray(0.019, dtype=float32), 'hsic_zx': DeviceArray(0.148, dtype=float32), 'hsic_zx_zc': DeviceArray(0.023, dtype=float32), 'hsic_zx_zy': DeviceArray(0.016, dtype=float32), 'hsic_zy': DeviceArray(0.19, dtype=float32), 'hsic_zy_x': DeviceArray(0.01, dtype=float32), 'hsic_zy_zc': DeviceArray(0.019, dtype=float32), 'imp_zx': DeviceArray(0.068, dtype=float32), 'imp_zy': DeviceArray(0.07, dtype=float32), 'mse_rx': DeviceArray(0.459, dtype=float32), 'mse_ry': DeviceArray(0.228, dtype=float32), 'mses': DeviceArray(-2.257, dtype=float32)}
# indxRep: 1  iteration:  10  rep:  0  part:  0
# iteration report:  10
# monitor
# {'hsic_indep': DeviceArray(-14.349, dtype=float32), 'hsic_resids': DeviceArray(-6.963, dtype=float32), 'hsic_rx_ax': DeviceArray(0.02, dtype=float32), 'hsic_ry_ay': DeviceArray(0.047, dtype=float32), 'hsic_x_zc': DeviceArray(0.055, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.984, dtype=float32), 'hsic_y_zc': DeviceArray(0.124, dtype=float32), 'hsic_zc': DeviceArray(0.142, dtype=float32), 'hsic_zx': DeviceArray(0.265, dtype=float32), 'hsic_zx_zc': DeviceArray(0.059, dtype=float32), 'hsic_zx_zy': DeviceArray(0.008, dtype=float32), 'hsic_zy': DeviceArray(0.346, dtype=float32), 'hsic_zy_x': DeviceArray(0.008, dtype=float32), 'hsic_zy_zc': DeviceArray(0.145, dtype=float32), 'imp_zx': DeviceArray(0.13, dtype=float32), 'imp_zy': DeviceArray(0.129, dtype=float32), 'mse_rx': DeviceArray(0.661, dtype=float32), 'mse_ry': DeviceArray(0.716, dtype=float32), 'mses': DeviceArray(-0.749, dtype=float32)}
# indxRep: 1  iteration:  10  rep:  1  part:  0
# iteration report:  10
# monitor
# {'hsic_indep': DeviceArray(-14.072, dtype=float32), 'hsic_resids': DeviceArray(-7.744, dtype=float32), 'hsic_rx_ax': DeviceArray(0.015, dtype=float32), 'hsic_ry_ay': DeviceArray(0.03, dtype=float32), 'hsic_x_zc': DeviceArray(0.062, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.69, dtype=float32), 'hsic_y_zc': DeviceArray(0.148, dtype=float32), 'hsic_zc': DeviceArray(0.179, dtype=float32), 'hsic_zx': DeviceArray(0.352, dtype=float32), 'hsic_zx_zc': DeviceArray(0.068, dtype=float32), 'hsic_zx_zy': DeviceArray(0.009, dtype=float32), 'hsic_zy': DeviceArray(0.452, dtype=float32), 'hsic_zy_x': DeviceArray(0.008, dtype=float32), 'hsic_zy_zc': DeviceArray(0.159, dtype=float32), 'imp_zx': DeviceArray(0.179, dtype=float32), 'imp_zy': DeviceArray(0.176, dtype=float32), 'mse_rx': DeviceArray(0.702, dtype=float32), 'mse_ry': DeviceArray(0.812, dtype=float32), 'mses': DeviceArray(-0.562, dtype=float32)}
# indxRep: 1  iteration:  10  rep:  2  part:  0
# iteration report:  10
# monitor
# {'hsic_indep': DeviceArray(-14.564, dtype=float32), 'hsic_resids': DeviceArray(-8.389, dtype=float32), 'hsic_rx_ax': DeviceArray(0.014, dtype=float32), 'hsic_ry_ay': DeviceArray(0.016, dtype=float32), 'hsic_x_zc': DeviceArray(0.064, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.591, dtype=float32), 'hsic_y_zc': DeviceArray(0.16, dtype=float32), 'hsic_zc': DeviceArray(0.207, dtype=float32), 'hsic_zx': DeviceArray(0.406, dtype=float32), 'hsic_zx_zc': DeviceArray(0.059, dtype=float32), 'hsic_zx_zy': DeviceArray(0.007, dtype=float32), 'hsic_zy': DeviceArray(0.512, dtype=float32), 'hsic_zy_x': DeviceArray(0.008, dtype=float32), 'hsic_zy_zc': DeviceArray(0.142, dtype=float32), 'imp_zx': DeviceArray(0.225, dtype=float32), 'imp_zy': DeviceArray(0.213, dtype=float32), 'mse_rx': DeviceArray(0.717, dtype=float32), 'mse_ry': DeviceArray(0.849, dtype=float32), 'mses': DeviceArray(-0.496, dtype=float32)}
# indxRep: 1  iteration:  10  rep:  3  part:  0
# iteration report:  10
# monitor
# {'hsic_indep': DeviceArray(-16.062, dtype=float32), 'hsic_resids': DeviceArray(-8.957, dtype=float32), 'hsic_rx_ax': DeviceArray(0.01, dtype=float32), 'hsic_ry_ay': DeviceArray(0.012, dtype=float32), 'hsic_x_zc': DeviceArray(0.059, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.719, dtype=float32), 'hsic_y_zc': DeviceArray(0.152, dtype=float32), 'hsic_zc': DeviceArray(0.219, dtype=float32), 'hsic_zx': DeviceArray(0.427, dtype=float32), 'hsic_zx_zc': DeviceArray(0.031, dtype=float32), 'hsic_zx_zy': DeviceArray(0.006, dtype=float32), 'hsic_zy': DeviceArray(0.521, dtype=float32), 'hsic_zy_x': DeviceArray(0.007, dtype=float32), 'hsic_zy_zc': DeviceArray(0.09, dtype=float32), 'imp_zx': DeviceArray(0.253, dtype=float32), 'imp_zy': DeviceArray(0.234, dtype=float32), 'mse_rx': DeviceArray(0.731, dtype=float32), 'mse_ry': DeviceArray(0.884, dtype=float32), 'mses': DeviceArray(-0.437, dtype=float32)}
# indxRep: 1  iteration:  10  rep:  4  part:  0
# iteration report:  10
# monitor
# {'hsic_indep': DeviceArray(-17.543, dtype=float32), 'hsic_resids': DeviceArray(-9.861, dtype=float32), 'hsic_rx_ax': DeviceArray(0.006, dtype=float32), 'hsic_ry_ay': DeviceArray(0.009, dtype=float32), 'hsic_x_zc': DeviceArray(0.061, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.743, dtype=float32), 'hsic_y_zc': DeviceArray(0.143, dtype=float32), 'hsic_zc': DeviceArray(0.2, dtype=float32), 'hsic_zx': DeviceArray(0.417, dtype=float32), 'hsic_zx_zc': DeviceArray(0.015, dtype=float32), 'hsic_zx_zy': DeviceArray(0.006, dtype=float32), 'hsic_zy': DeviceArray(0.489, dtype=float32), 'hsic_zy_x': DeviceArray(0.006, dtype=float32), 'hsic_zy_zc': DeviceArray(0.043, dtype=float32), 'imp_zx': DeviceArray(0.249, dtype=float32), 'imp_zy': DeviceArray(0.228, dtype=float32), 'mse_rx': DeviceArray(0.735, dtype=float32), 'mse_ry': DeviceArray(0.916, dtype=float32), 'mses': DeviceArray(-0.396, dtype=float32)}
# indxRep: 1  iteration:  10  rep:  5  part:  0
# iteration report:  10
# monitor
# {'hsic_indep': DeviceArray(-21.295, dtype=float32), 'hsic_resids': DeviceArray(-10.609, dtype=float32), 'hsic_rx_ax': DeviceArray(0.005, dtype=float32), 'hsic_ry_ay': DeviceArray(0.005, dtype=float32), 'hsic_x_zc': DeviceArray(0.08, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.494, dtype=float32), 'hsic_y_zc': DeviceArray(0.139, dtype=float32), 'hsic_zc': DeviceArray(0.187, dtype=float32), 'hsic_zx': DeviceArray(0.384, dtype=float32), 'hsic_zx_zc': DeviceArray(0.023, dtype=float32), 'hsic_zx_zy': DeviceArray(0., dtype=float32), 'hsic_zy': DeviceArray(0.446, dtype=float32), 'hsic_zy_x': DeviceArray(0.004, dtype=float32), 'hsic_zy_zc': DeviceArray(0.013, dtype=float32), 'imp_zx': DeviceArray(0.261, dtype=float32), 'imp_zy': DeviceArray(0.22, dtype=float32), 'mse_rx': DeviceArray(0.772, dtype=float32), 'mse_ry': DeviceArray(0.941, dtype=float32), 'mses': DeviceArray(-0.319, dtype=float32)}
# indxRep: 1  iteration:  10  rep:  6  part:  0
# iteration report:  20
# monitor
# {'hsic_indep': DeviceArray(-15.89, dtype=float32), 'hsic_resids': DeviceArray(-6.213, dtype=float32), 'hsic_rx_ax': DeviceArray(0.045, dtype=float32), 'hsic_ry_ay': DeviceArray(0.044, dtype=float32), 'hsic_x_zc': DeviceArray(0.031, dtype=float32), 'hsic_xy_zc': DeviceArray(-6.458, dtype=float32), 'hsic_y_zc': DeviceArray(0.05, dtype=float32), 'hsic_zc': DeviceArray(0.089, dtype=float32), 'hsic_zx': DeviceArray(0.142, dtype=float32), 'hsic_zx_zc': DeviceArray(0.025, dtype=float32), 'hsic_zx_zy': DeviceArray(0.016, dtype=float32), 'hsic_zy': DeviceArray(0.19, dtype=float32), 'hsic_zy_x': DeviceArray(0.01, dtype=float32), 'hsic_zy_zc': DeviceArray(0.03, dtype=float32), 'imp_zx': DeviceArray(0.074, dtype=float32), 'imp_zy': DeviceArray(0.07, dtype=float32), 'mse_rx': DeviceArray(0.489, dtype=float32), 'mse_ry': DeviceArray(0.209, dtype=float32), 'mses': DeviceArray(-2.283, dtype=float32)}
# indxRep: 2  iteration:  20  rep:  0  part:  0
# iteration report:  20
# monitor
# {'hsic_indep': DeviceArray(-14.502, dtype=float32), 'hsic_resids': DeviceArray(-6.911, dtype=float32), 'hsic_rx_ax': DeviceArray(0.023, dtype=float32), 'hsic_ry_ay': DeviceArray(0.044, dtype=float32), 'hsic_x_zc': DeviceArray(0.058, dtype=float32), 'hsic_xy_zc': DeviceArray(-5.003, dtype=float32), 'hsic_y_zc': DeviceArray(0.117, dtype=float32), 'hsic_zc': DeviceArray(0.125, dtype=float32), 'hsic_zx': DeviceArray(0.266, dtype=float32), 'hsic_zx_zc': DeviceArray(0.059, dtype=float32), 'hsic_zx_zy': DeviceArray(0.008, dtype=float32), 'hsic_zy': DeviceArray(0.347, dtype=float32), 'hsic_zy_x': DeviceArray(0.008, dtype=float32), 'hsic_zy_zc': DeviceArray(0.13, dtype=float32), 'imp_zx': DeviceArray(0.129, dtype=float32), 'imp_zy': DeviceArray(0.13, dtype=float32), 'mse_rx': DeviceArray(0.662, dtype=float32), 'mse_ry': DeviceArray(0.719, dtype=float32), 'mses': DeviceArray(-0.742, dtype=float32)}
# indxRep: 2  iteration:  20  rep:  1  part:  0
# iteration report:  20
# monitor
# {'hsic_indep': DeviceArray(-14.313, dtype=float32), 'hsic_resids': DeviceArray(-7.612, dtype=float32), 'hsic_rx_ax': DeviceArray(0.015, dtype=float32), 'hsic_ry_ay': DeviceArray(0.033, dtype=float32), 'hsic_x_zc': DeviceArray(0.066, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.628, dtype=float32), 'hsic_y_zc': DeviceArray(0.147, dtype=float32), 'hsic_zc': DeviceArray(0.169, dtype=float32), 'hsic_zx': DeviceArray(0.351, dtype=float32), 'hsic_zx_zc': DeviceArray(0.071, dtype=float32), 'hsic_zx_zy': DeviceArray(0.007, dtype=float32), 'hsic_zy': DeviceArray(0.455, dtype=float32), 'hsic_zy_x': DeviceArray(0.008, dtype=float32), 'hsic_zy_zc': DeviceArray(0.159, dtype=float32), 'imp_zx': DeviceArray(0.184, dtype=float32), 'imp_zy': DeviceArray(0.18, dtype=float32), 'mse_rx': DeviceArray(0.702, dtype=float32), 'mse_ry': DeviceArray(0.813, dtype=float32), 'mses': DeviceArray(-0.561, dtype=float32)}
# indxRep: 2  iteration:  20  rep:  2  part:  0
# iteration report:  20
# monitor
# {'hsic_indep': DeviceArray(-15.062, dtype=float32), 'hsic_resids': DeviceArray(-8.404, dtype=float32), 'hsic_rx_ax': DeviceArray(0.014, dtype=float32), 'hsic_ry_ay': DeviceArray(0.016, dtype=float32), 'hsic_x_zc': DeviceArray(0.062, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.636, dtype=float32), 'hsic_y_zc': DeviceArray(0.158, dtype=float32), 'hsic_zc': DeviceArray(0.21, dtype=float32), 'hsic_zx': DeviceArray(0.405, dtype=float32), 'hsic_zx_zc': DeviceArray(0.057, dtype=float32), 'hsic_zx_zy': DeviceArray(0.005, dtype=float32), 'hsic_zy': DeviceArray(0.515, dtype=float32), 'hsic_zy_x': DeviceArray(0.007, dtype=float32), 'hsic_zy_zc': DeviceArray(0.141, dtype=float32), 'imp_zx': DeviceArray(0.232, dtype=float32), 'imp_zy': DeviceArray(0.217, dtype=float32), 'mse_rx': DeviceArray(0.724, dtype=float32), 'mse_ry': DeviceArray(0.847, dtype=float32), 'mses': DeviceArray(-0.489, dtype=float32)}
# indxRep: 2  iteration:  20  rep:  3  part:  0
# iteration report:  20
# monitor
# {'hsic_indep': DeviceArray(-16.699, dtype=float32), 'hsic_resids': DeviceArray(-8.987, dtype=float32), 'hsic_rx_ax': DeviceArray(0.01, dtype=float32), 'hsic_ry_ay': DeviceArray(0.012, dtype=float32), 'hsic_x_zc': DeviceArray(0.059, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.724, dtype=float32), 'hsic_y_zc': DeviceArray(0.152, dtype=float32), 'hsic_zc': DeviceArray(0.218, dtype=float32), 'hsic_zx': DeviceArray(0.425, dtype=float32), 'hsic_zx_zc': DeviceArray(0.031, dtype=float32), 'hsic_zx_zy': DeviceArray(0.003, dtype=float32), 'hsic_zy': DeviceArray(0.523, dtype=float32), 'hsic_zy_x': DeviceArray(0.006, dtype=float32), 'hsic_zy_zc': DeviceArray(0.091, dtype=float32), 'imp_zx': DeviceArray(0.262, dtype=float32), 'imp_zy': DeviceArray(0.239, dtype=float32), 'mse_rx': DeviceArray(0.738, dtype=float32), 'mse_ry': DeviceArray(0.882, dtype=float32), 'mses': DeviceArray(-0.43, dtype=float32)}
# indxRep: 2  iteration:  20  rep:  4  part:  0
# iteration report:  20
# monitor
# {'hsic_indep': DeviceArray(-17.74, dtype=float32), 'hsic_resids': DeviceArray(-9.824, dtype=float32), 'hsic_rx_ax': DeviceArray(0.007, dtype=float32), 'hsic_ry_ay': DeviceArray(0.008, dtype=float32), 'hsic_x_zc': DeviceArray(0.057, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.81, dtype=float32), 'hsic_y_zc': DeviceArray(0.143, dtype=float32), 'hsic_zc': DeviceArray(0.207, dtype=float32), 'hsic_zx': DeviceArray(0.419, dtype=float32), 'hsic_zx_zc': DeviceArray(0.012, dtype=float32), 'hsic_zx_zy': DeviceArray(0.007, dtype=float32), 'hsic_zy': DeviceArray(0.49, dtype=float32), 'hsic_zy_x': DeviceArray(0.006, dtype=float32), 'hsic_zy_zc': DeviceArray(0.043, dtype=float32), 'imp_zx': DeviceArray(0.246, dtype=float32), 'imp_zy': DeviceArray(0.229, dtype=float32), 'mse_rx': DeviceArray(0.737, dtype=float32), 'mse_ry': DeviceArray(0.913, dtype=float32), 'mses': DeviceArray(-0.396, dtype=float32)}
# indxRep: 2  iteration:  20  rep:  5  part:  0
# iteration report:  20
# monitor
# {'hsic_indep': DeviceArray(-20.406, dtype=float32), 'hsic_resids': DeviceArray(-10.554, dtype=float32), 'hsic_rx_ax': DeviceArray(0.007, dtype=float32), 'hsic_ry_ay': DeviceArray(0.004, dtype=float32), 'hsic_x_zc': DeviceArray(0.042, dtype=float32), 'hsic_xy_zc': DeviceArray(-5.219, dtype=float32), 'hsic_y_zc': DeviceArray(0.13, dtype=float32), 'hsic_zc': DeviceArray(0.23, dtype=float32), 'hsic_zx': DeviceArray(0.386, dtype=float32), 'hsic_zx_zc': DeviceArray(0.013, dtype=float32), 'hsic_zx_zy': DeviceArray(0.002, dtype=float32), 'hsic_zy': DeviceArray(0.447, dtype=float32), 'hsic_zy_x': DeviceArray(0.004, dtype=float32), 'hsic_zy_zc': DeviceArray(0.017, dtype=float32), 'imp_zx': DeviceArray(0.251, dtype=float32), 'imp_zy': DeviceArray(0.221, dtype=float32), 'mse_rx': DeviceArray(0.748, dtype=float32), 'mse_ry': DeviceArray(0.936, dtype=float32), 'mses': DeviceArray(-0.357, dtype=float32)}
# indxRep: 2  iteration:  20  rep:  6  part:  0
# iteration report:  30
# monitor
# {'hsic_indep': DeviceArray(-16.374, dtype=float32), 'hsic_resids': DeviceArray(-6.077, dtype=float32), 'hsic_rx_ax': DeviceArray(0.043, dtype=float32), 'hsic_ry_ay': DeviceArray(0.053, dtype=float32), 'hsic_x_zc': DeviceArray(0.018, dtype=float32), 'hsic_xy_zc': DeviceArray(-7.687, dtype=float32), 'hsic_y_zc': DeviceArray(0.025, dtype=float32), 'hsic_zc': DeviceArray(0.04, dtype=float32), 'hsic_zx': DeviceArray(0.141, dtype=float32), 'hsic_zx_zc': DeviceArray(0.02, dtype=float32), 'hsic_zx_zy': DeviceArray(0.016, dtype=float32), 'hsic_zy': DeviceArray(0.19, dtype=float32), 'hsic_zy_x': DeviceArray(0.01, dtype=float32), 'hsic_zy_zc': DeviceArray(0.023, dtype=float32), 'imp_zx': DeviceArray(0.075, dtype=float32), 'imp_zy': DeviceArray(0.07, dtype=float32), 'mse_rx': DeviceArray(0.47, dtype=float32), 'mse_ry': DeviceArray(0.172, dtype=float32), 'mses': DeviceArray(-2.517, dtype=float32)}
# indxRep: 3  iteration:  30  rep:  0  part:  0
# iteration report:  30
# monitor
# {'hsic_indep': DeviceArray(-15.191, dtype=float32), 'hsic_resids': DeviceArray(-6.823, dtype=float32), 'hsic_rx_ax': DeviceArray(0.027, dtype=float32), 'hsic_ry_ay': DeviceArray(0.04, dtype=float32), 'hsic_x_zc': DeviceArray(0.058, dtype=float32), 'hsic_xy_zc': DeviceArray(-5.434, dtype=float32), 'hsic_y_zc': DeviceArray(0.075, dtype=float32), 'hsic_zc': DeviceArray(0.081, dtype=float32), 'hsic_zx': DeviceArray(0.267, dtype=float32), 'hsic_zx_zc': DeviceArray(0.053, dtype=float32), 'hsic_zx_zy': DeviceArray(0.008, dtype=float32), 'hsic_zy': DeviceArray(0.347, dtype=float32), 'hsic_zy_x': DeviceArray(0.008, dtype=float32), 'hsic_zy_zc': DeviceArray(0.075, dtype=float32), 'imp_zx': DeviceArray(0.129, dtype=float32), 'imp_zy': DeviceArray(0.131, dtype=float32), 'mse_rx': DeviceArray(0.661, dtype=float32), 'mse_ry': DeviceArray(0.694, dtype=float32), 'mses': DeviceArray(-0.779, dtype=float32)}
# indxRep: 3  iteration:  30  rep:  1  part:  0
# iteration report:  30
# monitor
# {'hsic_indep': DeviceArray(-14.555, dtype=float32), 'hsic_resids': DeviceArray(-7.576, dtype=float32), 'hsic_rx_ax': DeviceArray(0.015, dtype=float32), 'hsic_ry_ay': DeviceArray(0.034, dtype=float32), 'hsic_x_zc': DeviceArray(0.068, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.608, dtype=float32), 'hsic_y_zc': DeviceArray(0.146, dtype=float32), 'hsic_zc': DeviceArray(0.164, dtype=float32), 'hsic_zx': DeviceArray(0.35, dtype=float32), 'hsic_zx_zc': DeviceArray(0.073, dtype=float32), 'hsic_zx_zy': DeviceArray(0.006, dtype=float32), 'hsic_zy': DeviceArray(0.457, dtype=float32), 'hsic_zy_x': DeviceArray(0.007, dtype=float32), 'hsic_zy_zc': DeviceArray(0.157, dtype=float32), 'imp_zx': DeviceArray(0.188, dtype=float32), 'imp_zy': DeviceArray(0.183, dtype=float32), 'mse_rx': DeviceArray(0.703, dtype=float32), 'mse_ry': DeviceArray(0.811, dtype=float32), 'mses': DeviceArray(-0.561, dtype=float32)}
# indxRep: 3  iteration:  30  rep:  2  part:  0
# iteration report:  30
# monitor
# {'hsic_indep': DeviceArray(-15.568, dtype=float32), 'hsic_resids': DeviceArray(-8.408, dtype=float32), 'hsic_rx_ax': DeviceArray(0.013, dtype=float32), 'hsic_ry_ay': DeviceArray(0.017, dtype=float32), 'hsic_x_zc': DeviceArray(0.063, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.615, dtype=float32), 'hsic_y_zc': DeviceArray(0.157, dtype=float32), 'hsic_zc': DeviceArray(0.207, dtype=float32), 'hsic_zx': DeviceArray(0.403, dtype=float32), 'hsic_zx_zc': DeviceArray(0.057, dtype=float32), 'hsic_zx_zy': DeviceArray(0.003, dtype=float32), 'hsic_zy': DeviceArray(0.518, dtype=float32), 'hsic_zy_x': DeviceArray(0.006, dtype=float32), 'hsic_zy_zc': DeviceArray(0.142, dtype=float32), 'imp_zx': DeviceArray(0.238, dtype=float32), 'imp_zy': DeviceArray(0.222, dtype=float32), 'mse_rx': DeviceArray(0.731, dtype=float32), 'mse_ry': DeviceArray(0.845, dtype=float32), 'mses': DeviceArray(-0.482, dtype=float32)}
# indxRep: 3  iteration:  30  rep:  3  part:  0
# iteration report:  30
# monitor
# {'hsic_indep': DeviceArray(-16.935, dtype=float32), 'hsic_resids': DeviceArray(-8.964, dtype=float32), 'hsic_rx_ax': DeviceArray(0.01, dtype=float32), 'hsic_ry_ay': DeviceArray(0.012, dtype=float32), 'hsic_x_zc': DeviceArray(0.059, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.73, dtype=float32), 'hsic_y_zc': DeviceArray(0.15, dtype=float32), 'hsic_zc': DeviceArray(0.214, dtype=float32), 'hsic_zx': DeviceArray(0.426, dtype=float32), 'hsic_zx_zc': DeviceArray(0.029, dtype=float32), 'hsic_zx_zy': DeviceArray(0.003, dtype=float32), 'hsic_zy': DeviceArray(0.524, dtype=float32), 'hsic_zy_x': DeviceArray(0.006, dtype=float32), 'hsic_zy_zc': DeviceArray(0.091, dtype=float32), 'imp_zx': DeviceArray(0.261, dtype=float32), 'imp_zy': DeviceArray(0.241, dtype=float32), 'mse_rx': DeviceArray(0.743, dtype=float32), 'mse_ry': DeviceArray(0.882, dtype=float32), 'mses': DeviceArray(-0.422, dtype=float32)}
# indxRep: 3  iteration:  30  rep:  4  part:  0
# iteration report:  30
# monitor
# {'hsic_indep': DeviceArray(-20.618, dtype=float32), 'hsic_resids': DeviceArray(-10.378, dtype=float32), 'hsic_rx_ax': DeviceArray(0.004, dtype=float32), 'hsic_ry_ay': DeviceArray(0.008, dtype=float32), 'hsic_x_zc': DeviceArray(0.053, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.884, dtype=float32), 'hsic_y_zc': DeviceArray(0.144, dtype=float32), 'hsic_zc': DeviceArray(0.208, dtype=float32), 'hsic_zx': DeviceArray(0.41, dtype=float32), 'hsic_zx_zc': DeviceArray(0.015, dtype=float32), 'hsic_zx_zy': DeviceArray(0., dtype=float32), 'hsic_zy': DeviceArray(0.495, dtype=float32), 'hsic_zy_x': DeviceArray(0.004, dtype=float32), 'hsic_zy_zc': DeviceArray(0.044, dtype=float32), 'imp_zx': DeviceArray(0.273, dtype=float32), 'imp_zy': DeviceArray(0.239, dtype=float32), 'mse_rx': DeviceArray(0.778, dtype=float32), 'mse_ry': DeviceArray(0.909, dtype=float32), 'mses': DeviceArray(-0.347, dtype=float32)}
# indxRep: 3  iteration:  30  rep:  5  part:  0
# iteration report:  30
# monitor
# {'hsic_indep': DeviceArray(-21.706, dtype=float32), 'hsic_resids': DeviceArray(-10.471, dtype=float32), 'hsic_rx_ax': DeviceArray(0.007, dtype=float32), 'hsic_ry_ay': DeviceArray(0.004, dtype=float32), 'hsic_x_zc': DeviceArray(0.073, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.51, dtype=float32), 'hsic_y_zc': DeviceArray(0.151, dtype=float32), 'hsic_zc': DeviceArray(0.199, dtype=float32), 'hsic_zx': DeviceArray(0.386, dtype=float32), 'hsic_zx_zc': DeviceArray(0.01, dtype=float32), 'hsic_zx_zy': DeviceArray(0.001, dtype=float32), 'hsic_zy': DeviceArray(0.448, dtype=float32), 'hsic_zy_x': DeviceArray(0.004, dtype=float32), 'hsic_zy_zc': DeviceArray(0.012, dtype=float32), 'imp_zx': DeviceArray(0.256, dtype=float32), 'imp_zy': DeviceArray(0.222, dtype=float32), 'mse_rx': DeviceArray(0.759, dtype=float32), 'mse_ry': DeviceArray(0.94, dtype=float32), 'mses': DeviceArray(-0.337, dtype=float32)}
# indxRep: 3  iteration:  30  rep:  6  part:  0
# iteration report:  40
# monitor
# {'hsic_indep': DeviceArray(-16.347, dtype=float32), 'hsic_resids': DeviceArray(-6.095, dtype=float32), 'hsic_rx_ax': DeviceArray(0.045, dtype=float32), 'hsic_ry_ay': DeviceArray(0.05, dtype=float32), 'hsic_x_zc': DeviceArray(0.016, dtype=float32), 'hsic_xy_zc': DeviceArray(-7.765, dtype=float32), 'hsic_y_zc': DeviceArray(0.027, dtype=float32), 'hsic_zc': DeviceArray(0.041, dtype=float32), 'hsic_zx': DeviceArray(0.141, dtype=float32), 'hsic_zx_zc': DeviceArray(0.02, dtype=float32), 'hsic_zx_zy': DeviceArray(0.016, dtype=float32), 'hsic_zy': DeviceArray(0.189, dtype=float32), 'hsic_zy_x': DeviceArray(0.01, dtype=float32), 'hsic_zy_zc': DeviceArray(0.025, dtype=float32), 'imp_zx': DeviceArray(0.078, dtype=float32), 'imp_zy': DeviceArray(0.07, dtype=float32), 'mse_rx': DeviceArray(0.448, dtype=float32), 'mse_ry': DeviceArray(0.173, dtype=float32), 'mses': DeviceArray(-2.558, dtype=float32)}
# indxRep: 4  iteration:  40  rep:  0  part:  0
# iteration report:  40
# monitor
# {'hsic_indep': DeviceArray(-15.265, dtype=float32), 'hsic_resids': DeviceArray(-6.776, dtype=float32), 'hsic_rx_ax': DeviceArray(0.026, dtype=float32), 'hsic_ry_ay': DeviceArray(0.044, dtype=float32), 'hsic_x_zc': DeviceArray(0.073, dtype=float32), 'hsic_xy_zc': DeviceArray(-5.323, dtype=float32), 'hsic_y_zc': DeviceArray(0.066, dtype=float32), 'hsic_zc': DeviceArray(0.08, dtype=float32), 'hsic_zx': DeviceArray(0.267, dtype=float32), 'hsic_zx_zc': DeviceArray(0.064, dtype=float32), 'hsic_zx_zy': DeviceArray(0.008, dtype=float32), 'hsic_zy': DeviceArray(0.349, dtype=float32), 'hsic_zy_x': DeviceArray(0.007, dtype=float32), 'hsic_zy_zc': DeviceArray(0.064, dtype=float32), 'imp_zx': DeviceArray(0.13, dtype=float32), 'imp_zy': DeviceArray(0.134, dtype=float32), 'mse_rx': DeviceArray(0.657, dtype=float32), 'mse_ry': DeviceArray(0.694, dtype=float32), 'mses': DeviceArray(-0.785, dtype=float32)}
# indxRep: 4  iteration:  40  rep:  1  part:  0
# iteration report:  40
# monitor
# {'hsic_indep': DeviceArray(-14.733, dtype=float32), 'hsic_resids': DeviceArray(-7.566, dtype=float32), 'hsic_rx_ax': DeviceArray(0.015, dtype=float32), 'hsic_ry_ay': DeviceArray(0.034, dtype=float32), 'hsic_x_zc': DeviceArray(0.069, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.617, dtype=float32), 'hsic_y_zc': DeviceArray(0.143, dtype=float32), 'hsic_zc': DeviceArray(0.159, dtype=float32), 'hsic_zx': DeviceArray(0.35, dtype=float32), 'hsic_zx_zc': DeviceArray(0.073, dtype=float32), 'hsic_zx_zy': DeviceArray(0.005, dtype=float32), 'hsic_zy': DeviceArray(0.458, dtype=float32), 'hsic_zy_x': DeviceArray(0.007, dtype=float32), 'hsic_zy_zc': DeviceArray(0.153, dtype=float32), 'imp_zx': DeviceArray(0.19, dtype=float32), 'imp_zy': DeviceArray(0.185, dtype=float32), 'mse_rx': DeviceArray(0.707, dtype=float32), 'mse_ry': DeviceArray(0.811, dtype=float32), 'mses': DeviceArray(-0.556, dtype=float32)}
# indxRep: 4  iteration:  40  rep:  2  part:  0
# iteration report:  40
# monitor
# {'hsic_indep': DeviceArray(-15.742, dtype=float32), 'hsic_resids': DeviceArray(-8.338, dtype=float32), 'hsic_rx_ax': DeviceArray(0.014, dtype=float32), 'hsic_ry_ay': DeviceArray(0.018, dtype=float32), 'hsic_x_zc': DeviceArray(0.066, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.575, dtype=float32), 'hsic_y_zc': DeviceArray(0.157, dtype=float32), 'hsic_zc': DeviceArray(0.201, dtype=float32), 'hsic_zx': DeviceArray(0.403, dtype=float32), 'hsic_zx_zc': DeviceArray(0.059, dtype=float32), 'hsic_zx_zy': DeviceArray(0.003, dtype=float32), 'hsic_zy': DeviceArray(0.519, dtype=float32), 'hsic_zy_x': DeviceArray(0.006, dtype=float32), 'hsic_zy_zc': DeviceArray(0.143, dtype=float32), 'imp_zx': DeviceArray(0.24, dtype=float32), 'imp_zy': DeviceArray(0.225, dtype=float32), 'mse_rx': DeviceArray(0.73, dtype=float32), 'mse_ry': DeviceArray(0.845, dtype=float32), 'mses': DeviceArray(-0.483, dtype=float32)}
# indxRep: 4  iteration:  40  rep:  3  part:  0
# iteration report:  40
# monitor
# {'hsic_indep': DeviceArray(-17.264, dtype=float32), 'hsic_resids': DeviceArray(-8.939, dtype=float32), 'hsic_rx_ax': DeviceArray(0.011, dtype=float32), 'hsic_ry_ay': DeviceArray(0.012, dtype=float32), 'hsic_x_zc': DeviceArray(0.062, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.672, dtype=float32), 'hsic_y_zc': DeviceArray(0.15, dtype=float32), 'hsic_zc': DeviceArray(0.207, dtype=float32), 'hsic_zx': DeviceArray(0.425, dtype=float32), 'hsic_zx_zc': DeviceArray(0.03, dtype=float32), 'hsic_zx_zy': DeviceArray(0.002, dtype=float32), 'hsic_zy': DeviceArray(0.525, dtype=float32), 'hsic_zy_x': DeviceArray(0.005, dtype=float32), 'hsic_zy_zc': DeviceArray(0.092, dtype=float32), 'imp_zx': DeviceArray(0.264, dtype=float32), 'imp_zy': DeviceArray(0.244, dtype=float32), 'mse_rx': DeviceArray(0.744, dtype=float32), 'mse_ry': DeviceArray(0.882, dtype=float32), 'mses': DeviceArray(-0.421, dtype=float32)}
# indxRep: 4  iteration:  40  rep:  4  part:  0
# iteration report:  40
# monitor
# {'hsic_indep': DeviceArray(-20.294, dtype=float32), 'hsic_resids': DeviceArray(-10.363, dtype=float32), 'hsic_rx_ax': DeviceArray(0.004, dtype=float32), 'hsic_ry_ay': DeviceArray(0.007, dtype=float32), 'hsic_x_zc': DeviceArray(0.068, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.685, dtype=float32), 'hsic_y_zc': DeviceArray(0.136, dtype=float32), 'hsic_zc': DeviceArray(0.187, dtype=float32), 'hsic_zx': DeviceArray(0.412, dtype=float32), 'hsic_zx_zc': DeviceArray(0.014, dtype=float32), 'hsic_zx_zy': DeviceArray(0.001, dtype=float32), 'hsic_zy': DeviceArray(0.497, dtype=float32), 'hsic_zy_x': DeviceArray(0.004, dtype=float32), 'hsic_zy_zc': DeviceArray(0.043, dtype=float32), 'imp_zx': DeviceArray(0.267, dtype=float32), 'imp_zy': DeviceArray(0.243, dtype=float32), 'mse_rx': DeviceArray(0.772, dtype=float32), 'mse_ry': DeviceArray(0.912, dtype=float32), 'mses': DeviceArray(-0.351, dtype=float32)}
# indxRep: 4  iteration:  40  rep:  5  part:  0
# iteration report:  40
# monitor
# {'hsic_indep': DeviceArray(-25.287, dtype=float32), 'hsic_resids': DeviceArray(-10.913, dtype=float32), 'hsic_rx_ax': DeviceArray(0.005, dtype=float32), 'hsic_ry_ay': DeviceArray(0.004, dtype=float32), 'hsic_x_zc': DeviceArray(0.057, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.797, dtype=float32), 'hsic_y_zc': DeviceArray(0.145, dtype=float32), 'hsic_zc': DeviceArray(0.203, dtype=float32), 'hsic_zx': DeviceArray(0.382, dtype=float32), 'hsic_zx_zc': DeviceArray(0.003, dtype=float32), 'hsic_zx_zy': DeviceArray(0., dtype=float32), 'hsic_zy': DeviceArray(0.451, dtype=float32), 'hsic_zy_x': DeviceArray(0.002, dtype=float32), 'hsic_zy_zc': DeviceArray(0.011, dtype=float32), 'imp_zx': DeviceArray(0.269, dtype=float32), 'imp_zy': DeviceArray(0.23, dtype=float32), 'mse_rx': DeviceArray(0.788, dtype=float32), 'mse_ry': DeviceArray(0.936, dtype=float32), 'mses': DeviceArray(-0.305, dtype=float32)}
# indxRep: 4  iteration:  40  rep:  6  part:  0
# iteration:  50
# iteration report:  50
# monitor
# {'hsic_indep': DeviceArray(-16.238, dtype=float32), 'hsic_resids': DeviceArray(-5.99, dtype=float32), 'hsic_rx_ax': DeviceArray(0.045, dtype=float32), 'hsic_ry_ay': DeviceArray(0.055, dtype=float32), 'hsic_x_zc': DeviceArray(0.015, dtype=float32), 'hsic_xy_zc': DeviceArray(-7.694, dtype=float32), 'hsic_y_zc': DeviceArray(0.031, dtype=float32), 'hsic_zc': DeviceArray(0.043, dtype=float32), 'hsic_zx': DeviceArray(0.145, dtype=float32), 'hsic_zx_zc': DeviceArray(0.02, dtype=float32), 'hsic_zx_zy': DeviceArray(0.016, dtype=float32), 'hsic_zy': DeviceArray(0.188, dtype=float32), 'hsic_zy_x': DeviceArray(0.01, dtype=float32), 'hsic_zy_zc': DeviceArray(0.027, dtype=float32), 'imp_zx': DeviceArray(0.074, dtype=float32), 'imp_zy': DeviceArray(0.069, dtype=float32), 'mse_rx': DeviceArray(0.456, dtype=float32), 'mse_ry': DeviceArray(0.206, dtype=float32), 'mses': DeviceArray(-2.364, dtype=float32)}
# indxRep: 5  iteration:  50  rep:  0  part:  0
# iteration report:  50
# monitor
# {'hsic_indep': DeviceArray(-15.581, dtype=float32), 'hsic_resids': DeviceArray(-6.819, dtype=float32), 'hsic_rx_ax': DeviceArray(0.025, dtype=float32), 'hsic_ry_ay': DeviceArray(0.044, dtype=float32), 'hsic_x_zc': DeviceArray(0.071, dtype=float32), 'hsic_xy_zc': DeviceArray(-5.526, dtype=float32), 'hsic_y_zc': DeviceArray(0.056, dtype=float32), 'hsic_zc': DeviceArray(0.075, dtype=float32), 'hsic_zx': DeviceArray(0.265, dtype=float32), 'hsic_zx_zc': DeviceArray(0.06, dtype=float32), 'hsic_zx_zy': DeviceArray(0.007, dtype=float32), 'hsic_zy': DeviceArray(0.348, dtype=float32), 'hsic_zy_x': DeviceArray(0.007, dtype=float32), 'hsic_zy_zc': DeviceArray(0.054, dtype=float32), 'imp_zx': DeviceArray(0.132, dtype=float32), 'imp_zy': DeviceArray(0.135, dtype=float32), 'mse_rx': DeviceArray(0.658, dtype=float32), 'mse_ry': DeviceArray(0.69, dtype=float32), 'mses': DeviceArray(-0.79, dtype=float32)}
# indxRep: 5  iteration:  50  rep:  1  part:  0
# iteration report:  50
# monitor
# {'hsic_indep': DeviceArray(-14.958, dtype=float32), 'hsic_resids': DeviceArray(-7.582, dtype=float32), 'hsic_rx_ax': DeviceArray(0.016, dtype=float32), 'hsic_ry_ay': DeviceArray(0.032, dtype=float32), 'hsic_x_zc': DeviceArray(0.069, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.677, dtype=float32), 'hsic_y_zc': DeviceArray(0.134, dtype=float32), 'hsic_zc': DeviceArray(0.152, dtype=float32), 'hsic_zx': DeviceArray(0.349, dtype=float32), 'hsic_zx_zc': DeviceArray(0.072, dtype=float32), 'hsic_zx_zy': DeviceArray(0.005, dtype=float32), 'hsic_zy': DeviceArray(0.459, dtype=float32), 'hsic_zy_x': DeviceArray(0.007, dtype=float32), 'hsic_zy_zc': DeviceArray(0.143, dtype=float32), 'imp_zx': DeviceArray(0.191, dtype=float32), 'imp_zy': DeviceArray(0.187, dtype=float32), 'mse_rx': DeviceArray(0.71, dtype=float32), 'mse_ry': DeviceArray(0.812, dtype=float32), 'mses': DeviceArray(-0.551, dtype=float32)}
# indxRep: 5  iteration:  50  rep:  2  part:  0
# iteration report:  50
# monitor
# {'hsic_indep': DeviceArray(-16.123, dtype=float32), 'hsic_resids': DeviceArray(-8.327, dtype=float32), 'hsic_rx_ax': DeviceArray(0.013, dtype=float32), 'hsic_ry_ay': DeviceArray(0.018, dtype=float32), 'hsic_x_zc': DeviceArray(0.064, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.603, dtype=float32), 'hsic_y_zc': DeviceArray(0.155, dtype=float32), 'hsic_zc': DeviceArray(0.202, dtype=float32), 'hsic_zx': DeviceArray(0.401, dtype=float32), 'hsic_zx_zc': DeviceArray(0.058, dtype=float32), 'hsic_zx_zy': DeviceArray(0.002, dtype=float32), 'hsic_zy': DeviceArray(0.522, dtype=float32), 'hsic_zy_x': DeviceArray(0.006, dtype=float32), 'hsic_zy_zc': DeviceArray(0.142, dtype=float32), 'imp_zx': DeviceArray(0.244, dtype=float32), 'imp_zy': DeviceArray(0.227, dtype=float32), 'mse_rx': DeviceArray(0.735, dtype=float32), 'mse_ry': DeviceArray(0.845, dtype=float32), 'mses': DeviceArray(-0.476, dtype=float32)}
# indxRep: 5  iteration:  50  rep:  3  part:  0
# iteration report:  50
# monitor
# {'hsic_indep': DeviceArray(-18.198, dtype=float32), 'hsic_resids': DeviceArray(-9.025, dtype=float32), 'hsic_rx_ax': DeviceArray(0.01, dtype=float32), 'hsic_ry_ay': DeviceArray(0.012, dtype=float32), 'hsic_x_zc': DeviceArray(0.064, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.66, dtype=float32), 'hsic_y_zc': DeviceArray(0.149, dtype=float32), 'hsic_zc': DeviceArray(0.204, dtype=float32), 'hsic_zx': DeviceArray(0.423, dtype=float32), 'hsic_zx_zc': DeviceArray(0.03, dtype=float32), 'hsic_zx_zy': DeviceArray(0.001, dtype=float32), 'hsic_zy': DeviceArray(0.528, dtype=float32), 'hsic_zy_x': DeviceArray(0.005, dtype=float32), 'hsic_zy_zc': DeviceArray(0.093, dtype=float32), 'imp_zx': DeviceArray(0.271, dtype=float32), 'imp_zy': DeviceArray(0.249, dtype=float32), 'mse_rx': DeviceArray(0.753, dtype=float32), 'mse_ry': DeviceArray(0.882, dtype=float32), 'mses': DeviceArray(-0.409, dtype=float32)}
# indxRep: 5  iteration:  50  rep:  4  part:  0
# iteration report:  50
# monitor
# {'hsic_indep': DeviceArray(-20.825, dtype=float32), 'hsic_resids': DeviceArray(-10.45, dtype=float32), 'hsic_rx_ax': DeviceArray(0.004, dtype=float32), 'hsic_ry_ay': DeviceArray(0.008, dtype=float32), 'hsic_x_zc': DeviceArray(0.076, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.531, dtype=float32), 'hsic_y_zc': DeviceArray(0.141, dtype=float32), 'hsic_zc': DeviceArray(0.189, dtype=float32), 'hsic_zx': DeviceArray(0.412, dtype=float32), 'hsic_zx_zc': DeviceArray(0.019, dtype=float32), 'hsic_zx_zy': DeviceArray(0., dtype=float32), 'hsic_zy': DeviceArray(0.497, dtype=float32), 'hsic_zy_x': DeviceArray(0.004, dtype=float32), 'hsic_zy_zc': DeviceArray(0.045, dtype=float32), 'imp_zx': DeviceArray(0.271, dtype=float32), 'imp_zy': DeviceArray(0.245, dtype=float32), 'mse_rx': DeviceArray(0.775, dtype=float32), 'mse_ry': DeviceArray(0.911, dtype=float32), 'mses': DeviceArray(-0.348, dtype=float32)}
# indxRep: 5  iteration:  50  rep:  5  part:  0
# iteration report:  50
# monitor
# {'hsic_indep': DeviceArray(-21.903, dtype=float32), 'hsic_resids': DeviceArray(-11.002, dtype=float32), 'hsic_rx_ax': DeviceArray(0.005, dtype=float32), 'hsic_ry_ay': DeviceArray(0.004, dtype=float32), 'hsic_x_zc': DeviceArray(0.076, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.477, dtype=float32), 'hsic_y_zc': DeviceArray(0.15, dtype=float32), 'hsic_zc': DeviceArray(0.199, dtype=float32), 'hsic_zx': DeviceArray(0.379, dtype=float32), 'hsic_zx_zc': DeviceArray(0.011, dtype=float32), 'hsic_zx_zy': DeviceArray(0.001, dtype=float32), 'hsic_zy': DeviceArray(0.453, dtype=float32), 'hsic_zy_x': DeviceArray(0.002, dtype=float32), 'hsic_zy_zc': DeviceArray(0.011, dtype=float32), 'imp_zx': DeviceArray(0.279, dtype=float32), 'imp_zy': DeviceArray(0.236, dtype=float32), 'mse_rx': DeviceArray(0.813, dtype=float32), 'mse_ry': DeviceArray(0.938, dtype=float32), 'mses': DeviceArray(-0.271, dtype=float32)}
# indxRep: 5  iteration:  50  rep:  6  part:  0
# iteration report:  60
# monitor
# {'hsic_indep': DeviceArray(-16.477, dtype=float32), 'hsic_resids': DeviceArray(-6.046, dtype=float32), 'hsic_rx_ax': DeviceArray(0.046, dtype=float32), 'hsic_ry_ay': DeviceArray(0.051, dtype=float32), 'hsic_x_zc': DeviceArray(0.01, dtype=float32), 'hsic_xy_zc': DeviceArray(-8.436, dtype=float32), 'hsic_y_zc': DeviceArray(0.022, dtype=float32), 'hsic_zc': DeviceArray(0.028, dtype=float32), 'hsic_zx': DeviceArray(0.148, dtype=float32), 'hsic_zx_zc': DeviceArray(0.02, dtype=float32), 'hsic_zx_zy': DeviceArray(0.016, dtype=float32), 'hsic_zy': DeviceArray(0.188, dtype=float32), 'hsic_zy_x': DeviceArray(0.01, dtype=float32), 'hsic_zy_zc': DeviceArray(0.021, dtype=float32), 'imp_zx': DeviceArray(0.068, dtype=float32), 'imp_zy': DeviceArray(0.07, dtype=float32), 'mse_rx': DeviceArray(0.422, dtype=float32), 'mse_ry': DeviceArray(0.181, dtype=float32), 'mses': DeviceArray(-2.572, dtype=float32)}
# indxRep: 6  iteration:  60  rep:  0  part:  0
# iteration report:  60
# monitor
# {'hsic_indep': DeviceArray(-15.92, dtype=float32), 'hsic_resids': DeviceArray(-6.882, dtype=float32), 'hsic_rx_ax': DeviceArray(0.025, dtype=float32), 'hsic_ry_ay': DeviceArray(0.041, dtype=float32), 'hsic_x_zc': DeviceArray(0.073, dtype=float32), 'hsic_xy_zc': DeviceArray(-5.768, dtype=float32), 'hsic_y_zc': DeviceArray(0.043, dtype=float32), 'hsic_zc': DeviceArray(0.068, dtype=float32), 'hsic_zx': DeviceArray(0.265, dtype=float32), 'hsic_zx_zc': DeviceArray(0.058, dtype=float32), 'hsic_zx_zy': DeviceArray(0.007, dtype=float32), 'hsic_zy': DeviceArray(0.347, dtype=float32), 'hsic_zy_x': DeviceArray(0.007, dtype=float32), 'hsic_zy_zc': DeviceArray(0.041, dtype=float32), 'imp_zx': DeviceArray(0.133, dtype=float32), 'imp_zy': DeviceArray(0.137, dtype=float32), 'mse_rx': DeviceArray(0.663, dtype=float32), 'mse_ry': DeviceArray(0.688, dtype=float32), 'mses': DeviceArray(-0.785, dtype=float32)}
# indxRep: 6  iteration:  60  rep:  1  part:  0
# iteration report:  60
# monitor
# {'hsic_indep': DeviceArray(-15.227, dtype=float32), 'hsic_resids': DeviceArray(-7.606, dtype=float32), 'hsic_rx_ax': DeviceArray(0.016, dtype=float32), 'hsic_ry_ay': DeviceArray(0.031, dtype=float32), 'hsic_x_zc': DeviceArray(0.071, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.743, dtype=float32), 'hsic_y_zc': DeviceArray(0.122, dtype=float32), 'hsic_zc': DeviceArray(0.138, dtype=float32), 'hsic_zx': DeviceArray(0.349, dtype=float32), 'hsic_zx_zc': DeviceArray(0.072, dtype=float32), 'hsic_zx_zy': DeviceArray(0.004, dtype=float32), 'hsic_zy': DeviceArray(0.461, dtype=float32), 'hsic_zy_x': DeviceArray(0.006, dtype=float32), 'hsic_zy_zc': DeviceArray(0.129, dtype=float32), 'imp_zx': DeviceArray(0.193, dtype=float32), 'imp_zy': DeviceArray(0.189, dtype=float32), 'mse_rx': DeviceArray(0.713, dtype=float32), 'mse_ry': DeviceArray(0.813, dtype=float32), 'mses': DeviceArray(-0.546, dtype=float32)}
# indxRep: 6  iteration:  60  rep:  2  part:  0
# iteration report:  60
# monitor
# {'hsic_indep': DeviceArray(-16.381, dtype=float32), 'hsic_resids': DeviceArray(-8.328, dtype=float32), 'hsic_rx_ax': DeviceArray(0.013, dtype=float32), 'hsic_ry_ay': DeviceArray(0.019, dtype=float32), 'hsic_x_zc': DeviceArray(0.066, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.581, dtype=float32), 'hsic_y_zc': DeviceArray(0.155, dtype=float32), 'hsic_zc': DeviceArray(0.199, dtype=float32), 'hsic_zx': DeviceArray(0.401, dtype=float32), 'hsic_zx_zc': DeviceArray(0.058, dtype=float32), 'hsic_zx_zy': DeviceArray(0.002, dtype=float32), 'hsic_zy': DeviceArray(0.523, dtype=float32), 'hsic_zy_x': DeviceArray(0.005, dtype=float32), 'hsic_zy_zc': DeviceArray(0.142, dtype=float32), 'imp_zx': DeviceArray(0.245, dtype=float32), 'imp_zy': DeviceArray(0.231, dtype=float32), 'mse_rx': DeviceArray(0.739, dtype=float32), 'mse_ry': DeviceArray(0.844, dtype=float32), 'mses': DeviceArray(-0.472, dtype=float32)}
# indxRep: 6  iteration:  60  rep:  3  part:  0
# iteration report:  60
# monitor
# {'hsic_indep': DeviceArray(-18.428, dtype=float32), 'hsic_resids': DeviceArray(-8.994, dtype=float32), 'hsic_rx_ax': DeviceArray(0.011, dtype=float32), 'hsic_ry_ay': DeviceArray(0.012, dtype=float32), 'hsic_x_zc': DeviceArray(0.062, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.696, dtype=float32), 'hsic_y_zc': DeviceArray(0.146, dtype=float32), 'hsic_zc': DeviceArray(0.2, dtype=float32), 'hsic_zx': DeviceArray(0.425, dtype=float32), 'hsic_zx_zc': DeviceArray(0.028, dtype=float32), 'hsic_zx_zy': DeviceArray(0.001, dtype=float32), 'hsic_zy': DeviceArray(0.529, dtype=float32), 'hsic_zy_x': DeviceArray(0.004, dtype=float32), 'hsic_zy_zc': DeviceArray(0.092, dtype=float32), 'imp_zx': DeviceArray(0.269, dtype=float32), 'imp_zy': DeviceArray(0.252, dtype=float32), 'mse_rx': DeviceArray(0.757, dtype=float32), 'mse_ry': DeviceArray(0.884, dtype=float32), 'mses': DeviceArray(-0.401, dtype=float32)}
# indxRep: 6  iteration:  60  rep:  4  part:  0
# iteration report:  60
# monitor
# {'hsic_indep': DeviceArray(-19.438, dtype=float32), 'hsic_resids': DeviceArray(-9.951, dtype=float32), 'hsic_rx_ax': DeviceArray(0.007, dtype=float32), 'hsic_ry_ay': DeviceArray(0.007, dtype=float32), 'hsic_x_zc': DeviceArray(0.068, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.651, dtype=float32), 'hsic_y_zc': DeviceArray(0.141, dtype=float32), 'hsic_zc': DeviceArray(0.19, dtype=float32), 'hsic_zx': DeviceArray(0.417, dtype=float32), 'hsic_zx_zc': DeviceArray(0.012, dtype=float32), 'hsic_zx_zy': DeviceArray(0.002, dtype=float32), 'hsic_zy': DeviceArray(0.497, dtype=float32), 'hsic_zy_x': DeviceArray(0.004, dtype=float32), 'hsic_zy_zc': DeviceArray(0.046, dtype=float32), 'imp_zx': DeviceArray(0.257, dtype=float32), 'imp_zy': DeviceArray(0.244, dtype=float32), 'mse_rx': DeviceArray(0.763, dtype=float32), 'mse_ry': DeviceArray(0.913, dtype=float32), 'mses': DeviceArray(-0.361, dtype=float32)}
# indxRep: 6  iteration:  60  rep:  5  part:  0
# iteration report:  60
# monitor
# ...
# indxRep: 98  iteration:  980  rep:  4  part:  0
# iteration report:  980
# monitor
# {'hsic_indep': DeviceArray(-27.208, dtype=float32), 'hsic_resids': DeviceArray(-10.084, dtype=float32), 'hsic_rx_ax': DeviceArray(0.006, dtype=float32), 'hsic_ry_ay': DeviceArray(0.008, dtype=float32), 'hsic_x_zc': DeviceArray(0.194, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.219, dtype=float32), 'hsic_y_zc': DeviceArray(0.076, dtype=float32), 'hsic_zc': DeviceArray(0.051, dtype=float32), 'hsic_zx': DeviceArray(0.307, dtype=float32), 'hsic_zx_zc': DeviceArray(0.001, dtype=float32), 'hsic_zx_zy': DeviceArray(0., dtype=float32), 'hsic_zy': DeviceArray(0.463, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.004, dtype=float32), 'imp_zx': DeviceArray(0.12, dtype=float32), 'imp_zy': DeviceArray(0.353, dtype=float32), 'mse_rx': DeviceArray(1.016, dtype=float32), 'mse_ry': DeviceArray(1.082, dtype=float32), 'mses': DeviceArray(0.094, dtype=float32)}
# indxRep: 98  iteration:  980  rep:  5  part:  0
# iteration report:  980
# monitor
# {'hsic_indep': DeviceArray(-24.914, dtype=float32), 'hsic_resids': DeviceArray(-10.058, dtype=float32), 'hsic_rx_ax': DeviceArray(0.006, dtype=float32), 'hsic_ry_ay': DeviceArray(0.007, dtype=float32), 'hsic_x_zc': DeviceArray(0.143, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.636, dtype=float32), 'hsic_y_zc': DeviceArray(0.068, dtype=float32), 'hsic_zc': DeviceArray(0.118, dtype=float32), 'hsic_zx': DeviceArray(0.351, dtype=float32), 'hsic_zx_zc': DeviceArray(0.009, dtype=float32), 'hsic_zx_zy': DeviceArray(0.001, dtype=float32), 'hsic_zy': DeviceArray(0.467, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.003, dtype=float32), 'imp_zx': DeviceArray(0.138, dtype=float32), 'imp_zy': DeviceArray(0.294, dtype=float32), 'mse_rx': DeviceArray(0.961, dtype=float32), 'mse_ry': DeviceArray(0.982, dtype=float32), 'mses': DeviceArray(-0.058, dtype=float32)}
# indxRep: 98  iteration:  980  rep:  6  part:  0
# iteration report:  990
# monitor
# {'hsic_indep': DeviceArray(-16.69, dtype=float32), 'hsic_resids': DeviceArray(-6.606, dtype=float32), 'hsic_rx_ax': DeviceArray(0.04, dtype=float32), 'hsic_ry_ay': DeviceArray(0.034, dtype=float32), 'hsic_x_zc': DeviceArray(0.028, dtype=float32), 'hsic_xy_zc': DeviceArray(-7.407, dtype=float32), 'hsic_y_zc': DeviceArray(0.022, dtype=float32), 'hsic_zc': DeviceArray(0.08, dtype=float32), 'hsic_zx': DeviceArray(0.146, dtype=float32), 'hsic_zx_zc': DeviceArray(0.02, dtype=float32), 'hsic_zx_zy': DeviceArray(0.014, dtype=float32), 'hsic_zy': DeviceArray(0.188, dtype=float32), 'hsic_zy_x': DeviceArray(0.008, dtype=float32), 'hsic_zy_zc': DeviceArray(0.025, dtype=float32), 'imp_zx': DeviceArray(0.074, dtype=float32), 'imp_zy': DeviceArray(0.079, dtype=float32), 'mse_rx': DeviceArray(0.574, dtype=float32), 'mse_ry': DeviceArray(0.143, dtype=float32), 'mses': DeviceArray(-2.496, dtype=float32)}
# indxRep: 99  iteration:  990  rep:  0  part:  0
# iteration report:  990
# monitor
# {'hsic_indep': DeviceArray(-19.768, dtype=float32), 'hsic_resids': DeviceArray(-7.782, dtype=float32), 'hsic_rx_ax': DeviceArray(0.013, dtype=float32), 'hsic_ry_ay': DeviceArray(0.033, dtype=float32), 'hsic_x_zc': DeviceArray(0.126, dtype=float32), 'hsic_xy_zc': DeviceArray(-5.419, dtype=float32), 'hsic_y_zc': DeviceArray(0.035, dtype=float32), 'hsic_zc': DeviceArray(0.048, dtype=float32), 'hsic_zx': DeviceArray(0.167, dtype=float32), 'hsic_zx_zc': DeviceArray(0.017, dtype=float32), 'hsic_zx_zy': DeviceArray(0.005, dtype=float32), 'hsic_zy': DeviceArray(0.349, dtype=float32), 'hsic_zy_x': DeviceArray(0.002, dtype=float32), 'hsic_zy_zc': DeviceArray(0.012, dtype=float32), 'imp_zx': DeviceArray(0.095, dtype=float32), 'imp_zy': DeviceArray(0.211, dtype=float32), 'mse_rx': DeviceArray(0.816, dtype=float32), 'mse_ry': DeviceArray(0.679, dtype=float32), 'mses': DeviceArray(-0.591, dtype=float32)}
# indxRep: 99  iteration:  990  rep:  1  part:  0
# iteration report:  990
# monitor
# {'hsic_indep': DeviceArray(-21.813, dtype=float32), 'hsic_resids': DeviceArray(-8.391, dtype=float32), 'hsic_rx_ax': DeviceArray(0.011, dtype=float32), 'hsic_ry_ay': DeviceArray(0.021, dtype=float32), 'hsic_x_zc': DeviceArray(0.123, dtype=float32), 'hsic_xy_zc': DeviceArray(-5.009, dtype=float32), 'hsic_y_zc': DeviceArray(0.054, dtype=float32), 'hsic_zc': DeviceArray(0.027, dtype=float32), 'hsic_zx': DeviceArray(0.22, dtype=float32), 'hsic_zx_zc': DeviceArray(0.013, dtype=float32), 'hsic_zx_zy': DeviceArray(0.002, dtype=float32), 'hsic_zy': DeviceArray(0.43, dtype=float32), 'hsic_zy_x': DeviceArray(0.002, dtype=float32), 'hsic_zy_zc': DeviceArray(0.007, dtype=float32), 'imp_zx': DeviceArray(0.125, dtype=float32), 'imp_zy': DeviceArray(0.31, dtype=float32), 'mse_rx': DeviceArray(0.884, dtype=float32), 'mse_ry': DeviceArray(0.872, dtype=float32), 'mses': DeviceArray(-0.26, dtype=float32)}
# indxRep: 99  iteration:  990  rep:  2  part:  0
# iteration report:  990
# monitor
# {'hsic_indep': DeviceArray(-23.447, dtype=float32), 'hsic_resids': DeviceArray(-9.248, dtype=float32), 'hsic_rx_ax': DeviceArray(0.008, dtype=float32), 'hsic_ry_ay': DeviceArray(0.013, dtype=float32), 'hsic_x_zc': DeviceArray(0.158, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.759, dtype=float32), 'hsic_y_zc': DeviceArray(0.054, dtype=float32), 'hsic_zc': DeviceArray(0.036, dtype=float32), 'hsic_zx': DeviceArray(0.253, dtype=float32), 'hsic_zx_zc': DeviceArray(0.008, dtype=float32), 'hsic_zx_zy': DeviceArray(0.001, dtype=float32), 'hsic_zy': DeviceArray(0.487, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.005, dtype=float32), 'imp_zx': DeviceArray(0.12, dtype=float32), 'imp_zy': DeviceArray(0.356, dtype=float32), 'mse_rx': DeviceArray(1.013, dtype=float32), 'mse_ry': DeviceArray(0.959, dtype=float32), 'mses': DeviceArray(-0.029, dtype=float32)}
# indxRep: 99  iteration:  990  rep:  3  part:  0
# iteration report:  990
# monitor
# {'hsic_indep': DeviceArray(-25.428, dtype=float32), 'hsic_resids': DeviceArray(-9.803, dtype=float32), 'hsic_rx_ax': DeviceArray(0.006, dtype=float32), 'hsic_ry_ay': DeviceArray(0.01, dtype=float32), 'hsic_x_zc': DeviceArray(0.19, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.366, dtype=float32), 'hsic_y_zc': DeviceArray(0.067, dtype=float32), 'hsic_zc': DeviceArray(0.05, dtype=float32), 'hsic_zx': DeviceArray(0.295, dtype=float32), 'hsic_zx_zc': DeviceArray(0.005, dtype=float32), 'hsic_zx_zy': DeviceArray(0., dtype=float32), 'hsic_zy': DeviceArray(0.492, dtype=float32), 'hsic_zy_x': DeviceArray(0.002, dtype=float32), 'hsic_zy_zc': DeviceArray(0.002, dtype=float32), 'imp_zx': DeviceArray(0.13, dtype=float32), 'imp_zy': DeviceArray(0.386, dtype=float32), 'mse_rx': DeviceArray(0.963, dtype=float32), 'mse_ry': DeviceArray(1.035, dtype=float32), 'mses': DeviceArray(-0.004, dtype=float32)}
# indxRep: 99  iteration:  990  rep:  4  part:  0
# iteration report:  990
# monitor
# {'hsic_indep': DeviceArray(-26.947, dtype=float32), 'hsic_resids': DeviceArray(-10.042, dtype=float32), 'hsic_rx_ax': DeviceArray(0.006, dtype=float32), 'hsic_ry_ay': DeviceArray(0.007, dtype=float32), 'hsic_x_zc': DeviceArray(0.221, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.226, dtype=float32), 'hsic_y_zc': DeviceArray(0.066, dtype=float32), 'hsic_zc': DeviceArray(0.063, dtype=float32), 'hsic_zx': DeviceArray(0.318, dtype=float32), 'hsic_zx_zc': DeviceArray(0.005, dtype=float32), 'hsic_zx_zy': DeviceArray(0., dtype=float32), 'hsic_zy': DeviceArray(0.463, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.002, dtype=float32), 'imp_zx': DeviceArray(0.127, dtype=float32), 'imp_zy': DeviceArray(0.354, dtype=float32), 'mse_rx': DeviceArray(1.014, dtype=float32), 'mse_ry': DeviceArray(1.116, dtype=float32), 'mses': DeviceArray(0.123, dtype=float32)}
# indxRep: 99  iteration:  990  rep:  5  part:  0
# iteration report:  990
# monitor
# {'hsic_indep': DeviceArray(-27.024, dtype=float32), 'hsic_resids': DeviceArray(-10.037, dtype=float32), 'hsic_rx_ax': DeviceArray(0.006, dtype=float32), 'hsic_ry_ay': DeviceArray(0.008, dtype=float32), 'hsic_x_zc': DeviceArray(0.156, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.637, dtype=float32), 'hsic_y_zc': DeviceArray(0.062, dtype=float32), 'hsic_zc': DeviceArray(0.122, dtype=float32), 'hsic_zx': DeviceArray(0.36, dtype=float32), 'hsic_zx_zc': DeviceArray(0.003, dtype=float32), 'hsic_zx_zy': DeviceArray(0., dtype=float32), 'hsic_zy': DeviceArray(0.466, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.003, dtype=float32), 'imp_zx': DeviceArray(0.129, dtype=float32), 'imp_zy': DeviceArray(0.295, dtype=float32), 'mse_rx': DeviceArray(0.964, dtype=float32), 'mse_ry': DeviceArray(0.989, dtype=float32), 'mses': DeviceArray(-0.047, dtype=float32)}
# indxRep: 99  iteration:  990  rep:  6  part:  0
# iteration:  1000
# iteration report:  1000
# monitor
# {'hsic_indep': DeviceArray(-16.701, dtype=float32), 'hsic_resids': DeviceArray(-6.479, dtype=float32), 'hsic_rx_ax': DeviceArray(0.041, dtype=float32), 'hsic_ry_ay': DeviceArray(0.037, dtype=float32), 'hsic_x_zc': DeviceArray(0.024, dtype=float32), 'hsic_xy_zc': DeviceArray(-7.589, dtype=float32), 'hsic_y_zc': DeviceArray(0.021, dtype=float32), 'hsic_zc': DeviceArray(0.059, dtype=float32), 'hsic_zx': DeviceArray(0.147, dtype=float32), 'hsic_zx_zc': DeviceArray(0.021, dtype=float32), 'hsic_zx_zy': DeviceArray(0.014, dtype=float32), 'hsic_zy': DeviceArray(0.189, dtype=float32), 'hsic_zy_x': DeviceArray(0.008, dtype=float32), 'hsic_zy_zc': DeviceArray(0.024, dtype=float32), 'imp_zx': DeviceArray(0.072, dtype=float32), 'imp_zy': DeviceArray(0.079, dtype=float32), 'mse_rx': DeviceArray(0.535, dtype=float32), 'mse_ry': DeviceArray(0.151, dtype=float32), 'mses': DeviceArray(-2.515, dtype=float32)}
# indxRep: 100  iteration:  1000  rep:  0  part:  0
# iteration report:  1000
# monitor
# {'hsic_indep': DeviceArray(-19.897, dtype=float32), 'hsic_resids': DeviceArray(-7.756, dtype=float32), 'hsic_rx_ax': DeviceArray(0.013, dtype=float32), 'hsic_ry_ay': DeviceArray(0.033, dtype=float32), 'hsic_x_zc': DeviceArray(0.134, dtype=float32), 'hsic_xy_zc': DeviceArray(-5.407, dtype=float32), 'hsic_y_zc': DeviceArray(0.033, dtype=float32), 'hsic_zc': DeviceArray(0.044, dtype=float32), 'hsic_zx': DeviceArray(0.165, dtype=float32), 'hsic_zx_zc': DeviceArray(0.018, dtype=float32), 'hsic_zx_zy': DeviceArray(0.005, dtype=float32), 'hsic_zy': DeviceArray(0.349, dtype=float32), 'hsic_zy_x': DeviceArray(0.002, dtype=float32), 'hsic_zy_zc': DeviceArray(0.01, dtype=float32), 'imp_zx': DeviceArray(0.097, dtype=float32), 'imp_zy': DeviceArray(0.212, dtype=float32), 'mse_rx': DeviceArray(0.832, dtype=float32), 'mse_ry': DeviceArray(0.693, dtype=float32), 'mses': DeviceArray(-0.551, dtype=float32)}
# indxRep: 100  iteration:  1000  rep:  1  part:  0
# iteration report:  1000
# monitor
# {'hsic_indep': DeviceArray(-21.706, dtype=float32), 'hsic_resids': DeviceArray(-8.405, dtype=float32), 'hsic_rx_ax': DeviceArray(0.011, dtype=float32), 'hsic_ry_ay': DeviceArray(0.021, dtype=float32), 'hsic_x_zc': DeviceArray(0.125, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.989, dtype=float32), 'hsic_y_zc': DeviceArray(0.054, dtype=float32), 'hsic_zc': DeviceArray(0.027, dtype=float32), 'hsic_zx': DeviceArray(0.218, dtype=float32), 'hsic_zx_zc': DeviceArray(0.013, dtype=float32), 'hsic_zx_zy': DeviceArray(0.002, dtype=float32), 'hsic_zy': DeviceArray(0.431, dtype=float32), 'hsic_zy_x': DeviceArray(0.002, dtype=float32), 'hsic_zy_zc': DeviceArray(0.007, dtype=float32), 'imp_zx': DeviceArray(0.127, dtype=float32), 'imp_zy': DeviceArray(0.311, dtype=float32), 'mse_rx': DeviceArray(0.883, dtype=float32), 'mse_ry': DeviceArray(0.871, dtype=float32), 'mses': DeviceArray(-0.262, dtype=float32)}
# indxRep: 100  iteration:  1000  rep:  2  part:  0
# iteration report:  1000
# monitor
# {'hsic_indep': DeviceArray(-23.623, dtype=float32), 'hsic_resids': DeviceArray(-9.283, dtype=float32), 'hsic_rx_ax': DeviceArray(0.007, dtype=float32), 'hsic_ry_ay': DeviceArray(0.013, dtype=float32), 'hsic_x_zc': DeviceArray(0.164, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.764, dtype=float32), 'hsic_y_zc': DeviceArray(0.052, dtype=float32), 'hsic_zc': DeviceArray(0.039, dtype=float32), 'hsic_zx': DeviceArray(0.252, dtype=float32), 'hsic_zx_zc': DeviceArray(0.008, dtype=float32), 'hsic_zx_zy': DeviceArray(0.001, dtype=float32), 'hsic_zy': DeviceArray(0.487, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.004, dtype=float32), 'imp_zx': DeviceArray(0.117, dtype=float32), 'imp_zy': DeviceArray(0.358, dtype=float32), 'mse_rx': DeviceArray(1.018, dtype=float32), 'mse_ry': DeviceArray(0.964, dtype=float32), 'mses': DeviceArray(-0.019, dtype=float32)}
# indxRep: 100  iteration:  1000  rep:  3  part:  0
# iteration report:  1000
# monitor
# {'hsic_indep': DeviceArray(-25.834, dtype=float32), 'hsic_resids': DeviceArray(-9.811, dtype=float32), 'hsic_rx_ax': DeviceArray(0.006, dtype=float32), 'hsic_ry_ay': DeviceArray(0.01, dtype=float32), 'hsic_x_zc': DeviceArray(0.188, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.435, dtype=float32), 'hsic_y_zc': DeviceArray(0.063, dtype=float32), 'hsic_zc': DeviceArray(0.051, dtype=float32), 'hsic_zx': DeviceArray(0.29, dtype=float32), 'hsic_zx_zc': DeviceArray(0.004, dtype=float32), 'hsic_zx_zy': DeviceArray(0., dtype=float32), 'hsic_zy': DeviceArray(0.491, dtype=float32), 'hsic_zy_x': DeviceArray(0.002, dtype=float32), 'hsic_zy_zc': DeviceArray(0.002, dtype=float32), 'imp_zx': DeviceArray(0.124, dtype=float32), 'imp_zy': DeviceArray(0.386, dtype=float32), 'mse_rx': DeviceArray(0.964, dtype=float32), 'mse_ry': DeviceArray(1.031, dtype=float32), 'mses': DeviceArray(-0.006, dtype=float32)}
# indxRep: 100  iteration:  1000  rep:  4  part:  0
# iteration report:  1000
# monitor
# {'hsic_indep': DeviceArray(-28.914, dtype=float32), 'hsic_resids': DeviceArray(-10.068, dtype=float32), 'hsic_rx_ax': DeviceArray(0.006, dtype=float32), 'hsic_ry_ay': DeviceArray(0.007, dtype=float32), 'hsic_x_zc': DeviceArray(0.214, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.38, dtype=float32), 'hsic_y_zc': DeviceArray(0.059, dtype=float32), 'hsic_zc': DeviceArray(0.069, dtype=float32), 'hsic_zx': DeviceArray(0.308, dtype=float32), 'hsic_zx_zc': DeviceArray(0.002, dtype=float32), 'hsic_zx_zy': DeviceArray(0., dtype=float32), 'hsic_zy': DeviceArray(0.461, dtype=float32), 'hsic_zy_x': DeviceArray(0.002, dtype=float32), 'hsic_zy_zc': DeviceArray(0.001, dtype=float32), 'imp_zx': DeviceArray(0.125, dtype=float32), 'imp_zy': DeviceArray(0.358, dtype=float32), 'mse_rx': DeviceArray(0.997, dtype=float32), 'mse_ry': DeviceArray(1.103, dtype=float32), 'mses': DeviceArray(0.096, dtype=float32)}
# indxRep: 100  iteration:  1000  rep:  5  part:  0
# iteration report:  1000
# monitor
# {'hsic_indep': DeviceArray(-26.703, dtype=float32), 'hsic_resids': DeviceArray(-10.076, dtype=float32), 'hsic_rx_ax': DeviceArray(0.005, dtype=float32), 'hsic_ry_ay': DeviceArray(0.008, dtype=float32), 'hsic_x_zc': DeviceArray(0.154, dtype=float32), 'hsic_xy_zc': DeviceArray(-4.624, dtype=float32), 'hsic_y_zc': DeviceArray(0.064, dtype=float32), 'hsic_zc': DeviceArray(0.115, dtype=float32), 'hsic_zx': DeviceArray(0.359, dtype=float32), 'hsic_zx_zc': DeviceArray(0.003, dtype=float32), 'hsic_zx_zy': DeviceArray(0., dtype=float32), 'hsic_zy': DeviceArray(0.466, dtype=float32), 'hsic_zy_x': DeviceArray(0.001, dtype=float32), 'hsic_zy_zc': DeviceArray(0.003, dtype=float32), 'imp_zx': DeviceArray(0.129, dtype=float32), 'imp_zy': DeviceArray(0.294, dtype=float32), 'mse_rx': DeviceArray(0.96, dtype=float32), 'mse_ry': DeviceArray(0.991, dtype=float32), 'mses': DeviceArray(-0.05, dtype=float32)}
# indxRep: 100  iteration:  1000  rep:  6  part:  0
# results

# %%
res.keys()
# Out:
# dict_keys(['params', 'path'])

# %%
res["path"].keys()
# Out:
# dict_keys(['loss', 'hsic_rx_ax', 'hsic_ry_ay', 'hsic_resids', 'hsic_zx_zy', 'hsic_zx_zc', 'hsic_zy_zc', 'hsic_zy_x', 'hsic_indep', 'hsic_x_zc', 'hsic_y_zc', 'hsic_xy_zc', 'mse_rx', 'mse_ry', 'mses', 'hsic_zx', 'hsic_zy', 'hsic_zc', 'imp_zx', 'imp_zy'])

# %%
res["path"]["loss"].shape
# Out:
# (101, 7, 1)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["loss"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7f63cc3502d0>,
#  <matplotlib.lines.Line2D at 0x7f62cf331750>,
#  <matplotlib.lines.Line2D at 0x7f62cf33d3d0>,
#  <matplotlib.lines.Line2D at 0x7f62cf33d4d0>,
#  <matplotlib.lines.Line2D at 0x7f62cf33d5d0>,
#  <matplotlib.lines.Line2D at 0x7f62cf33d610>,
#  <matplotlib.lines.Line2D at 0x7f62cf33d850>]

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["hsic_indep"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7f62cd9f6950>,
#  <matplotlib.lines.Line2D at 0x7f62cf8f4110>,
#  <matplotlib.lines.Line2D at 0x7f62cd9f6b90>,
#  <matplotlib.lines.Line2D at 0x7f62cd9f6c90>,
#  <matplotlib.lines.Line2D at 0x7f62cd9f6d90>,
#  <matplotlib.lines.Line2D at 0x7f62cd9f6dd0>,
#  <matplotlib.lines.Line2D at 0x7f62cd9f6f10>]

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["hsic_resids"][:,::,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7f62cd920610>,
#  <matplotlib.lines.Line2D at 0x7f62cd991890>,
#  <matplotlib.lines.Line2D at 0x7f62cd920850>,
#  <matplotlib.lines.Line2D at 0x7f62cd920950>,
#  <matplotlib.lines.Line2D at 0x7f62cd920a50>,
#  <matplotlib.lines.Line2D at 0x7f62cd920a90>,
#  <matplotlib.lines.Line2D at 0x7f62cd920cd0>]

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["mses"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7f62cd8aefd0>,
#  <matplotlib.lines.Line2D at 0x7f62cd8ae290>,
#  <matplotlib.lines.Line2D at 0x7f62cd8bd250>,
#  <matplotlib.lines.Line2D at 0x7f62cd8bd350>,
#  <matplotlib.lines.Line2D at 0x7f62cd8bd450>,
#  <matplotlib.lines.Line2D at 0x7f62cd8bd490>,
#  <matplotlib.lines.Line2D at 0x7f62cd8bd6d0>]

# %% [markdown]
# ## resids

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["hsic_rx_ax"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7f62cd84e310>,
#  <matplotlib.lines.Line2D at 0x7f62cd8405d0>,
#  <matplotlib.lines.Line2D at 0x7f62cd84e550>,
#  <matplotlib.lines.Line2D at 0x7f62cd84e650>,
#  <matplotlib.lines.Line2D at 0x7f62cd84e750>,
#  <matplotlib.lines.Line2D at 0x7f62cd84e790>,
#  <matplotlib.lines.Line2D at 0x7f62cd84e9d0>]

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["hsic_ry_ay"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7f62cd758910>,
#  <matplotlib.lines.Line2D at 0x7f62cd7c8c50>,
#  <matplotlib.lines.Line2D at 0x7f62cd758b50>,
#  <matplotlib.lines.Line2D at 0x7f62cd758c50>,
#  <matplotlib.lines.Line2D at 0x7f62cd758d50>,
#  <matplotlib.lines.Line2D at 0x7f62cd758d90>,
#  <matplotlib.lines.Line2D at 0x7f62cd758fd0>]

# %% [markdown]
# ## indeps

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["hsic_zx_zy"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7f62cd6e87d0>,
#  <matplotlib.lines.Line2D at 0x7f62cd6dba50>,
#  <matplotlib.lines.Line2D at 0x7f62cd6e8a10>,
#  <matplotlib.lines.Line2D at 0x7f62cd6e8b10>,
#  <matplotlib.lines.Line2D at 0x7f62cd6e8c10>,
#  <matplotlib.lines.Line2D at 0x7f62cd6e8c50>,
#  <matplotlib.lines.Line2D at 0x7f62cd6e8e90>]

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["hsic_zx_zc"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7f62cd6786d0>,
#  <matplotlib.lines.Line2D at 0x7f62cd6bf990>,
#  <matplotlib.lines.Line2D at 0x7f62cd678910>,
#  <matplotlib.lines.Line2D at 0x7f62cd678a10>,
#  <matplotlib.lines.Line2D at 0x7f62cd678b10>,
#  <matplotlib.lines.Line2D at 0x7f62cd678b50>,
#  <matplotlib.lines.Line2D at 0x7f62cd678d90>]

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["hsic_zy_zc"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7f62cd610a50>,
#  <matplotlib.lines.Line2D at 0x7f62cd603d10>,
#  <matplotlib.lines.Line2D at 0x7f62cd610c90>,
#  <matplotlib.lines.Line2D at 0x7f62cd610d90>,
#  <matplotlib.lines.Line2D at 0x7f62cd610e90>,
#  <matplotlib.lines.Line2D at 0x7f62cd610ed0>,
#  <matplotlib.lines.Line2D at 0x7f62cd59e150>]

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["hsic_zy_x"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7f62cd535310>,
#  <matplotlib.lines.Line2D at 0x7f62cd527590>,
#  <matplotlib.lines.Line2D at 0x7f62cd535550>,
#  <matplotlib.lines.Line2D at 0x7f62cd535650>,
#  <matplotlib.lines.Line2D at 0x7f62cd535750>,
#  <matplotlib.lines.Line2D at 0x7f62cd535790>,
#  <matplotlib.lines.Line2D at 0x7f62cd5359d0>]

# %% [markdown]
# # mses

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["mse_rx"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7f62cd4c2850>,
#  <matplotlib.lines.Line2D at 0x7f62cd4b4ad0>,
#  <matplotlib.lines.Line2D at 0x7f62cd4c2a90>,
#  <matplotlib.lines.Line2D at 0x7f62cd4c2b90>,
#  <matplotlib.lines.Line2D at 0x7f62cd4c2c90>,
#  <matplotlib.lines.Line2D at 0x7f62cd4c2cd0>,
#  <matplotlib.lines.Line2D at 0x7f62cd4c2f10>]

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["mse_ry"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7f62cd3dd490>,
#  <matplotlib.lines.Line2D at 0x7f62cd450710>,
#  <matplotlib.lines.Line2D at 0x7f62cd3dd6d0>,
#  <matplotlib.lines.Line2D at 0x7f62cd3dd7d0>,
#  <matplotlib.lines.Line2D at 0x7f62cd3dd8d0>,
#  <matplotlib.lines.Line2D at 0x7f62cd3dd910>,
#  <matplotlib.lines.Line2D at 0x7f62cd3ddb50>]

# %% [markdown]
# ## zs vs z_est

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["hsic_zx"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7f62cd36d290>,
#  <matplotlib.lines.Line2D at 0x7f62cd35e510>,
#  <matplotlib.lines.Line2D at 0x7f62cd36d4d0>,
#  <matplotlib.lines.Line2D at 0x7f62cd36d5d0>,
#  <matplotlib.lines.Line2D at 0x7f62cd36d6d0>,
#  <matplotlib.lines.Line2D at 0x7f62cd36d710>,
#  <matplotlib.lines.Line2D at 0x7f62cd36d950>]

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["hsic_zy"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7f62cd304510>,
#  <matplotlib.lines.Line2D at 0x7f62cd2f87d0>,
#  <matplotlib.lines.Line2D at 0x7f62cd304750>,
#  <matplotlib.lines.Line2D at 0x7f62cd304850>,
#  <matplotlib.lines.Line2D at 0x7f62cd304950>,
#  <matplotlib.lines.Line2D at 0x7f62cd304990>,
#  <matplotlib.lines.Line2D at 0x7f62cd304bd0>]

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["hsic_zc"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7f62cd21d790>,
#  <matplotlib.lines.Line2D at 0x7f62cd28da50>,
#  <matplotlib.lines.Line2D at 0x7f62cd21d9d0>,
#  <matplotlib.lines.Line2D at 0x7f62cd21dad0>,
#  <matplotlib.lines.Line2D at 0x7f62cd21dbd0>,
#  <matplotlib.lines.Line2D at 0x7f62cd21dc10>,
#  <matplotlib.lines.Line2D at 0x7f62cd21de50>]

# %% [markdown]
# ## zc in zx and zy

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["imp_zx"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7f62cd1a1fd0>,
#  <matplotlib.lines.Line2D at 0x7f62cd1a1290>,
#  <matplotlib.lines.Line2D at 0x7f62cd1b0250>,
#  <matplotlib.lines.Line2D at 0x7f62cd1b0350>,
#  <matplotlib.lines.Line2D at 0x7f62cd1b0450>,
#  <matplotlib.lines.Line2D at 0x7f62cd1b0490>,
#  <matplotlib.lines.Line2D at 0x7f62cd1b06d0>]

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["imp_zy"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7f62cd12cdd0>,
#  <matplotlib.lines.Line2D at 0x7f62cd12c190>,
#  <matplotlib.lines.Line2D at 0x7f62cd12cf50>,
#  <matplotlib.lines.Line2D at 0x7f62cd137150>,
#  <matplotlib.lines.Line2D at 0x7f62cd137250>,
#  <matplotlib.lines.Line2D at 0x7f62cd137290>,
#  <matplotlib.lines.Line2D at 0x7f62cd1374d0>]

# %% [markdown]
# # hsic(x, zc), hsic(y, zc)

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["hsic_x_zc"][:,0:8,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7f62cd0b0c90>,
#  <matplotlib.lines.Line2D at 0x7f62cd0b0150>,
#  <matplotlib.lines.Line2D at 0x7f62cd0b0ed0>,
#  <matplotlib.lines.Line2D at 0x7f62cd0b0fd0>,
#  <matplotlib.lines.Line2D at 0x7f62cd0bc110>,
#  <matplotlib.lines.Line2D at 0x7f62cd0bc150>,
#  <matplotlib.lines.Line2D at 0x7f62cd0bc390>]

# %%
plt.plot(onp.arange(res["path"]["loss"].shape[0]),res["path"]["hsic_y_zc"][:,:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7f62cd02ac50>,
#  <matplotlib.lines.Line2D at 0x7f62cd01de10>,
#  <matplotlib.lines.Line2D at 0x7f62cd02ae90>,
#  <matplotlib.lines.Line2D at 0x7f62cd02af90>,
#  <matplotlib.lines.Line2D at 0x7f62cd02afd0>,
#  <matplotlib.lines.Line2D at 0x7f62cd01d890>,
#  <matplotlib.lines.Line2D at 0x7f62cd01d910>]

# %% [markdown]
# ## solution

# %%
params = res["params"]

# %%
params["alpha_x"].shape
# Out:
# (1000, 7)

# %%
N = x.shape[0]
    

D_x = covariance_matrix(sqeuclidean_distance, x, x)
sigma_x_med = 1 / np.median(D_x)
K_x = rbf_kernel_matrix({'gamma': sigma_x_med}, x, x)

D_y = covariance_matrix(sqeuclidean_distance, y, y)
sigma_y = 1 / np.median(D_y)
K_y = rbf_kernel_matrix({'gamma': sigma_y}, y, y)
    
D_u = covariance_matrix(sqeuclidean_distance, U, U)
sigma_u = 1 / np.median(D_u)
K_u = rbf_kernel_matrix({'gamma': sigma_u}, U, U)

# %%
rep = 0
alpha_x = params["alpha_x"][:,rep][:,None]
alpha_y = params["alpha_y"][:,rep][:,None]
alpha_c = params["alpha_c"][:,rep][:,None]
    
zx = K_u@alpha_x
zy = K_u@alpha_y
zc = K_u@alpha_c
    
zx = (zx - np.mean(zx)) / (np.std(zx))
zy = (zy - np.mean(zy)) / (np.std(zy))
zc = (zc - np.mean(zc)) / (np.std(zc))

    
sig_x_h = np.exp(params["ln_sig_x_h"])
sig_zx_h = np.exp(params["ln_sig_zx_h"])
sig_zy_h = np.exp(params["ln_sig_zy_h"])
sig_zc_h = np.exp(params["ln_sig_zc_h"])
sig_rx_h = np.exp(params["ln_sig_rx_h"])
sig_ry_h = np.exp(params["ln_sig_ry_h"])
    


sig_x_f = np.exp(params["ln_sig_x_f"])
sig_zx_f = np.exp(params["ln_sig_zx_f"])
sig_zy_f = np.exp(params["ln_sig_zy_f"])
sig_zc_f = np.exp(params["ln_sig_zc_f"])
    
    
sigs_f = np.hstack([sig_x_f, sig_zx_f, sig_zy_f, sig_zc_f])
K_ax_f, K_ay_f, K_ax_h, K_ay_h, K_x_h, K_zx_h, K_zy_h, K_zc_h = kernel_mat_LNC(D_x, x, zx, zy, zc, sig_x_h, sig_zx_h, sig_zy_h, sig_zc_h, sigs_f) 
n = K_ax_f.shape[0]

ws = np.ones(n)
weights_y, resids_y, y_hat = krrModel(lam, K_ay_f, y, ws)
weights_x, resids_x, x_hat = krrModel(lam, K_ax_f, x, ws)

# %%
(alpha_x*np.ones(7))[0:10,:]
# Out:
# DeviceArray([[-67.809, -67.809, -67.809, -67.809, -67.809, -67.809,
#               -67.809],
#              [ 21.778,  21.778,  21.778,  21.778,  21.778,  21.778,
#                21.778],
#              [376.001, 376.001, 376.001, 376.001, 376.001, 376.001,
#               376.001],
#              [-84.022, -84.022, -84.022, -84.022, -84.022, -84.022,
#               -84.022],
#              [-28.095, -28.095, -28.095, -28.095, -28.095, -28.095,
#               -28.095],
#              [ 37.716,  37.716,  37.716,  37.716,  37.716,  37.716,
#                37.716],
#              [ 12.783,  12.783,  12.783,  12.783,  12.783,  12.783,
#                12.783],
#              [-45.376, -45.376, -45.376, -45.376, -45.376, -45.376,
#               -45.376],
#              [-13.79 , -13.79 , -13.79 , -13.79 , -13.79 , -13.79 ,
#               -13.79 ],
#              [ -1.295,  -1.295,  -1.295,  -1.295,  -1.295,  -1.295,
#                -1.295]], dtype=float32)

# %%
plt.scatter(x, x_hat)

# %%
_, _, xu_hat = krrModel(lam, K_u, x, ws)

# %%
plt.scatter(x, xu_hat)

# %%
plt.scatter(y, y_hat)

# %%
K_ayu_f  = K_x_h*K_u

# %%
weights_yu, resids_yu, yu_hat = krrModel(lam, K_ayu_f, y, ws)

# %%
plt.scatter(y, yu_hat)

# %%
_, _, yx_hat = krrModel(lam, K_x_h, y, ws)

# %%
plt.scatter(y, yx_hat)

# %%
alpha_x = params["alpha_x"][:,rep][:,None]
alpha_y = params["alpha_y"][:,rep][:,None]
alpha_c = params["alpha_c"][:,rep][:,None]
    
zx = K_u@alpha_x
zy = K_u@alpha_y
zc = K_u@alpha_c

# %%
zx.shape
# Out:
# (1000, 1)

# %%
plt.scatter(zx, x)

# %%
plt.scatter(zc, x)

# %%
plt.scatter(zx, y)

# %%
plt.scatter(zy, y)

# %%
plt.scatter(zc, y)
